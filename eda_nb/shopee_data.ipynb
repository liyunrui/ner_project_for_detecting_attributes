# %%
#! /usr/bin/env python3
"""
Created on Oct 24 2018

Text preprocessing and sequential labeling.

TO do list in the future:
    - pull data again using pyspark for getting original item_name
    
@author: Ray

"""

import sys
import os
import ast # real json-like string
import pandas as pd
import gc
import sys
sys.path.append('../../brand_recognition_bio_FE/preprocessing')
from clean_helpers import clean_name

def filter_data_for_ner_task(df, out_col, FLAG, attr = ' Brand'):
    """
    Return reliable data that we generally make sure attribute you assigned exist in the title.
    """
    num_filter = 0
    keep = []
    attr_tags = []
    for ix, row in df.iterrows():
        if FLAG == 'shopee':
            title = row['title'] # str
            tagging_dict = ast.literal_eval(row['mobile']) # dict
            attr_tag = tagging_dict[attr][0][0] # str
            if attr_tag.lower() in title.lower():
                keep.append(1)
                attr_tags.append(attr_tag)
            else:
                num_filter += 1
                keep.append(0)
                attr_tags.append(0)
        elif FLAG == 'lazada':
            title = row['item_name'] # str
            attr_tag = row['brand'] # str
            if attr_tag.lower() in title.lower():
                keep.append(1)
                attr_tags.append(attr_tag)
            else:
                num_filter += 1
                keep.append(0)
                attr_tags.append(0)
            
        else:
            # if the assertion fails, Python uses ArgumentExpression as the argument for the AssertionError. 
            assert False,  'the FLAG only accecpt shopee and lazada lah fuck u !!' # condition, AssertionError
    #-----------------
    # output
    #-----------------
    df['keep'] = keep
    df['attr_tags'] = attr_tags
    df.rename(columns = {'title': out_col[0], 'attr_tags':out_col[1]}, inplace = True)
    df = df[df.keep == 1]
    df = df[out_col]
    gc.collect()
    return df, num_filter

def sequence_labeling_w_bio_encoding(row, NORMALIZED = False):
    '''
    BIO encoding is a distant supervision approach to automatically generate training data for training machine- earning based model. 
    
        # B-B: 2
        # I-B: 1
        # O: 0
    Reference for distant supervision approach: http://deepdive.stanford.edu/distant_supervision
    Reference for BIO : Attribute Extraction from Product Titles in eCommerce.
    Assumption:
        - We assume that one sku only has one brand name.(kind of non-realistic)
    parameters:
    --------------
    df: DataFrame
    if_assumption: str. if True, we assume we only have one-single brand_word in one item_name. 
    Otherwise, we can have multiple token with positive lable in one item_name.
    '''

    # initialize variables
    word_list = []
    tagging = [] # multi-class label, {0:not part of the brand name, 1: intermediate part of the brand name, 2:beginning of the brand name}
    item_name = []
    val = [] 
    #---------------
    # sequential labeling with BIO encoding
    #---------------
    brand_started = False
    b_ix = 0
    brand = row.what_brand_name.iloc[0].split(' ')
    title = clean_name(row['item_name'].iloc[0]).split(' ')
    # filter
    title = [t for t in title if '' != t]
    for w_ix, word in enumerate(title):
        if word.lower() == brand[0].lower():
            tagging.append(2) # B-B: 2
            brand_started = True
            b_ix += 1
        elif (len(brand) > 1) and (brand_started):
            if b_ix >= len(brand):
                # for avoiding . For example, if 'BUMBLE AND BUMBLE by Bumble and Bumble: QUENCHING CONDITIONER 8.5 OZ'
                tagging.append(0) # O: 0
                brand_started = False  
                b_ix = 0                
            else:
                if word.lower() == brand[b_ix].lower():
                    tagging.append(1) # I-B: 1
                    b_ix += 1
                    if b_ix == len(brand):
                        # go back to orginal state because we already marked what we want
                        brand_started = False
                        b_ix = 0
                else:
                    tagging.append(0) # O: 0
                    brand_started = False     
                    # if we need to modified the labeling we priviously marked.
                    if b_ix < len(brand):
                        go_back_to_modified = 0
                        for i in range(b_ix):
                            #print ('w_ix', w_ix) # w_ix 對應的不是整個 tagging的list: 兩個解法, 1.groupby 2.w_ix要一直被加上
                            go_back_to_modified += 1
                            #print ('go back', w_ix - go_back_to_modified)
                            tagging[w_ix - go_back_to_modified] = 0 # O: 0
                        # Once removing privous labeling, we update b_ix to zero
                        b_ix = 0         
        else:
            brand_started = False
            tagging.append(0) # O: 0
        #---------------------------
        # for output dataframe
        #---------------------------
        if NORMALIZED == True:
            word_list.append(word.lower())
        else:
            word_list.append(word)
        item_name.append(clean_name(row['item_name'].iloc[0]))
        val.append(row['eval_set'].iloc[0])
    #---------------------------
    # output
    #---------------------------
    df = pd.DataFrame({'tokens':word_list, 
                'label': tagging,
                'eval_set': val,
                'item_name':item_name})[['item_name','tokens','label','eval_set']]
    return df

# %%
    #--------------------------
    # setting
    #--------------------------
    output_column = ['item_name', 'brand', 'eval_set']

    #--------------------------
    # loading data
    #--------------------------
    lazada_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_brand.csv')
    shoope_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_tagging.csv')

    #--------------------------
    # preprocessing data
    #--------------------------
    shoope_mobile.drop_duplicates(subset = ['itemid'], inplace = True)
    lazada_mobile.brand = lazada_mobile.brand.apply(lambda x : x.lower())
    lazada_mobile.rename(columns = {'title':'item_name'}, inplace = True)


    #--------------------------
    # data configuration: take Lazada data as testing and shoppe as training data.
    #-------------------------- 

    lazada_mobile['eval_set'] = ['test' for i in range(len(lazada_mobile))]
    shoope_mobile['eval_set'] = ['train' for i in range(len(shoope_mobile))]
    #--------------------------
    # filter: In order to get high-quality data, we remove the sku that his attribute name do not exist in title from our shopee data.
    #--------------------------
    attr = ' Brand'
    lazada_mobile, num_filter_l = filter_data_for_ner_task(lazada_mobile, FLAG = 'lazada', out_col = output_column, attr =  attr)
    shoope_mobile, num_filter_s = filter_data_for_ner_task(shoope_mobile, FLAG = 'shopee', out_col = output_column, attr =  attr)
    print ('num_sku_removed from shopee: {}'.format(num_filter_s))
    print ('num_sku_removed from lazada: {}'.format(num_filter_l))
# Out:
# num_sku_removed from shopee: 39873
# num_sku_removed from lazada: 18004

# %%
shoope_mobile.shape
# Out:
# (269916, 3)

# %%
lazada_mobile.shape
# Out:
# (12404, 4)

# %%
lazada_mobile
# Out:
#                                                item_name       brand  \
# 0      Samsung Galaxy J2 Prime REFRESH SM-G532 - Abso...     samsung
# 1       Samsung Galaxy J1 Ace 2016 SM-J111 - 8GB - Hitam     samsung
# 2      Samsung Galaxy J2 Prime REFRESH SM-G532 - Meta...     samsung
# 3      Samsung Galaxy J1 Ace 2016 SM-J111 - 8GB - Putih      samsung
# 4               Samsung Galaxy J2 Prime SM-G532 - Silver     samsung
# 5                  Samsung Galaxy J2 Pro - SMJ250 - Gold     samsung
# 6        Samsung Galaxy J1 Ace 2016 SM-J111 - 8GB -
# 30398  DOOGEE BL12000 6.0 Inch 12000mAh Battery 12V/3...      doogee
# 30399                   Apple iPhone 6s 16GB - Rose Gold       apple
# 30400                 Apple iPhone 6 - 16Gb - Space Grey       apple
# 30401  Apple Original iPhone 5 LCD + Touch Screen Ass...       apple
# 30402                  Apple iPhone 6 LL/A Silent Camera       apple
# 30403  Shockproof Military Heavy Duty Karet dengan Ha...       apple
# 30404  Samsung Galaxy J7 Duo J720 Smartphone - 3/32 G...     samsung
# 30405  Samsung Galaxy J7 Duo J720 Smartphone - 3/32 G...     samsung
# 30406  Xiaomi Mi 8 Smartphone [128 GB/ 6 GB] Grs. dis...      xiaomi
# 30407            VIVO V11 PRO 6/64GB - Plus Tas Slempang        vivo
#
#             brand eval_set
# 0         samsung     test
# 1         samsung     test
# 2         samsung     test
# 3         samsung     test
# 4         samsung     test
# 5         samsung     test
# 6         samsung     test
# 7         samsung     test
# 8         samsung     test
# 9         samsung     test
# 10        samsung     test
# 11        samsung     test
# 13        samsung     test
# 14        samsung     test
# 15        samsung     test
# 16        samsung     test
# 17        samsung     test
# 18        samsung     test
# 19        samsung     test
# 20        samsung     test
# 21        samsung     test
# 22        samsung     test
# 23        samsung     test
# 24        samsung     test
# 25        samsung     test
# 26        samsung     test
# 27        samsung     test
# 28        samsung     test
# 29        samsung     test
# 30        samsung     test
# ...           ...      ...
# 30311      xiaomi     test
# 30312     samsung     test
# 30313        vivo     test
# 30314        vivo     test
# 30315        vivo     test
# 30316        vivo     test
# 30317        vivo     test
# 30318        asus     test
# 30319        asus     test
# 30320        asus     test
# 30321        asus     test
# 30322        asus     test
# 30333      huawei     test
# 30391          lg     test
# 30392          lg     test
# 30393  blackberry     test
# 30394      doogee     test
# 30395      doogee     test
# 30396      doogee     test
# 30397      doogee     test
# 30398      doogee     test
# 30399       apple     test
# 30400       apple     test
# 30401       apple     test
# 30402       apple     test
# 30403       apple     test
# 30404     samsung     test
# 30405     samsung     test
# 30406      xiaomi     test
# 30407        vivo     test
#
# [12404 rows x 4 columns]

# %%
df1.head() # is_brand --> tag

# %%
shoope_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_tagging.csv')

# %%
shoope_mobile.shape

# %%
shoope_mobile.head()

# %%
c = 0
for ix, row in shoope_mobile.iterrows():
    title = row['title'] # str
    tagging_dict = ast.literal_eval(row['mobile']) # dict
    attr_tag = tagging_dict[' Brand'][0][0] # str
    if attr_tag.lower() in title.lower():
        pass
    else:
        print ('title', title)
        print ('attr_tag', attr_tag)
        if 'iphone' in title.lower():
            c+=1
print (c)

# %%
def filter_data_for_ner_task(df, out_col, attr = ' Brand'):
    """
    Return reliable data that we generally make sure attribute you assigned exist in the title.
    """
    num_filter = 0
    keep = []
    attr_tags = []
    for ix, row in df.iterrows():
        title = row['title'] # str
        tagging_dict = ast.literal_eval(row['mobile']) # dict
        attr_tag = tagging_dict[attr][0][0] # str
        if attr_tag.lower() in title.lower():
            keep.append(1)
            attr_tags.append(attr_tag)
        else:
            num_filter += 1
            keep.append(0)
            attr_tags.append(0)
    #-----------------
    # output
    #-----------------
    df['keep'] = keep
    df['attr_tags'] = attr_tags
    df.rename(columns = {'title': out_col[0], 'attr_tags':out_col[1]}, inplace = True)
    df[df.keep == 1]
    df = df[out_col]
    gc.collect()
    return df, num_filter

# %%
# df, num_filter = filter_data_for_ner_task(shoope_mobile.head(100), attr = ' Brand')
output_column = ['item_name', 'brand']
df, num_filter = filter_data_for_ner_task(shoope_mobile.head(100), out_col = output_column, attr =  ' Brand')

# %%
df

# %%
df.shape

# %%
39873 / shoope_mobile.shape[0]

# %%
df.head()

# %%
#--------------------------
# loading data
#--------------------------
lazada_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_brand.csv')
shoope_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_tagging.csv')

#--------------------------
# preprocessing data
#--------------------------
shoope_mobile.drop_duplicates(subset = ['itemid'], inplace = True)
lazada_mobile.brand = lazada_mobile.brand.apply(lambda x : x.lower())
lazada_mobile.rename(columns = {'title':'item_name'}, inplace = True)

brand_list_lazada = set(lazada_mobile.brand.unique())
# brand_list_shopee = set(shoope_mobile.brand.unique())
# print ('difference betwee target and source dataset', brand_list_lazada.difference(brand_list_shopee))

# %%
lazada_mobile.head()

# %%
#--------------------------
# setting
#--------------------------
output_column = ['item_name', 'brand']
#--------------------------
# loading data
#--------------------------
lazada_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_brand.csv')
shoope_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_tagging.csv')

#--------------------------
# preprocessing data
#--------------------------
shoope_mobile.drop_duplicates(subset = ['itemid'], inplace = True)
lazada_mobile.brand = lazada_mobile.brand.apply(lambda x : x.lower())
lazada_mobile.rename(columns = {'title':'item_name'}, inplace = True)


#--------------------------
# data configuration: take Lazada data as testing and shoppe as training data.
#-------------------------- 

lazada_mobile['eval_set'] = ['test' for i in range(len(lazada_mobile))]
shoope_mobile['eval_set'] = ['train' for i in range(len(shoope_mobile))]

# 
df = pd.concat([lazada_mobile[output_column], shoope_mobile[output_column]], axis = 0)

# %%
shoope_mobile.head()

# %%
lazada_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_brand.csv')

# %%
lazada_mobile.columns.tolist()
# Out:
# ['brand', 'title', 'price', 'page_num', 'item_url', 'image_url']

# %%
lazada_mobile.head()
# Out:
#      brand                                              title         price  \
# 0  Samsung  Samsung Galaxy J2 Prime REFRESH SM-G532 - Abso...  1255000.00Rp
# 1  Samsung   Samsung Galaxy J1 Ace 2016 SM-J111 - 8GB - Hitam  1029000.00Rp
# 2  Samsung  Samsung Galaxy J2 Prime REFRESH SM-G532 - Meta...  1255000.00Rp
# 3  Samsung  Samsung Galaxy J1 Ace 2016 SM-J111 - 8GB - Putih   1029000.00Rp
# 4  Samsung           Samsung Galaxy J2 Prime SM-G532 - Silver  1255000.00Rp
#
#    page_num                                           item_url  \
# 0         1  https://www.lazada.co.id/products/samsung-gala...
# 1         1  https://www.lazada.co.id/products/samsung-gala...
# 2         1  https://www.lazada.co.id/products/samsung-gala...
# 3         1  https://www.lazada.co.id/products/samsung-gala...
# 4         1  https://www.lazada.co.id/products/samsung-gala...
#
#                                            image_url
# 0  https://id-live-01.slatic.net/original/975bb08...
# 1  https://id-test-11.slatic.net/p/2/samsung-gala...
# 2  https://id-live-01.slatic.net/original/aa5584e...
# 3  https://id-test-11.slatic.net/p/2/samsung-gala...
# 4  https://id-test-11.slatic.net/p/2/samsung-gala...

# %%
#! /usr/bin/env python3
"""
Created on Oct 24 2018

It provides text preprocessing and 
@author: Ray

"""

import sys
import ast # real json-like string
import pandas as pd
import gc
import sys
import os
sys.path.append('../../brand_recognition_bio_FE/preprocessing')
sys.path.append('../../brand_recognition_bio_FE/py_model')
from preprocessing import sequence_labeling_w_bio_encoding
import logging

def filter_data_for_ner_task(df, out_col, attr = ' Brand'):
    """
    Return reliable data that we generally make sure attribute you assigned exist in the title.
    """
    num_filter = 0
    keep = []
    attr_tags = []
    for ix, row in df.iterrows():
        title = row['title'] # str
        tagging_dict = ast.literal_eval(row['mobile']) # dict
        attr_tag = tagging_dict[attr][0][0] # str
        if attr_tag.lower() in title.lower():
            keep.append(1)
            attr_tags.append(attr_tag)
        else:
            num_filter += 1
            keep.append(0)
            attr_tags.append(0)
    #-----------------
    # output
    #-----------------
    df['keep'] = keep
    df['attr_tags'] = attr_tags
    df.rename(columns = {'title': out_col[0], 'attr_tags':out_col[1]}, inplace = True)
    df = df[df.keep == 1]
    df = df[out_col]
    gc.collect()
    return df, num_filter

if __name__ == '__main__':
    #--------------------------
    # setting
    #--------------------------
    output_column = ['item_name', 'brand', 'eval_set']

    #--------------------------
    # loading data
    #--------------------------
    lazada_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_brand.csv')
    shoope_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_tagging.csv')

    #--------------------------
    # preprocessing data
    #--------------------------
    shoope_mobile.drop_duplicates(subset = ['itemid'], inplace = True)
    lazada_mobile.brand = lazada_mobile.brand.apply(lambda x : x.lower())
    lazada_mobile.rename(columns = {'title':'item_name'}, inplace = True)


    #--------------------------
    # data configuration: take Lazada data as testing and shoppe as training data.
    #-------------------------- 

    lazada_mobile['eval_set'] = ['test' for i in range(len(lazada_mobile))]
    shoope_mobile['eval_set'] = ['train' for i in range(len(shoope_mobile))]
    #--------------------------
    # filter: In order to get high-quality data, we remove the sku that his attribute name do not exist in title from our shopee data.
    #--------------------------
    attr = ' Brand'
    shoope_mobile, num_filter = filter_data_for_ner_task(shoope_mobile, out_col = output_column, attr =  attr)
    print ('num_sku_removed: {}'.format(num_filter))

    df = pd.concat([lazada_mobile[output_column], shoope_mobile[output_column]], axis = 0)
    del lazada_mobile, shoope_mobile
    gc.collect()

    #--------------------------
    # BIO tagging
    #--------------------------
    df.rename(columns = {'brand':'what_brand_name'}, inplace = True)
# Out:
# num_sku_removed: 39873

# %%
df
# Out:
#                                                 item_name what_brand_name  \
# 0       Samsung Galaxy J2 Prime REFRESH SM-G532 - Abso...         samsung
# 1        Samsung Galaxy J1 Ace 2016 SM-J111 - 8GB - Hitam         samsung
# 2       Samsung Galaxy J2 Prime REFRESH SM-G532 - Meta...         samsung
# 3       Samsung Galaxy J1 Ace 2016 SM-J111 - 8GB - Putih          samsung
# 4                Samsung Galaxy J2 Prime SM-G532 - Silver         samsung
# 5                   Samsung Galaxy J2 Pro - SMJ250 - Gold         samsung
# 6         Samsung Galaxy J1 Ace 2016 SM-J111 - 8GB -
# 309783  super sale promo shopee 9.9 oppo f9 4gb ram 64...            OPPO
# 309784  huawei honor 6x pro ini yang 4gb/64gb bukan yg...          Huawei
# 309785  oppo f7 youth 4gb/64gb ai beauty technology 20...            OPPO
# 309786        xiaomi redmi 6a gold 2/16 garansi resmi tam          Xiaomi
# 309787  promo diskon 80 hp xiaomi redmi note 4x ram 3/...          Xiaomi
# 309788            oppo f7 plus ram 6/128 gb garansi resmi            OPPO
#
#        eval_set
# 0          test
# 1          test
# 2          test
# 3          test
# 4          test
# 5          test
# 6          test
# 7          test
# 8          test
# 9          test
# 10         test
# 11         test
# 12         test
# 13         test
# 14         test
# 15         test
# 16         test
# 17         test
# 18         test
# 19         test
# 20         test
# 21         test
# 22         test
# 23         test
# 24         test
# 25         test
# 26         test
# 27         test
# 28         test
# 29         test
# ...         ...
# 309757    train
# 309758    train
# 309759    train
# 309760    train
# 309761    train
# 309762    train
# 309763    train
# 309765    train
# 309766    train
# 309767    train
# 309768    train
# 309769    train
# 309770    train
# 309771    train
# 309772    train
# 309774    train
# 309775    train
# 309776    train
# 309777    train
# 309778    train
# 309779    train
# 309780    train
# 309781    train
# 309782    train
# 309783    train
# 309784    train
# 309785    train
# 309786    train
# 309787    train
# 309788    train
#
# [300324 rows x 3 columns]

# %%
df.head(300).groupby('item_name').apply(lambda x: sequence_labeling_w_bio_encoding(x, NORMALIZED = False)).reset_index(drop = True)
# Out:
# -------------------------------------------------------------------------
# KeyError                                Traceback (most recent call last)
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'is_valid'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                Traceback (most recent call last)
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# <ipython-input-5-2d111fff8dd4> in <lambda>(x)
# ----> 1 df.head(300).groupby('item_name').apply(lambda x: sequence_labeling_w_bio_encoding(x, NORMALIZED = False)).reset_index(drop = True)
#
# ~/ner_project/brand_recognition_bio_FE/preprocessing/preprocessing.py in sequence_labeling_w_bio_encoding(row, NORMALIZED)
#     204         item_name.append(clean_name(row['item_name'].iloc[0]))
# --> 205         val.append(row['is_valid'].iloc[0])
#     206     #---------------------------
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'is_valid'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                Traceback (most recent call last)
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'item_name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                Traceback (most recent call last)
# <ipython-input-5-2d111fff8dd4> in <module>()
# ----> 1 df.head(300).groupby('item_name').apply(lambda x: sequence_labeling_w_bio_encoding(x, NORMALIZED = False)).reset_index(drop = True)
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     928
#     929                 with _group_selection_context(self):
# --> 930                     return self._python_apply_general(f)
#     931
#     932         return result
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# <ipython-input-5-2d111fff8dd4> in <lambda>(x)
# ----> 1 df.head(300).groupby('item_name').apply(lambda x: sequence_labeling_w_bio_encoding(x, NORMALIZED = False)).reset_index(drop = True)
#
# ~/ner_project/brand_recognition_bio_FE/preprocessing/preprocessing.py in sequence_labeling_w_bio_encoding(row, NORMALIZED)
#     157     b_ix = 0
#     158     brand = row.what_brand_name.iloc[0].split(' ')
# --> 159     title = clean_name(row['item_name'].iloc[0]).split(' ')
#     160     # filter
#     161     title = [t for t in title if '' != t]
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'item_name'

# %%
df1 = pd.read_csv('../data/processed/mobile_training_v2.csv')

# %%
df1
# Out:
#                                                  item_name      tokens  label  \
# 0          Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White     Samsung      2
# 1          Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White      Galaxy      0
# 2          Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White          J1      0
# 3          Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White         Ace      0
# 4          Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White        2016      0
# 5          Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White    SM-J111F      0
# 6          Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White         8GB      0
# 7          Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White           -      0
# 8          Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White       White      0
# 9             Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...   Blackview      2
# 10            Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...      BV8000      0
# 11            Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...         Pro      0
# 12            Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...         RAM      0
# 13            Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...         6GB      0
# 14            Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...        64GB      0
# 15            Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...        IP68      0
# 16            Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...  Waterproff      0
# 17            Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...      Rugged      0
# 18            Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...  Smartphone      0
# 19                                     iCherry C118 -putih     iCherry      2
# 20                                     iCherry C118 -putih        C118      0
# 21                                     iCherry C118 -putih      -putih      0
# 22                     Advan Hammer R3F - Dual Sim - Hitam       Advan      0
# 23                     Advan Hammer R3F - Dual Sim - Hitam      Hammer      0
# 24                     Advan Hammer R3F - Dual Sim - Hitam         R3F      0
# 25                     Advan Hammer R3F - Dual Sim - Hitam           -      0
# 26                     Advan Hammer R3F - Dual Sim - Hitam        Dual      0
# 27                     Advan Hammer R3F - Dual Sim - Hitam         Sim      0
# 28                     Advan Hammer R3F - Dual Sim - Hitam           -      0
# 29                     Advan Hammer R3F - Dual Sim - Hitam       Hitam      0
# ...                                                    ...         ...    ...
# 2142770  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...          3G      0
# 2142771  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...           -      0
# 2142772  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...       Putih      0
# 2142773  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...     Samsung      2
# 2142774  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...      Galaxy      0
# 2142775  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...           V      0
# 2142776  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...   SM-G313HZ      0
# 2142777  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...           -      0
# 2142778  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...      Kitkat      0
# 2142779  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...           -      0
# 2142780  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...        Dual      0
# 2142781  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...         SIM      0
# 2142782  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...          3G      0
# 2142783  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...           -      0
# 2142784  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...         4GB      0
# 2142785  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...           -      0
# 2142786  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...       Hitam      0
# 2142787  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...     Samsung      2
# 2142788  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...      Galaxy      0
# 2142789  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...           V      0
# 2142790  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...   SM-G313HZ      0
# 2142791  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...           -      0
# 2142792  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...     Android      0
# 2142793  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...      Kitkat      0
# 2142794  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...           -      0
# 2142795  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...        Dual      0
# 2142796  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...         SIM      0
# 2142797  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...          3G      0
# 2142798  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...           -      0
# 2142799  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...       Hitam      0
#
#         eval_set
# 0           test
# 1           test
# 2           test
# 3           test
# 4           test
# 5           test
# 6           test
# 7           test
# 8           test
# 9           test
# 10          test
# 11          test
# 12          test
# 13          test
# 14          test
# 15          test
# 16          test
# 17          test
# 18          test
# 19          test
# 20          test
# 21          test
# 22          test
# 23          test
# 24          test
# 25          test
# 26          test
# 27          test
# 28          test
# 29          test
# ...          ...
# 2142770     test
# 2142771     test
# 2142772     test
# 2142773     test
# 2142774     test
# 2142775     test
# 2142776     test
# 2142777     test
# 2142778     test
# 2142779     test
# 2142780     test
# 2142781     test
# 2142782     test
# 2142783     test
# 2142784     test
# 2142785     test
# 2142786     test
# 2142787     test
# 2142788     test
# 2142789     test
# 2142790     test
# 2142791     test
# 2142792     test
# 2142793     test
# 2142794     test
# 2142795     test
# 2142796     test
# 2142797     test
# 2142798     test
# 2142799     test
#
# [2142800 rows x 4 columns]
