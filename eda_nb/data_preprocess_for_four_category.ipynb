# %%
#! /usr/bin/env python3
"""
Created on Oct 24 2018

Text preprocessing and sequential labeling.

TO do list in the future:
    - pull data again using pyspark for getting original item_name when need feature engineering.

@author: Ray

"""

import sys
import os
import ast # real json-like string
import pandas as pd
import gc
sys.path.append('../../brand_recognition_bio_FE/preprocessing')
from clean_helpers import clean_name

pd.options.display.max_columns = 100
pd.options.display.max_rows = 500
pd.options.display.max_colwidth = 1000


def filter_data_for_ner_task(df, out_col, FLAG, attr = ' Brand'):
    """
    Return reliable data that we generally make sure attribute you assigned exist in the title.
    """
    num_filter = 0
    keep = []
    attr_tags = []
    sku_need_to_replenish_attribute = []
    for ix, row in df.iterrows():
        if FLAG == 'shopee':
            title = row['title'] # str
            #tagging_dict = ast.literal_eval(row['mobile']) # dict 
            tagging_dict = ast.literal_eval(row[9]) 
            #--------------
            # preprocessing for tagging filed in raw shaopee data
            #--------------
            try:
                if tagging_dict[attr] != 'no value':
                    attr_tag = tagging_dict[attr][0][0] # str
                else:
                    attr_tag = tagging_dict[attr] # str
            except:
                try:
                    attr1 = 'Brand'
                    if tagging_dict[attr1] != 'no value':
                        attr_tag = tagging_dict[attr1][0][0] # str
                    else:
                        attr_tag = tagging_dict[attr1] # str
                except:
                    attr2 = ' brand'
                    if tagging_dict[attr2] != 'no value':
                        attr_tag = tagging_dict[attr2][0][0] # str
                    else:
                        attr_tag = tagging_dict[attr2] # str
                   
            #--------------
            # core
            #--------------
            if attr_tag == 'no value':
                num_filter += 1
                keep.append(0)
                attr_tags.append(0)
                sku_need_to_replenish_attribute.append(title)
            elif attr_tag.lower() in title.lower():
                keep.append(1)
                attr_tags.append(attr_tag)
            else:
                num_filter += 1
                keep.append(0)
                attr_tags.append(0)
        elif FLAG == 'lazada':
            title = row['item_name'] # str
            attr_tag = row['brand'] # str
            if attr_tag.lower() in title.lower():
                keep.append(1)
                attr_tags.append(attr_tag)
            else:
                num_filter += 1
                keep.append(0)
                attr_tags.append(0)
            
        else:
            # if the assertion fails, Python uses ArgumentExpression as the argument for the AssertionError. 
            assert False,  '========= the FLAG only accecpt shopee and lazada lah fuck u =========' # condition, AssertionError
    # save sku without attribute value
    df[df.title.isin(sku_need_to_replenish_attribute)].to_csv('../data/processed/{}_missing.csv'.format(category), index = False)

    #-----------------
    # output
    #-----------------
    df['keep'] = keep
    df['attr_tags'] = attr_tags

    if FLAG == 'shopee':
        pass
    elif FLAG == 'lazada':
        df.drop(['brand'], axis = 1, inplace = True)
    else:
        assert False, '========= the FLAG only accecpt shopee and lazada lah fuck u ========='

    df.rename(columns = {'title': out_col[0], 'attr_tags':out_col[1]}, inplace = True)
    df = df[df.keep == 1]
    df = df[out_col]
    gc.collect()
    return df, num_filter, sku_need_to_replenish_attribute

def sequence_labeling_w_bio_encoding(row, NORMALIZED = False):
    '''
    BIO encoding is a distant supervision approach to automatically generate training data for training machine-learning based model. 
    
        # B-B: 2
        # I-B: 1
        # O: 0
    Reference for distant supervision approach: http://deepdive.stanford.edu/distant_supervision
    Reference for BIO : Attribute Extraction from Product Titles in eCommerce.
   
    parameters:
    --------------
    df: DataFrame
    if_assumption: str. if True, we assume we only have one-single brand_word in one item_name. 
    Otherwise, we can have multiple token with positive lable in one item_name.
    '''

    # initialize variables
    word_list = []
    tagging = [] # multi-class label, {0:not part of the brand name, 1: intermediate part of the brand name, 2:beginning of the brand name}
    item_name = []
    val = [] 
    #---------------
    # sequential labeling with BIO encoding
    #---------------
    brand_started = False
    b_ix = 0
    brand = row.what_brand_name.iloc[0].split(' ')
    title = clean_name(row['item_name'].iloc[0]).split(' ')
    # filter
    title = [t for t in title if '' != t]
    for w_ix, word in enumerate(title):
        if word.lower() == brand[0].lower():
            tagging.append(2) # B-B: 2
            brand_started = True
            b_ix += 1
        elif (len(brand) > 1) and (brand_started):
            if b_ix >= len(brand):
                # for avoiding . For example, if 'BUMBLE AND BUMBLE by Bumble and Bumble: QUENCHING CONDITIONER 8.5 OZ'
                tagging.append(0) # O: 0
                brand_started = False  
                b_ix = 0                
            else:
                if word.lower() == brand[b_ix].lower():
                    tagging.append(1) # I-B: 1
                    b_ix += 1
                    if b_ix == len(brand):
                        # go back to orginal state because we already marked what we want
                        brand_started = False
                        b_ix = 0
                else:
                    tagging.append(0) # O: 0
                    brand_started = False     
                    # if we need to modified the labeling we priviously marked.
                    if b_ix < len(brand):
                        go_back_to_modified = 0
                        for i in range(b_ix):
                            #print ('w_ix', w_ix) # w_ix 對應的不是整個 tagging的list: 兩個解法, 1.groupby 2.w_ix要一直被加上
                            go_back_to_modified += 1
                            #print ('go back', w_ix - go_back_to_modified)
                            tagging[w_ix - go_back_to_modified] = 0 # O: 0
                        # Once removing privous labeling, we update b_ix to zero
                        b_ix = 0         
        else:
            brand_started = False
            tagging.append(0) # O: 0
        #---------------------------
        # for output dataframe
        #---------------------------
        if NORMALIZED == True:
            word_list.append(word.lower())
        else:
            word_list.append(word)
        item_name.append(clean_name(row['item_name'].iloc[0]))
        val.append(row['eval_set'].iloc[0])
    #---------------------------
    # output
    #---------------------------
    df = pd.DataFrame({'tokens':word_list, 
                'label': tagging,
                'eval_set': val,
                'item_name':item_name})[['item_name','tokens','label','eval_set']]
    return df

# %% [markdown]
# # Beauty-Lips
# # Beauty-face
# # Women top
# # Women dress

# %%
os.listdir('/data/ner_task/dress/shopee_data_tagging_result/')
# Out:
# ['lips', 'dress', 'face', 'women_top', 'mobile']

# %%
# shopee = pd.read_csv('/data/ner_task/dress/shopee_data_tagging_result/dress/dress_ID_attribute_tagging_v2.csv')
# shopee

# %%
# for ix, row in shoope_mobile.sample(100).iterrows():
#     print (row[9])

# %%
os.listdir('/data/ner_task/dress/shopee_data_tagging_result/')
# Out:
# ['lips', 'dress', 'face', 'women_top', 'mobile']

# %%
for category in os.listdir('/data/ner_task/dress/shopee_data_tagging_result/')[:]:
    #--------------------------
    # setting
    #--------------------------
    print ('category : {}'.format(category))
    file_name = [i for i in os.listdir('/data/ner_task/dress/shopee_data_tagging_result/{}'.format(category)) if 'v2' in i ][0]
    date_path = '/data/ner_task/dress/shopee_data_tagging_result/{}/{}'.format(category, file_name)
    # output column
    output_column = ['item_name', 'brand', 'eval_set']
    # train/val ratio
    val_size = 0.1
    #--------------------------
    # loading data
    #--------------------------
    shopee = pd.read_csv(date_path)
    print ('# training sku : {}'.format(len(shopee[shopee.eval_set == 'train'])))
    print ('# testing sku : {}'.format(len(shopee[shopee.eval_set == 'test'])))

    #--------------------------
    # preprocessing data
    #--------------------------
    # droup duplicated: make our result trustworthy, don't count the same itemname with same brand 
    shopee.drop_duplicates(subset = ['title'], inplace = True)
    shopee = shopee.reset_index(drop = True)
    #--------------------------
    # filter: In order to get high-quality data, we remove the sku that his attribute name do not exist in title from our shopee data.
    #--------------------------
    attr = ' Brand'
    shopee, num_filter_s, sku_need_to_replenish_attribute = filter_data_for_ner_task(shopee, FLAG = 'shopee', out_col = output_column, attr =  attr)
    shopee.reset_index(drop = True, inplace = True)
    print ('eval_set-distribution', shopee.eval_set.value_counts())
    #--------------------------
    # data configuration
    #-------------------------- 
    # using time-series split method as validating strategy: switch to shuffle with item_id
    n = int(len(shopee[shopee.eval_set == 'train']) * val_size)
    print ('number of validating sku : {}'.format(n))
    val_item_name = set(pd.Series(shopee[shopee.eval_set == 'train'].tail(n).item_name))
    for ix, row in shopee[shopee.eval_set == 'train'].iterrows():
        if row['item_name'] in val_item_name:
            shopee['eval_set'].iloc[ix] = 'val' 

    print ('num_sku_removed from shopee: {}'.format(num_filter_s))
    print ('# of total sku : {}'.format(len(shopee)))
    print ('# training sku : {}'.format(len(shopee[shopee.eval_set == 'train'])))
    print ('# validating sku : {}'.format(len(shopee[shopee.eval_set == 'val'])))
    print ('# testing sku : {}'.format(len(shopee[shopee.eval_set == 'test'])))
    print ('testing ration : {}'.format(len(shopee[shopee.eval_set == 'test']) / len(shopee)))
    df = pd.concat([
        #lazada_mobile[output_column], 
        shopee[output_column]
    ], axis = 0)
    #del shopee
    gc.collect()
    #--------------------------
    # BIO tagging
    #--------------------------
    df.rename(columns = {'brand':'what_brand_name'}, inplace = True)

    df = df.groupby('item_name').apply(lambda x: sequence_labeling_w_bio_encoding(x, NORMALIZED = False)).reset_index(drop = True)

    #-------------------------
    # post-processing: remove some sku we cannot tag trough our sequential labeling.
    #-------------------------
    '''
    It's very little and the reason why this happening after text processomg is, for example, let's say a title of sku and brand is buy 1 get 1 free kasus and asus
    Then, he won't be filtered by text processing.
    '''
    no_label_item_name = df.groupby('item_name').label.mean().to_frame().reset_index()
    no_label_item_name = no_label_item_name[no_label_item_name.label == 0].item_name.tolist()
    df = df[~df.item_name.isin(no_label_item_name)]

    gc.collect()
    #--------------------------
    # save
    #--------------------------
    base_path = '../data/processed'

    if not os.path.isdir(base_path):
        os.makedirs(base_path)

    df.to_csv(os.path.join(base_path,'{}_training.csv'.format(category)) , index = False)
    print ('sucessfully saving the {} data '.format(category))
# Out:
# category : lips
# # training sku : 112415
# # testing sku : 28104
# eval_set-distribution train    35291
# test      8857
# Name: eval_set, dtype: int64
# number of validating sku : 3529
# num_sku_removed from shopee: 62685
# # of total sku : 44148
# # training sku : 31762
# # validating sku : 3529
# # testing sku : 8857
# testing ration : 0.20062063966657606
# sucessfully saving the lips data
# category : dress
# # training sku : 302864
# # testing sku : 75716
# eval_set-distribution train    3498
# test      492
# Name: eval_set, dtype: int64
# number of validating sku : 349
# num_sku_removed from shopee: 332061
# # of total sku : 3990
# # training sku : 3149
# # validating sku : 349
# # testing sku : 492
# testing ration : 0.12330827067669173
# sucessfully saving the dress data
# category : face
# # training sku : 211920
# # testing sku : 52990
# eval_set-distribution train    58844
# test     15121
# Name: eval_set, dtype: int64
# number of validating sku : 5884
# num_sku_removed from shopee: 138161
# # of total sku : 73965
# # training sku : 52960
# # validating sku : 5884
# # testing sku : 15121
# testing ration : 0.20443452984519705
# sucessfully saving the face data
# category : women_top
# # training sku : 304304
# # testing sku : 76080
# eval_set-distribution train    6789
# test     1391
# Name: eval_set, dtype: int64
# number of validating sku : 678
# num_sku_removed from shopee: 339057
# # of total sku : 8180
# # training sku : 6111
# # validating sku : 678
# # testing sku : 1391
# testing ration : 0.17004889975550122
# sucessfully saving the women_top data
# category : mobile
# # training sku : 247831
# # testing sku : 61958
# eval_set-distribution train    160247
# test      26642
# Name: eval_set, dtype: int64
# number of validating sku : 16024
# num_sku_removed from shopee: 43667
# # of total sku : 186889
# # training sku : 144223
# # validating sku : 16024
# # testing sku : 26642
# testing ration : 0.1425552065664646
# sucessfully saving the mobile data

# %%
assert 1==0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-788ee363e0a2> in <module>()
# ----> 1 assert 1==0
#
# AssertionError:

# %%
8857/44148

# %%
df

# %%
sku_need_to_replenish_attribute

# %%
#shopee.eval_set.value_counts()

# %%
"""
drop by itemid:
lips
num_sku_removed from shopee: 509
# of total sku : 491
# training sku : 416
# validating sku : 75
# testing sku : 0
category : dress
number of validating sku : 100
num_sku_removed from shopee: 997
# of total sku : 3
# training sku : 3
# validating sku : 0
# testing sku : 0
category : face
number of validating sku : 100
num_sku_removed from shopee: 618
# of total sku : 382
# training sku : 333
# validating sku : 49
# testing sku : 0
category : women_top
number of validating sku : 100
num_sku_removed from shopee: 988
# of total sku : 12
# training sku : 10
# validating sku : 2
# testing sku : 0
category : mobile
number of validating sku : 100
num_sku_removed from shopee: 279
# of total sku : 721
# training sku : 643
# validating sku : 78
# testing sku : 0

drop by itemname:
lips
num_sku_removed from shopee: 470
# of total sku : 439
# training sku : 394
# validating sku : 45
# testing sku : 0
category : dress
number of validating sku : 98
num_sku_removed from shopee: 982
# of total sku : 3
# training sku : 3
# validating sku : 0
# testing sku : 0
category : face
number of validating sku : 95
num_sku_removed from shopee: 604
# of total sku : 355
# training sku : 317
# validating sku : 38
# testing sku : 0
category : women_top
number of validating sku : 97
num_sku_removed from shopee: 967
# of total sku : 12
# training sku : 10
# validating sku : 2
# testing sku : 0
category : mobile
number of validating sku : 98
num_sku_removed from shopee: 275
# of total sku : 713
# training sku : 638
# validating sku : 75
# testing sku : 0
"""

# %%
shopee.drop_duplicates('item_name').shape

# %%
shopee.reset_index(drop = True)

# %%
pd.read_csv('/data/ner_task/data_for_brand_detection_model/face_training.csv')

# %%
'women_top_training.csv'[:-13]

# %% [markdown]
# # check out the original brand column built from ko.wen, dose she provie multiple brand?

# %%
date_path = '/data/ner_task/dress/shopee_data_tagging_result/dress/dress_ID_attribute_tagging_v2.csv'
df = pd.read_csv(date_path)

# %%
df
# Out:
#             itemid  \
# 0           103565
# 1           193241
# 2           254350
# 3           385458
# 4           505033
# 5           528784
# 6           550030
# 7           550070
# 8           550361
# 9           550384
# 10          565802
# 11          590713
# 12          590758
# 13          590794
# 14          590955
# 15          591307
# 16          591358
# 17          591401
# 18          591416
# 19          591554
# 20          610282
# 21          678718
# 22          692599
# 23          877397
# 24          947846
# 25         1009191
# 26         1046567
# 27         1066429
# 28         1066494
# 29         1066591
# 30         1078176
# 31         1116009
# 32         1129788
# 33         1156067
# 34         1273226
# 35         1274797
# 36         1275200
# 37         1464472
# 38         1495407
# 39         1532318
# 40         1629599
# 41         1673689
# 42         1691461
# 43         1761439
# 44         1773188
# 45         1851513
# 46         1874194
# 47         1917255
# 48         1961190
# 49         1998891
# 50         2007750
# 51         2033336
# 52         2062070
# 53         2073452
# 54         2074075
# 55         2098689
# 56         2134591
# 57         2140727
# 58         2140920
# 59         2181116
# 60         2204547
# 61         2246834
# 62         2249700
# 63         2269971
# 64         2286249
# 65         2286582
# 66         2292638
# 67         2361801
# 68         2377934
# 69         2378134
# 70         2484055
# 71         2490304
# 72         2541355
# 73         2576586
# 74         2589178
# 75         2597037
# 76         2610315
# 77         2667730
# 78         2708479
# 79         2733173
# 80         2796320
# 81         2799367
# 82         2806232
# 83         2806427
# 84         2806615
# 85         2806808
# 86         2849279
# 87         2910929
# 88         2923899
# 89         2993579
# 90         3051635
# 91         3075518
# 92         3125653
# 93         3133809
# 94         3152370
# 95         3155917
# 96         3167613
# 97         3170200
# 98         3174603
# 99         3175973
# 100        3176018
# 101        3205068
# 102        3212501
# 103        3253919
# 104        3254654
# 105        3284027
# 106        3338597
# 107        3350502
# 108        3367641
# 109        3385196
# 110        3421367
# 111        3448163
# 112        3487917
# 113        3512227
# 114        3574491
# 115        3588629
# 116        3597888
# 117        3751245
# 118        3905079
# 119        3907421
# 120        3947718
# 121        4014132
# 122        4014282
# 123        4037461
# 124        4038154
# 125        4039800
# 126        4044700
# 127        4045045
# 128        4102667
# 129        4113101
# 130        4139201
# 131        4163013
# 132        4165867
# 133        4172296
# 134        4213942
# 135        4214184
# 136        4214670
# 137        4270045
# 138        4343605
# 139        4343886
# 140        4377036
# 141        4410057
# 142        4509305
# 143        4510973
# 144        4517277
# 145        4532201
# 146        4533214
# 147        4614671
# 148        4655436
# 149        4696417
# 150        4713022
# 151        4762730
# 152        5000047
# 153        5022833
# 154        5067102
# 155        5067151
# 156        5110832
# 157        5111096
# 158        5116488
# 159        5126872
# 160        5130274
# 161        5147017
# 162        5151486
# 163        5255929
# 164        5257022
# 165        5257818
# 166        5258187
# 167        5258206
# 168        5258310
# 169        5290063
# 170        5290395
# 171        5301225
# 172        5306545
# 173        5306926
# 174        5308027
# 175        5308225
# 176        5309290
# 177        5309310
# 178        5309526
# 179        5319580
# 180        5360040
# 181        5360597
# 182        5361702
# 183        5436796
# 184        5475841
# 185        5501549
# 186        5505120
# 187        5510731
# 188        5512460
# 189        5517624
# 190        5540034
# 191        5552661
# 192        5557864
# 193        5568064
# 194        5609178
# 195        5614111
# 196        5646712
# 197        5716616
# 198        5776132
# 199        5829055
# 200        5829511
# 201        5829577
# 202        5829640
# 203        5829859
# 204        5831031
# 205        5867291
# 206        5889484
# 207        5928081
# 208        5929504
# 209        5931305
# 210        5943098
# 211        5962926
# 212        5999521
# 213        6009040
# 214        6017437
# 215        6028506
# 216        6097484
# 217        6120622
# 218        6135796
# 219        6140250
# 220        6271733
# 221        6271814
# 222        6288969
# 223        6290813
# 224        6373691
# 225        6382554
# 226        6454174
# 227        6524359
# 228        6524660
# 229        6829737
# 230        6844278
# 231        6912296
# 232        6912679
# 233        6948257
# 234        6952147
# 235        6968350
# 236        6996072
# 237        7019092
# 238        7021778
# 239        7022218
# 240        7022268
# 241        7022314
# 242        7022337
# 243        7036257
# 244        7194738
# 245        7195583
# 246        7203503
# 247        7315004
# 248        7339277
# 249        7372716
# ...            ...
# 378330  1484210471
# 378331  1484213372
# 378332  1484214438
# 378333  1484215846
# 378334  1484220033
# 378335  1484222240
# 378336  1484225281
# 378337  1484226594
# 378338  1484232439
# 378339  1484232568
# 378340  1484232590
# 378341  1484232648
# 378342  1484232633
# 378343  1484232663
# 378344  1484232811
# 378345  1484232881
# 378346  1484233030
# 378347  1484242034
# 378348  1484243626
# 378349  1484245149
# 378350  1484246123
# 378351  1484247942
# 378352  1484248106
# 378353  1484251592
# 378354  1484251957
# 378355  1484257027
# 378356  1484258188
# 378357  1484259585
# 378358  1484267677
# 378359  1484267702
# 378360  1484269281
# 378361  1484270020
# 378362  1484270215
# 378363  1484270177
# 378364  1484270179
# 378365  1484270325
# 378366  1484270360
# 378367  1484280312
# 378368  1484281514
# 378369  1484284433
# 378370  1484292367
# 378371  1484294409
# 378372  1484326957
# 378373  1484327168
# 378374  1484328091
# 378375  1484331463
# 378376  1484336245
# 378377  1484336450
# 378378  1484336666
# 378379  1484336685
# 378380  1484347592
# 378381  1484350142
# 378382  1484359926
# 378383  1484361416
# 378384  1484364302
# 378385  1484366327
# 378386  1484370311
# 378387  1484372196
# 378388  1484376303
# 378389  1484388863
# 378390  1484389171
# 378391  1484393690
# 378392  1484394651
# 378393  1484403574
# 378394  1484407033
# 378395  1484409087
# 378396  1484410944
# 378397  1484417127
# 378398  1484424916
# 378399  1484435893
# 378400  1484437469
# 378401  1484453264
# 378402  1484456028
# 378403  1484457232
# 378404  1484461290
# 378405  1484470524
# 378406  1484475154
# 378407  1484481651
# 378408  1484482185
# 378409  1484483812
# 378410  1484495029
# 378411  1484495251
# 378412  1484495722
# 378413  1484500375
# 378414  1484500637
# 378415  1484503960
# 378416  1484505029
# 378417  1484505089
# 378418  1484505101
# 378419  1484505346
# 378420  1484515336
# 378421  1484534723
# 378422  1484534777
# 378423  1484538026
# 378424  1484546639
# 378425  1484552384
# 378426  1484552380
# 378427  1484553856
# 378428  1484555446
# 378429  1484555851
# 378430  1484567310
# 378431  1484568892
# 378432  1484570306
# 378433  1484573088
# 378434  1484573273
# 378435  1484577328
# 378436  1484578839
# 378437  1484580553
# 378438  1484595961
# 378439  1484616909
# 378440  1484618827
# 378441  1484625655
# 378442  1484631367
# 378443  1484633662
# 378444  1484635949
# 378445  1484638820
# 378446  1484639295
# 378447  1484639609
# 378448  1484649519
# 378449  1484656361
# 378450  1484673678
# 378451  1484675755
# 378452  1484677141
# 378453  1484682425
# 378454  1484688962
# 378455  1484696183
# 378456  1484698264
# 378457  1484701070
# 378458  1484701491
# 378459  1484704757
# 378460  1484705222
# 378461  1484706647
# 378462  1484706975
# 378463  1484709797
# 378464  1484716579
# 378465  1484723707
# 378466  1484724078
# 378467  1484724652
# 378468  1484726147
# 378469  1484728694
# 378470  1484728858
# 378471  1484728822
# 378472  1484729689
# 378473  1484739255
# 378474  1484741573
# 378475  1484746817
# 378476  1484754507
# 378477  1484759800
# 378478  1484763409
# 378479  1484769609
# 378480  1484770462
# 378481  1484772874
# 378482  1484774923
# 378483  1484776694
# 378484  1484777120
# 378485  1484781308
# 378486  1484792035
# 378487  1484792286
# 378488  1484792629
# 378489  1484793082
# 378490  1484793305
# 378491  1484793881
# 378492  1484798777
# 378493  1484800577
# 378494  1484807113
# 378495  1484807188
# 378496  1484809109
# 378497  1484811119
# 378498  1484815656
# 378499  1484818036
# 378500  1484819331
# 378501  1484820282
# 378502  1484821411
# 378503  1484825098
# 378504  1484826051
# 378505  1484826194
# 378506  1484828042
# 378507  1484829795
# 378508  1484832248
# 378509  1484834283
# 378510  1484835010
# 378511  1484836561
# 378512  1484848433
# 378513  1484855736
# 378514  1484859276
# 378515  1484861700
# 378516  1484863373
# 378517  1484864044
# 378518  1484869274
# 378519  1484876230
# 378520  1484896685
# 378521  1484907627
# 378522  1484907690
# 378523  1484916660
# 378524  1484920486
# 378525  1484922444
# 378526  1484925353
# 378527  1484930211
# 378528  1484930346
# 378529  1484931075
# 378530  1484932684
# 378531  1484937800
# 378532  1484939231
# 378533  1484949673
# 378534  1484950473
# 378535  1484951008
# 378536  1484951835
# 378537  1484954211
# 378538  1484957349
# 378539  1484960120
# 378540  1484968618
# 378541  1484970210
# 378542  1484994802
# 378543  1484996288
# 378544  1485007786
# 378545  1485014424
# 378546  1485017968
# 378547  1485026401
# 378548  1485027893
# 378549  1485033326
# 378550  1485037275
# 378551  1485037620
# 378552  1485038376
# 378553  1485048902
# 378554  1485049207
# 378555  1485055872
# 378556  1485056724
# 378557  1485065875
# 378558  1485090024
# 378559  1485091674
# 378560  1485099235
# 378561  1485103055
# 378562  1485104795
# 378563  1485107788
# 378564  1485112252
# 378565  1485112654
# 378566  1485112998
# 378567  1485130226
# 378568  1485130325
# 378569  1485130398
# 378570  1485130513
# 378571  1485142642
# 378572  1485142931
# 378573  1485143453
# 378574  1485170918
# 378575  1485206152
# 378576  1485230589
# 378577  1485232976
# 378578  1485246396
# 378579  1485249767
#
#                                                                                                      title  \
# 0                                                         dress import hijau sifon onlineshop murah cd-252
# 1                                                                                         londgress brukat
# 2                                                                              floral blue dress by zalora
# 3                                                                                         white dior dress
# 4                                                                                  maxi dress jeans button
# 5                                                                             little black sparkling dress
# 6                                                                             dress princess grey gatsuone
# 7                                                                     dress dora light grey black gatsuone
# 8                                                                     dress calista blue polkadot gatsuone
# 9                                                                        dress clarisa blue denim gatsuone
# 10                                                                           korea tutu black dress s44980
# 11                                                                         dress clara royal blue gatsuone
# 12                                                                     dress kristina black motif gatsuone
# 13                                                                        dress janet black motif gatsuone
# 14                                                                          dress clea black comb gatsuone
# 15                                                                      dress griselda black comb gatsuone
# 16                                                                         dress ellen blue motif gatsuone
# 17                                                                                 dress alka red gatsuone
# 18                                                                     dress grace off white comb gatsuone
# 19                                                                            dress connie yellow gatsuone
# 20                                                                     dress jania black polkadot gatsuone
# 21                                                                     dress corina black checker gatsuone
# 22                                                                                       galaxy midi dress
# 23                                                                                  hello kitty long dress
# 24                                                                            ayda songket olla mini dress
# 25                                                                                       three floor dress
# 26                                                                                     grey babydoll dress
# 27                                                                              longdress kombinasi brukat
# 28                                                                               sabrina flare putih scuba
# 29                                                                                      setdress baby pink
# 30                                                       forever21 dress bodycon tribal baju pesta branded
# 31                                                                     mini dress cantik sexy 3 red button
# 32                                                                              gaun pesta princess yunani
# 33                                                           9.9supet shopping day dress maxi pajang hitam
# 34                                                                   body soul leopard print bodycon dress
# 35                                                                                        white maxi dress
# 36                                                                                             party dress
# 37                                                                                         sexy long dress
# 38                                                                              longdress orange satu tali
# 39                                                                        bigjill stripe all size termurah
# 40                                                                               long dress burberry choco
# 41                                                                    orsolya accordion spandek maxi skirt
# 42                                                                           free ongkir dress ombre merah
# 43                                                                         mishtira plain flare maxi skirt
# 44                                                                         body talk drees never been used
# 45                                                                            body and soul dress preloved
# 46                                                                                             sporty maxi
# 47                                                                     preloved stripe loose dress premium
# 48                                                            dress jersey kombinasi brukat glitter 111393
# 49                                                                                polkadot dark blue dress
# 50                                                         simple dress only black and white matt twiscone
# 51                                                           big size collar dutch dress short hand import
# 52                                                                       sold pull bear simple black dress
# 53                        pmb626 125rb maxi layer 2tone bhn angelo baby terry halus ld110 pjg 130 import 0
# 54                            rebecca dress bahan katun rayon adem ld85 p75 fit to m pinggang karet 65.000
# 55                                                                    grey stripe abstrak motif mini dress
# 56                                             free ongkir dress pesta ukuran big size/jumbo fit to xxxxxl
# 57                                                                                     wrap body con dress
# 58                                                                                  zara basic black dress
# 59                                                                                        h&m simply black
# 60                                                                                        h&m jersey dress
# 61                                                                                  india maxi kelly marun
# 62                                                                              maxi rainbow wedges import
# 63                                                                                      dress hitam accent
# 64                                                                           dress cornelia black gatsuone
# 65                                                                         dress gena navy stripe gatsuone
# 66                                                                                            dress stripe
# 67                                                                                  baju pesta tutu brukat
# 68                                                                         dress pesta tile koktail import
# 69                                                        gaun pesta tile/brukat/dress pendek import korea
# 70                                                 dress hitam import bangkok premium bahan wedges stretch
# 71                                                             gaun joda sale sisa brown atau cokelat kopi
# 72                                                        pluffyschoice strapless bra invisible tanpa tali
# 73                                                                                 ysl maxi dress pashmina
# 74                                                                                  sexy back s61400 dress
# 75                                                                                      dress brokat prada
# 76                                                                                        mini stipe dress
# 77                                                                         preloved dress party baju pesta
# 78                                                                                 dress minimalis florist
# 79                                                                                    preloved denim dress
# 80                                                              long dress import korea/gaun pesta elegant
# 81                                                      dress white bone by axe femme import from japan hq
# 82                                                                      wedding dress import ekor pangjang
# 83                                        wedding dress impor gaun pengantin mewah/ekor panjang pita besar
# 84                                                     wedding dress tutu import/dress duyung ekor panjang
# 85                                               dress party/gaun pesta tutu flowers import/wedding import
# 86                                                             dress pesta party tutu polkadot sexy import
# 87                                                                white long dress free ongkir jabodetabek
# 88                                  basic long dress syar i polos lengan panjang sifon ceruti high quality
# 89                                           dress summer long sleeve animal print chiffon casual mini cat
# 90                                                                                minimal plain pink dress
# 91                                                                    dress jalan/dress pesta merah import
# 92          dress ribbon bahan brukat import mix jersey super+tile ada lapisan furing belakang sleting fit
# 93                                                     dress pesta/dress kerja elegant high quality import
# 94                                                                                 dress kemben hitam biru
# 95                                                                                    wedding dress import
# 96                                                                bolero wedding dress bulu gaun pengantin
# 97                                                                     dress kotak houndstooth hijau party
# 98                                                               dress a line karet pinggang abu krem navy
# 99                                                                           19794 white eyelet lace s m l
# 100                                                                          19794 white eyelet lace s m l
# 101                                               dress bodycon tali belakang hitam krem biru toska coklat
# 102                                                                            topshop shocking pink dress
# 103                                                         wedding dress couple/set/gaun pengantin import
# 104                                                                         wedding dress import red white
# 105                                                                                dress pesta hijau tosca
# 106                                                                                        sexy dress bali
# 107                     xeno free ongkir midi dress/dress wanita/dress cewek/casual dress murah/jumbo maxi
# 108                                                                                     sexy dress in grey
# 109                                                                   dress putih kerah hitam bulat kantor
# 110                                                                                    carolina maxi merah
# 111                                                                                       long dress party
# 112                                                                                           dress brukat
# 113                            dress peach selutut model elegan tidak pernah dipakai warna:peach dan salem
# 114                                                                        terusan marun from sophie paris
# 115                                                                               dress kantor formal biru
# 116                                            dress maxi lengan panjang polos tekstur good quality co 655
# 117                                                                         jasmine brocade dress 7/8 hand
# 118                                                          gaun pesta/gaun pengantin/wedding dress short
# 119                                                           longdress party/gaun pesta putih elegan bulu
# 120                                                     wedding dress set/couple bunga merah cantik import
# 121                                                                          dress lime krem coklat a line
# 122                                                        dress bodycon hijau lime tanktop panjang pastel
# 123                                                   gaun pesta tile/chiffon/longdress/dress import korea
# 124                                                long dress import murah cocktail party tile lace brukat
# 125                                                                    dress kerja formal kantor executive
# 126                                                                                mini dress from minimal
# 127                                                           dress maxi lengan panjang motif bunga co 676
# 128                                                               dress lime orange krem navy hitam coklat
# 129                                                                 long dress cleopatra peplum gaun pesta
# 130                                                      wedding/pre-wedding dress/gown white by vera wang
# 131                                                                            dress hitam pesta krem pink
# 132                                                           dress maxi motif bunga lengan panjang kh 752
# 133                                                                                        span mini dress
# 134                                                     dress krem abu hitam kerah triangle karet pinggang
# 135                                                                   dress maxi kancing abu panjang katun
# 136                                                            dress maxi etnik batik panjang motif kuning
# 137                                                                                      floral tile dress
# 138                                                                                       long dress pesta
# 139                                                                                blue long mermaid dress
# 140                                          bkk 034 sexy dress bahan katun hanya ada warna pink dan tosca
# 141                                                    long dress lengan panjang motif bunga flower kh 684
# 142                                                                                            party dress
# 143                                                              gaun pengantin/wedding dress import merah
# 144                                                                                 nio hitam dress brukat
# 145                                                                                tea length a-line dress
# 146                                                                              dress bahan sifon organza
# 147                                                                                 h&m simple black dress
# 148                                                                                      dress body n soul
# 149                                     clearance sale black kitty dress kerah putih white collar peterpan
# 150                                                                        wedding dress set/couple import
# 151                                                                              long dress import elegant
# 152                                                                  hq 4425 etnic longdress blue size m l
# 153                                                                              dress wanita maroon hitam
# 154                                                 dress tali belakang hijau pink fanta biru muda bodycon
# 155                                                  dress toska kuning biru orange sobek belakang bodycon
# 156                                                        dress putih kerah lancip bodycon lengan panjang
# 157                                                             dress bodycon t neck leher navy biru hitam
# 158                                                                      kintamani batik peplum mini dress
# 159                                         sale dress natal tahun baru best quality red wool winter ds500
# 160                               sale dress natal tahun baru white onlye best quality bling diamond ds420
# 161                                                        sale high quality satin purple mini dress md439
# 162                                                                                      dress loose putih
# 163                                                       dress triangle bodycon pink navy hitam off white
# 164                                                           dress etnik abstrak lengan satu motif kuning
# 165                                                     dress loose simpel tali bahu soft pink kuning muda
# 166                                                                    dress basic bodycon hitam abu cupid
# 167                                               dress bodycon basic tanktop panjang zigzag abstrak cupid
# 168                                                              dress mini pink fanta biru muda ungu lime
# 169                                                                                             long dress
# 170                                                                                      lace brukat dress
# 171                                                                         raylla strip dress tunik black
# 172                                                     dress kantor formal karet belakang pinggang import
# 173                                                          dress lengan satu tube kemben hitam navy krem
# 174                                                                 dress navy lengan panjang kerah kantor
# 175                                                               dress flower lengan panjang motif kantor
# 176                                                                      dress putih kerah hitam ungu navy
# 177                                                               dress putih kerah hitam ungu navy simpel
# 178                                                                              blus polo abu kerah hitam
# 179                                                                              dress unicron blue import
# 180              sale preloved dress manik-manik ungu fit s pjg 80cm depan belakang variasi manik2 plastik
# 181       sale preloved dress sifon halus motif leopard coklat gradasi abu variasi blink kuning ada furing
# 182                                                                                       louis maxi wafel
# 183                                                dress hitam kemben party black swarovski karet punggung
# 184                                                                     dress a line coklat ungu krem lime
# 185                                                                        dress kuning biru hitam bodycon
# 186                                                                                bebe strip dress dr0062
# 187                                                     dress panjang lengan maxi pastel salem hijau hitam
# 188                                                                dress stripes hitam putih bodycon garis
# 189                                                                                         red long dress
# 190                                                                                             maxi jodie
# 191                                                 dress silk lengan panjang basic kuning hijau pink biru
# 192                                              dress maxi lengan panjang motif bahan wedges adem nad 335
# 193                                                           bohemian dress nfb1093 toska dusty pink ungu
# 194                                                                        enfocus studio black gold dress
# 195                                                                         dress hitam bodycon party midi
# 196                                                                          preloved dress pesta promnite
# 197                                                                   mini dress by pull and bear original
# 198                                                              dress two tone biru toska ungu putih muda
# 199                                                                   dress kantor hitam formal gold pesta
# 200                                                                              dress bodycon putih party
# 201                                    dress bodycon dua warna orange toska krem biru muda tanktop panjang
# 202                                                                              dress kantor a line lipit
# 203                                                                dress lengan panjang biru hitam bodycon
# 204                                                               dress hijau pink fanta biru muda bodycon
# 205                                                                 korea new fall tutu plaid dress 885920
# 206                                                                   bohemian dress korea nfbek52421white
# 207                                                               dress satin abu silver berkualitas pesta
# 208                                                                  dress kantor formal pesta berkualitas
# 209                                        dress formal pesta party biru hitam abu putih satin berkualitas
# 210                                                                       new zalora luxe lace shift dress
# 211                                                                                        new peplum navy
# 212                                                                                dress bodycon lace bahu
# 213                                                              new tartan casual dress in red import bkk
# 214                                                                              sexy dress bustier yellow
# 215                                                                                dress keeta long sleeve
# 216                                                                                 sexi long dress import
# 217                                                        korea fairly tale baby pink dress 45326 on sale
# 218                                                                                       maxi brukat nina
# 219                                            dress loose muat sampai xl biru muda garis hitam putih navy
# 220                                                                   sale tosca violet mini bodycon skirt
# 221                                                         2473 black korean import dress real no replica
# 222                                                   baju/dress/gaun/longdress/maxi/gamis/tile/tutu pesta
# 223                              chelix 3in1 ancila buterfly maxi 65.000 cardi+pasmina bahan spandek fit l
# 224                                       x 1 original branded women dress terusan wanita baju pesta party
# 225                                                dress hitam bodycon lengan panjang spiked studded putih
# 226                           lycra spandex inner shorts celana dalaman dress free size short ketat pendek
# 227                                                                             black floral dress by roem
# 228                                                                            floral colour dress by roem
# 229                                                                      dress surfer girl pink new size m
# 230                                                                                      maxi mania vw1099
# 231                                                           scuba slim cutside longdress maxidress ds765
# 232                                                       scuba bodycon midi dress plain gaun wanita ds766
# 233                                                                                         long hem kotak
# 234                                                                  maharania elegant shanghai mini dress
# 235                                                          v brocade stripe bodycon bangkok import dress
# 236                                                                             black and white mini dress
# 237                                                                                 long dress full brukat
# 238                                                                dress stripes garis hitam putih bodycon
# 239                                                                            dress lengan panjang kantor
# 240                                                                 dress bodycon bustier hitam navy merah
# 241                                                                               dress putih lengan hitam
# 242                                                                                 dress maxi hitam putih
# 243                                                                                   hanbok sweet pink po
# 244                                                                  dress bodycon hitam toska krem coklat
# 245                                                                    dress kantor hijau kerah putih navy
# 246                                                 dress putih kerah hitam white black collar best seller
# 247                                                                                              roxy maxi
# 248                                                                 flowery strap back black n white dress
# 249                                                                               sienna shift dress black
# ...                                                                                                    ...
# 378330                                                                  gamis syari balotelli tunik wolfis
# 378331   dress pesta model deep v-neck tanpa lengan fit and flare bahan lace ada ukuran besar untuk wanita
# 378332   壹 original retro literary fan lingge twist loose sweater coat female autumn and winter new v-neck
# 378333                                                                            dress jumbo black rayoni
# 378334                                                                          tunik dress hoodie fila xl
# 378335                                                                         skater mini dress h&m saleo
# 378336                                jumpsuit bodycon wanita dengan model bergaya elegan untuk pesta club
# 378337                  dress pesta model o-neck fit and flare tanpa lengan warna merah mawar untuk wanita
# 378338  壹 original autumn new long knit cardigan female korean version of the large size loose retro liter
# 378339          壹 original autumn new retro literary sweater wild v-neck sleeveless solid color vest women
# 378340  壹 original autumn new bottoming shirt sweater knit female long section literary loose harajuku sol
# 378341  壹 original cotton and linen floral shirt loose tops in the long retro art autumn blouse long-sleev
# 378342  壹 original retro ethnic style embroidery long shirt women loose right cotton linen large size shir
# 378343  壹 original autumn new product loose round neck pullover linen sweater female literary leave two-pi
# 378344   壹 original mori girl literary retro embroidery hollow hook flower loose long-sleeved shirt v-neck
# 378345                 壹 original retro art long sleeve cotton and linen shirt female autumn new loose top
# 378346        壹 original autumn new literary retro embroidery cotton and linen long shirt women loose wild
# 378347                                                          tommy hilfiger black floral dress termurah
# 378348                                                                      mini dress short le forever 21
# 378349      gaun midi wanita dengan bahan katun warna polos dan lengan setengah bergaya elegan ukuran xxxl
# 378350         dress bodycon casual model o-neck lengan 3 4 desain patchwork untuk wanita musim semi panas
# 378351                                      branded bomfash midi party baju pesta pendek warna hitam dress
# 378352                               daster pekalongan gayalo midi little cat dress hamil baju tidur rayon
# 378353                   midi dress lemone tumblr tee t shirt kaos cewe spandek premium wanita 534ss merah
# 378354                                           brukat jumbo big size wanita pita xl xxl pesta dress midi
# 378355                                                                                       britasya maxi
# 378356                                                           maxi dress rx fashion visgel syahrini max
# 378357                    sale maxi dress baju maxmara lux umbrella gamis syar 39 i abstrak mint biru muda
# 378358                                                          tunik babyterry bunny import 041018/110918
# 378359                                                    gamis jersey mayung motif shabby fit to xl busui
# 378360                       gaun pesta dengan model rok tutu bahan tulle dan hiasan renda untuk perempuan
# 378361                            zanzea long dress tanpa lengan model lipit bahan katun linen warna polos
# 378362                      zanzea dress lengan panjang casual model longgar desain patchwork gaya vintage
# 378363                     long dress sexy model v-neck backless gaya vintage boho bahan lace untuk wanita
# 378364                                                 zanzea long dress hoodie lengan panjang dengan saku
# 378365                                                   jl tunik fendi gold panjang bahannkaos import 931
# 378366         zanzea dress maxi wanita kerah tinggi kancing lengan panjang lipat gaya retro warna polos 3
# 378367                              maxi dress hd alya mutiara maxy gaun kondangan gamis syari hijab pesta
# 378368                                                               jl tunik army kancing adem import 932
# 378369                                                                 maxi dress bella spandex sale hitam
# 378370                                                              long dress duyung 10005l model mermaid
# 378371                                                            jl tunik given import bhn scuba adem 934
# 378372                               dress pesta model off shoulder lengan panjang bahan lace untuk wanita
# 378373                                         dress bodycon model off shoulder kerah crew neck bahan lace
# 378374                                                                 mini dress borkat lace wanita black
# 378375                                                                     button west 0133 rhg dress midi
# 378376                                                               dress bali vega panjang souvenir khas
# 378377                                                                dress bali vega pendek souvenir khas
# 378378                                                                         dress bali vega pendek oleh
# 378379                                                                               gamis polos supernova
# 378380                                                         ds324 dress pesta bigsize jumbo party murah
# 378381                                                     7238 minidress bahan scuba komb tile belt fit l
# 378382                                                                    gamis wolfis monalisa bunga ungu
# 378383                               long panjang satin silk soft pink tosca hitam import murah dress maxi
# 378384                          jazirah 25 abaya maxy murah wanita dress muslim lengan panjang gamis black
# 378385                                                                                      nafsi tunik ik
# 378386                                dress mini o-neck lengan pendek a-line bahan sifon untuk musim panas
# 378387                         ready stok banyak model terkini modern mididress sabrina flare putih r8615w
# 378388     termurah blouse wanita jumbo atasan dress winda 913 bigisze katun stretch fit to xxl midi murah
# 378389                         s-m 29 5 old navy floral jersey knit swing dress reccomended ready yg black
# 378390                                                      9213 longdress bahan scuba komb tile obi fit l
# 378391                                                               8255 longdress bahan scuba fit lkecil
# 378392                             diskon 27 pearl glorya maxyyyyy grey sy fashion wanita terbaru termurah
# 378393                diskon 35 r project marbella dress grey balotelly sk fashion wanita terbaru termurah
# 378394        termurah dress brukat atasan wanita long gaun pesta lengan lace korea import black red merah
# 378395                                                                                           ziya maxi
# 378396                                                                                      jenna dress ml
# 378397                                                     midi dress 46638 green white brocade lace s m l
# 378398                                    seds772 pesta sepan kimono wanita pastel modern murah dress mini
# 378399                                                                                  dreas chelsy denim
# 378400                               gamis putri dress seragam kondangan maxi muslim mayoutfit rubylicious
# 378401                                                                                    yuka dharya 11.9
# 378402                                                                       sl 2in1 maxi venezuela 5warna
# 378403                                                                                  dress tunik quinsa
# 378404                                                                                           yuka maxy
# 378405                                   d1790 kimono mini katun by vivo gaun pendek babydoll casual dress
# 378406                                                                                         oraida maxi
# 378407                                                            longdress/gaun pesta preloved merk mango
# 378408                                                                    annaline maxi jual gamis terbaru
# 378409                                                                                           yuka maxy
# 378410                                                               shana denim jumbo 0141 qgz dress midi
# 378411                               lengan panjang bodycon casual party night club evening cocktail dress
# 378412                          elegan leher bulat lengan pendek partai sheath bodycon pensil velvet dress
# ...
# 92      2015-11-04 16:10:51    train
# 93      2015-11-04 18:09:00    train
# 94      2015-11-05 02:11:40    train
# 95      2015-11-05 08:51:16    train
# 96      2015-11-05 14:59:28    train
# 97      2015-11-05 16:04:15    train
# 98      2015-11-05 18:00:27    train
# 99      2015-11-05 18:37:58    train
# 100     2015-11-05 18:39:06    train
# 101     2015-11-06 13:36:48    train
# 102     2015-11-06 17:03:32    train
# 103     2015-11-07 16:54:25    train
# 104     2015-11-07 17:16:49    train
# 105     2015-11-08 15:01:11    train
# 106     2015-11-09 23:50:35    train
# 107     2015-11-10 11:22:58    train
# 108     2015-11-10 18:10:27    train
# 109     2015-11-11 01:09:25    train
# 110     2015-11-11 22:11:26    train
# 111     2015-11-12 14:46:57    train
# 112     2015-11-13 13:52:13    train
# 113     2015-11-13 22:27:12    train
# 114     2015-11-15 17:01:00    train
# 115     2015-11-15 23:32:37    train
# 116     2015-11-16 10:20:45    train
# 117     2015-11-19 20:13:40    train
# 118     2015-11-23 17:00:34    train
# 119     2015-11-23 18:01:24    train
# 120     2015-11-24 17:09:19    train
# 121     2015-11-26 00:30:02    train
# 122     2015-11-26 00:33:50    train
# 123     2015-11-26 16:40:38    train
# 124     2015-11-26 16:57:07    train
# 125     2015-11-26 17:38:35    train
# 126     2015-11-26 19:52:30    train
# 127     2015-11-26 20:01:04    train
# 128     2015-11-28 02:06:53    train
# 129     2015-11-28 12:59:57    train
# 130     2015-11-29 01:29:30    train
# 131     2015-11-29 19:28:20    train
# 132     2015-11-29 20:56:53    train
# 133     2015-11-29 23:40:26    train
# 134     2015-12-01 00:51:40    train
# 135     2015-12-01 00:59:11    train
# 136     2015-12-01 01:16:57    train
# 137     2015-12-02 11:16:55    train
# 138     2015-12-03 20:05:23    train
# 139     2015-12-03 20:11:25    train
# 140     2015-12-04 14:22:22    train
# 141     2015-12-05 04:05:41    train
# 142     2015-12-07 15:48:28    train
# 143     2015-12-07 16:28:38    train
# 144     2015-12-07 18:59:16    train
# 145     2015-12-07 23:13:53    train
# 146     2015-12-07 23:37:27    train
# 147     2015-12-09 18:21:14    train
# 148     2015-12-10 13:56:20    train
# 149     2015-12-11 10:50:34    train
# 150     2015-12-11 16:51:42    train
# 151     2015-12-12 17:19:41    train
# 152     2015-12-17 19:06:45    train
# 153     2015-12-18 09:00:13    train
# 154     2015-12-19 02:37:50    train
# 155     2015-12-19 02:41:08    train
# 156     2015-12-20 02:38:06    train
# 157     2015-12-20 02:49:35    train
# 158     2015-12-20 10:25:16    train
# 159     2015-12-20 15:17:53    train
# 160     2015-12-20 16:43:42    train
# 161     2015-12-20 23:34:19    train
# 162     2015-12-21 01:26:48    train
# 163     2015-12-23 01:23:59    train
# 164     2015-12-23 02:01:16    train
# 165     2015-12-23 02:38:02    train
# 166     2015-12-23 02:58:43    train
# 167     2015-12-23 03:00:26    train
# 168     2015-12-23 03:09:16    train
# 169     2015-12-23 20:05:54    train
# 170     2015-12-23 20:14:39    train
# 171     2015-12-23 23:25:57    train
# 172     2015-12-24 00:51:46    train
# 173     2015-12-24 01:01:46    train
# 174     2015-12-24 01:36:56    train
# 175     2015-12-24 01:42:55    train
# 176     2015-12-24 02:26:27    train
# 177     2015-12-24 02:27:32    train
# 178     2015-12-24 02:38:56    train
# 179     2015-12-24 12:10:19    train
# 180     2015-12-25 10:56:39    train
# 181     2015-12-25 11:12:30    train
# 182     2015-12-25 11:40:08    train
# 183     2015-12-27 02:39:09    train
# 184     2015-12-28 01:01:32    train
# 185     2015-12-28 17:19:08    train
# 186     2015-12-28 18:48:17    train
# 187     2015-12-28 21:03:04    train
# 188     2015-12-28 21:38:34    train
# 189     2015-12-28 23:24:38    train
# 190     2015-12-29 13:59:10    train
# 191     2015-12-29 18:13:12    train
# 192     2015-12-29 20:21:03    train
# 193     2015-12-29 23:44:33    train
# 194     2015-12-30 21:10:25    train
# 195     2015-12-30 22:37:41    train
# 196     2015-12-31 19:07:40    train
# 197     2016-01-02 20:19:43    train
# 198     2016-01-04 01:46:40    train
# 199     2016-01-05 00:16:42    train
# 200     2016-01-05 00:24:52    train
# 201     2016-01-05 00:26:04    train
# 202     2016-01-05 00:27:14    train
# 203     2016-01-05 00:30:52    train
# 204     2016-01-05 00:53:20    train
# 205     2016-01-05 17:47:09    train
# 206     2016-01-05 23:59:07    train
# 207     2016-01-06 17:25:51    train
# 208     2016-01-06 17:40:47    train
# 209     2016-01-06 18:10:30    train
# 210     2016-01-06 21:44:44    train
# 211     2016-01-07 06:43:59    train
# 212     2016-01-07 19:29:25    train
# 213     2016-01-07 22:07:19    train
# 214     2016-01-08 00:16:19    train
# 215     2016-01-08 09:39:47    train
# 216     2016-01-09 12:08:26    train
# 217     2016-01-09 20:05:08    train
# 218     2016-01-10 01:12:14    train
# 219     2016-01-10 05:02:37    train
# 220     2016-01-12 14:22:26    train
# 221     2016-01-12 14:23:38    train
# 222     2016-01-12 19:03:29    train
# 223     2016-01-12 19:36:54    train
# 224     2016-01-13 23:27:42    train
# 225     2016-01-14 02:28:37    train
# 226     2016-01-15 08:25:40    train
# 227     2016-01-16 10:46:05    train
# 228     2016-01-16 10:53:42    train
# 229     2016-01-20 19:42:25    train
# 230     2016-01-20 22:42:48    train
# 231     2016-01-21 19:22:42    train
# 232     2016-01-21 19:28:30    train
# 233     2016-01-22 07:54:42    train
# 234     2016-01-22 10:02:06    train
# 235     2016-01-22 14:20:35    train
# 236     2016-01-22 20:46:05    train
# 237     2016-01-23 01:38:36    train
# 238     2016-01-23 02:47:45    train
# 239     2016-01-23 03:07:05    train
# 240     2016-01-23 03:09:22    train
# 241     2016-01-23 03:12:46    train
# 242     2016-01-23 03:14:13    train
# 243     2016-01-23 11:53:37    train
# 244     2016-01-25 19:18:27    train
# 245     2016-01-25 19:33:46    train
# 246     2016-01-25 21:29:39    train
# 247     2016-01-27 11:04:31    train
# 248     2016-01-27 16:15:52    train
# 249     2016-01-27 22:56:49    train
# ...                     ...      ...
# 378330  2018-09-11 16:37:56     test
# 378331  2018-09-11 16:38:59     test
# 378332  2018-09-11 16:39:17     test
# 378333  2018-09-11 16:39:47     test
# 378334  2018-09-11 16:41:21     test
# 378335  2018-09-11 16:42:09     test
# 378336  2018-09-11 16:43:02     test
# 378337  2018-09-11 16:43:31     test
# 378338  2018-09-11 16:45:12     test
# 378339  2018-09-11 16:45:14     test
# 378340  2018-09-11 16:45:14     test
# 378341  2018-09-11 16:45:15     test
# 378342  2018-09-11 16:45:15     test
# 378343  2018-09-11 16:45:16     test
# 378344  2018-09-11 16:45:18     test
# 378345  2018-09-11 16:45:19     test
# 378346  2018-09-11 16:45:22     test
# 378347  2018-09-11 16:48:11     test
# 378348  2018-09-11 16:48:43     test
# 378349  2018-09-11 16:49:14     test
# 378350  2018-09-11 16:49:33     test
# 378351  2018-09-11 16:50:07     test
# 378352  2018-09-11 16:50:10     test
# 378353  2018-09-11 16:51:07     test
# 378354  2018-09-11 16:51:14     test
# 378355  2018-09-11 16:52:50     test
# 378356  2018-09-11 16:53:13     test
# 378357  2018-09-11 16:53:36     test
# 378358  2018-09-11 16:56:32     test
# 378359  2018-09-11 16:56:33     test
# 378360  2018-09-11 16:57:10     test
# 378361  2018-09-11 16:57:26     test
# 378362  2018-09-11 16:57:29     test
# 378363  2018-09-11 16:57:29     test
# 378364  2018-09-11 16:57:29     test
# 378365  2018-09-11 16:57:31     test
# 378366  2018-09-11 16:57:32     test
# 378367  2018-09-11 17:00:51     test
# 378368  2018-09-11 17:01:15     test
# 378369  2018-09-11 17:02:06     test
# 378370  2018-09-11 17:04:50     test
# 378371  2018-09-11 17:05:37     test
# 378372  2018-09-11 17:15:50     test
# 378373  2018-09-11 17:15:53     test
# 378374  2018-09-11 17:16:05     test
# 378375  2018-09-11 17:17:04     test
# 378376  2018-09-11 17:18:36     test
# 378377  2018-09-11 17:18:41     test
# 378378  2018-09-11 17:18:46     test
# 378379  2018-09-11 17:18:46     test
# 378380  2018-09-11 17:22:23     test
# 378381  2018-09-11 17:23:16     test
# 378382  2018-09-11 17:26:44     test
# 378383  2018-09-11 17:27:23     test
# 378384  2018-09-11 17:28:41     test
# 378385  2018-09-11 17:29:31     test
# 378386  2018-09-11 17:30:59     test
# 378387  2018-09-11 17:31:38     test
# 378388  2018-09-11 17:33:15     test
# 378389  2018-09-11 17:37:55     test
# 378390  2018-09-11 17:38:04     test
# 378391  2018-09-11 17:39:47     test
# 378392  2018-09-11 17:40:08     test
# 378393  2018-09-11 17:43:14     test
# 378394  2018-09-11 17:44:16     test
# 378395  2018-09-11 17:44:59     test
# 378396  2018-09-11 17:45:41     test
# 378397  2018-09-11 17:48:03     test
# 378398  2018-09-11 17:50:45     test
# 378399  2018-09-11 17:54:13     test
# 378400  2018-09-11 17:54:44     test
# 378401  2018-09-11 18:00:32     test
# 378402  2018-09-11 18:01:28     test
# 378403  2018-09-11 18:01:56     test
# 378404  2018-09-11 18:03:14     test
# 378405  2018-09-11 18:06:42     test
# 378406  2018-09-11 18:08:35     test
# 378407  2018-09-11 18:11:03     test
# 378408  2018-09-11 18:11:18     test
# 378409  2018-09-11 18:12:02     test
# 378410  2018-09-11 18:16:43     test
# 378411  2018-09-11 18:16:49     test
# 378412  2018-09-11 18:16:57     test
# 378413  2018-09-11 18:18:53     test
# 378414  2018-09-11 18:18:58     test
# 378415  2018-09-11 18:20:17     test
# 378416  2018-09-11 18:20:45     test
# 378417  2018-09-11 18:20:46     test
# 378418  2018-09-11 18:20:46     test
# 378419  2018-09-11 18:20:52     test
# 378420  2018-09-11 18:24:59     test
# 378421  2018-09-11 18:32:33     test
# 378422  2018-09-11 18:32:35     test
# 378423  2018-09-11 18:33:51     test
# 378424  2018-09-11 18:37:12     test
# 378425  2018-09-11 18:39:25     test
# 378426  2018-09-11 18:39:25     test
# 378427  2018-09-11 18:40:00     test
# 378428  2018-09-11 18:40:41     test
# 378429  2018-09-11 18:40:51     test
# 378430  2018-09-11 18:45:15     test
# 378431  2018-09-11 18:45:48     test
# 378432  2018-09-11 18:46:19     test
# 378433  2018-09-11 18:47:36     test
# 378434  2018-09-11 18:47:42     test
# 378435  2018-09-11 18:49:21     test
# 378436  2018-09-11 18:50:01     test
# 378437  2018-09-11 18:50:43     test
# 378438  2018-09-11 18:56:41     test
# 378439  2018-09-11 19:04:44     test
# 378440  2018-09-11 19:05:48     test
# 378441  2018-09-11 19:08:50     test
# 378442  2018-09-11 19:10:55     test
# 378443  2018-09-11 19:11:59     test
# 378444  2018-09-11 19:12:56     test
# 378445  2018-09-11 19:13:47     test
# 378446  2018-09-11 19:14:03     test
# 378447  2018-09-11 19:14:10     test
# 378448  2018-09-11 19:18:06     test
# 378449  2018-09-11 19:20:53     test
# 378450  2018-09-11 19:27:27     test
# 378451  2018-09-11 19:28:20     test
# 378452  2018-09-11 19:29:01     test
# 378453  2018-09-11 19:31:14     test
# 378454  2018-09-11 19:34:15     test
# 378455  2018-09-11 19:37:37     test
# 378456  2018-09-11 19:38:32     test
# 378457  2018-09-11 19:40:00     test
# 378458  2018-09-11 19:40:12     test
# 378459  2018-09-11 19:41:39     test
# 378460  2018-09-11 19:41:54     test
# 378461  2018-09-11 19:42:40     test
# 378462  2018-09-11 19:42:48     test
# 378463  2018-09-11 19:44:14     test
# 378464  2018-09-11 19:47:14     test
# 378465  2018-09-11 19:50:16     test
# 378466  2018-09-11 19:50:23     test
# 378467  2018-09-11 19:50:34     test
# 378468  2018-09-11 19:51:13     test
# 378469  2018-09-11 19:52:08     test
# 378470  2018-09-11 19:52:10     test
# 378471  2018-09-11 19:52:10     test
# 378472  2018-09-11 19:52:26     test
# 378473  2018-09-11 19:56:53     test
# 378474  2018-09-11 19:57:36     test
# 378475  2018-09-11 19:59:39     test
# 378476  2018-09-11 20:02:49     test
# 378477  2018-09-11 20:04:58     test
# 378478  2018-09-11 20:06:27     test
# 378479  2018-09-11 20:09:12     test
# 378480  2018-09-11 20:09:34     test
# 378481  2018-09-11 20:10:39     test
# 378482  2018-09-11 20:11:30     test
# 378483  2018-09-11 20:12:16     test
# 378484  2018-09-11 20:12:25     test
# 378485  2018-09-11 20:14:19     test
# 378486  2018-09-11 20:18:57     test
# 378487  2018-09-11 20:19:05     test
# 378488  2018-09-11 20:19:17     test
# 378489  2018-09-11 20:19:31     test
# 378490  2018-09-11 20:19:35     test
# 378491  2018-09-11 20:19:53     test
# 378492  2018-09-11 20:22:02     test
# 378493  2018-09-11 20:22:56     test
# 378494  2018-09-11 20:26:18     test
# 378495  2018-09-11 20:26:20     test
# 378496  2018-09-11 20:27:07     test
# 378497  2018-09-11 20:28:11     test
# 378498  2018-09-11 20:30:37     test
# 378499  2018-09-11 20:31:45     test
# 378500  2018-09-11 20:32:24     test
# 378501  2018-09-11 20:32:46     test
# 378502  2018-09-11 20:33:14     test
# 378503  2018-09-11 20:35:10     test
# 378504  2018-09-11 20:35:37     test
# 378505  2018-09-11 20:35:43     test
# 378506  2018-09-11 20:36:24     test
# 378507  2018-09-11 20:37:04     test
# 378508  2018-09-11 20:38:11     test
# 378509  2018-09-11 20:39:03     test
# 378510  2018-09-11 20:39:23     test
# 378511  2018-09-11 20:39:59     test
# 378512  2018-09-11 20:46:10     test
# 378513  2018-09-11 20:49:51     test
# 378514  2018-09-11 20:51:27     test
# 378515  2018-09-11 20:52:51     test
# 378516  2018-09-11 20:53:28     test
# 378517  2018-09-11 20:53:47     test
# 378518  2018-09-11 20:56:03     test
# 378519  2018-09-11 20:59:17     test
# 378520  2018-09-11 21:08:21     test
# 378521  2018-09-11 21:13:06     test
# 378522  2018-09-11 21:13:07     test
# 378523  2018-09-11 21:16:41     test
# 378524  2018-09-11 21:18:00     test
# 378525  2018-09-11 21:18:41     test
# 378526  2018-09-11 21:19:42     test
# 378527  2018-09-11 21:21:41     test
# 378528  2018-09-11 21:21:44     test
# 378529  2018-09-11 21:21:59     test
# 378530  2018-09-11 21:22:38     test
# 378531  2018-09-11 21:24:52     test
# 378532  2018-09-11 21:25:29     test
# 378533  2018-09-11 21:30:26     test
# 378534  2018-09-11 21:30:46     test
# 378535  2018-09-11 21:30:59     test
# 378536  2018-09-11 21:31:20     test
# 378537  2018-09-11 21:32:27     test
# 378538  2018-09-11 21:33:58     test
# 378539  2018-09-11 21:35:12     test
# 378540  2018-09-11 21:39:29     test
# 378541  2018-09-11 21:40:17     test
# 378542  2018-09-11 21:51:35     test
# 378543  2018-09-11 21:52:19     test
# 378544  2018-09-11 21:57:10     test
# 378545  2018-09-11 22:00:22     test
# 378546  2018-09-11 22:02:10     test
# 378547  2018-09-11 22:05:55     test
# 378548  2018-09-11 22:06:44     test
# 378549  2018-09-11 22:09:25     test
# 378550  2018-09-11 22:11:20     test
# 378551  2018-09-11 22:11:30     test
# 378552  2018-09-11 22:11:50     test
# 378553  2018-09-11 22:17:04     test
# 378554  2018-09-11 22:17:13     test
# 378555  2018-09-11 22:20:03     test
# 378556  2018-09-11 22:20:30     test
# 378557  2018-09-11 22:24:33     test
# 378558  2018-09-11 22:37:15     test
# 378559  2018-09-11 22:38:04     test
# 378560  2018-09-11 22:41:42     test
# 378561  2018-09-11 22:43:40     test
# 378562  2018-09-11 22:44:25     test
# 378563  2018-09-11 22:45:52     test
# 378564  2018-09-11 22:47:51     test
# 378565  2018-09-11 22:48:02     test
# 378566  2018-09-11 22:48:11     test
# 378567  2018-09-11 22:55:36     test
# 378568  2018-09-11 22:55:40     test
# 378569  2018-09-11 22:55:41     test
# 378570  2018-09-11 22:55:44     test
# 378571  2018-09-11 23:00:26     test
# 378572  2018-09-11 23:00:35     test
# 378573  2018-09-11 23:00:47     test
# 378574  2018-09-11 23:12:34     test
# 378575  2018-09-11 23:28:08     test
# 378576  2018-09-11 23:39:01     test
# 378577  2018-09-11 23:40:13     test
# 378578  2018-09-11 23:47:16     test
# 378579  2018-09-11 23:48:51     test
#
# [378580 rows x 12 columns]

# %%
attr = ' Brand'
for ix, row in df.head().iterrows():
    title = row['title'] # str
    #tagging_dict = ast.literal_eval(row['mobile']) # dict 
    tagging_dict = ast.literal_eval(row[9]) 
    print ('tagging_dict',tagging_dict)
    #--------------
    # preprocessing for tagging filed in raw shaopee data
    #--------------
    try:
        if tagging_dict[attr] != 'no value':
            attr_tag = tagging_dict[attr][0][0] # str
        else:
            attr_tag = tagging_dict[attr] # str
    except:
        try:
            attr1 = 'Brand'
            if tagging_dict[attr1] != 'no value':
                attr_tag = tagging_dict[attr1][0][0] # str
            else:
                attr_tag = tagging_dict[attr1] # str
        except:
            attr2 = ' brand'
            if tagging_dict[attr2] != 'no value':
                attr_tag = tagging_dict[attr2][0][0] # str
            else:
                attr_tag = tagging_dict[attr2] # str
# Out:
# tagging_dict {' Dress Length': 'no value', ' Collar Type': 'no value', ' Pattern': 'no value', ' Brand': 'no value', 'Dress Type': 'no value', ' Sleeves': 'no value', ' Clothing Material': [('Chiffon', '6')], ' Color Family': [('green', '1')], ' Fashion Trend': 'no value'}
# tagging_dict {' Dress Length': 'no value', ' Collar Type': 'no value', ' Pattern': [('Brocade', '1')], ' Brand': 'no value', 'Dress Type': 'no value', ' Sleeves': 'no value', ' Clothing Material': 'no value', ' Color Family': 'no value', ' Fashion Trend': 'no value'}
# tagging_dict {' Dress Length': 'no value', ' Collar Type': 'no value', ' Pattern': [('Floral', '1')], ' Brand': 'no value', 'Dress Type': 'no value', ' Sleeves': 'no value', ' Clothing Material': 'no value', ' Color Family': [('Floral', '1'), ('Blue', '1')], ' Fashion Trend': 'no value'}
# tagging_dict {' Dress Length': 'no value', ' Collar Type': 'no value', ' Pattern': 'no value', ' Brand': 'no value', 'Dress Type': 'no value', ' Sleeves': 'no value', ' Clothing Material': 'no value', ' Color Family': [('White', '1')], ' Fashion Trend': 'no value'}
# tagging_dict {' Dress Length': [('Maxi', '5')], ' Collar Type': 'no value', ' Pattern': 'no value', ' Brand': 'no value', 'Dress Type': [('Maxi Dress', '5')], ' Sleeves': 'no value', ' Clothing Material': 'no value', ' Color Family': 'no value', ' Fashion Trend': 'no value'}

# %%
attr_tag
# Out:
# 'no value'
