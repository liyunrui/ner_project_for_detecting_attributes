# %%
import pandas as pd

# %%
df = pd.read_csv('../data/processed/mobile_training_w_word_id.csv')
features = pd.read_hdf('../features/lazada_and_amazon/all_features.h5')
#df2 = pd.read_csv('../data/processed/mobile_training.csv')

# %%
df.head(10)
# Out:
#                                            item_name     tokens  is_brand  \
# 0    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White    Samsung         2
# 1    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White     Galaxy         0
# 2    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White         J1         0
# 3    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White        Ace         0
# 4    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White       2016         0
# 5    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White   SM-J111F         0
# 6    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White        8GB         0
# 7    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White          -         0
# 8    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White      White         0
# 9       Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...  Blackview         2
#
#   is_valid clean_tokens  item_id  word_id
# 0    train      samsung        1     7054
# 1    train       galaxy        1      537
# ...

# %%
accs = []

# %%
accs += [True,False,True] # sentence 1 three words

# %%
accs += [True, True] # sentence 2 two words

# %%
accs
# Out:
# [True, False, True, True, True]

# %%
import numpy as np
acc = np.mean(accs)
acc
# Out:
# 0.8

# %%
#df2.head()
len(df)
# Out:
# 253553

# %%
len(features)
# Out:
# 238668

# %%
features.head(10)
# Out:
#                                            item_name     tokens  label  \
# 0    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White    Samsung      2
# 1    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White     Galaxy      0
# 2    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White         J1      0
# 3    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White        Ace      0
# 4    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White       2016      0
# 5    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White   SM-J111F      0
# 6    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White        8GB      0
# 7    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White          -      0
# 8    Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White      White      0
# 9       Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...  Blackview      2
#
#   is_valid clean_tokens  item_id  word_id  if_tokens_has_numbers_in_the_str  \
# 0    train      samsung        1     7054                                 0
# ...
