# %%
#! /usr/bin/env python3
"""
Created on Oct 2 2018

Prepare data for the following tensorflow model.

Noticed:
    It may take around 13.935157557328543 mins, the real number depends on ur machine.

@author: Ray

TO do list in the future:
    - character embedding
    
"""
import os
import time
import sys
import numpy as np
import pandas as pd
from tqdm import tqdm
import gc
sys.path.append('/home/ld-sgdev/yunrui_li/ner_project/brand_recognition_bio_FE/preprocessing')
sys.path.append('/home/ld-sgdev/yunrui_li/ner_project/brand_recognition_bio_FE/py_model')
from clean_helpers import clean_name_for_word_embedding
from utils import init_logging
sys.path.append('../models/')
from data_utils import get_glove_vocab
from data_utils import write_vocab
from data_utils import load_vocab_and_return_word_to_id_dict
from data_utils import export_glove_vectors
import logging
import gc

def pad_1d(array, max_len, word_padding = True):
    if word_padding == True:
        array = array[:max_len]
        length = len(array)
        padded = array + [9858]*(max_len - len(array)) # padded index of unknown.
    else:
        array = array[:max_len]
        length = len(array)
        padded = array + [0]*(max_len - len(array)) # padded with zero.
    return padded, length

def encode_word_to_idx(word, word_to_id, vocabulary_set, lowercase = True, allow_unknown = True):
    '''encode a word (string) into id'''

    # 1. preprocess word
    if lowercase:
        word = word.lower()
    if word.isdigit():
        word = NUM

    # 2. get id of word
    if word in vocabulary_set:
        return word_to_id[word]
    else:
        if allow_unknown:
            return word_to_id[UNK]
        else:
            raise Exception("Unknow key is not allowed. Check that your vocab (tags?) is correct")

#--------------------
# setting
#--------------------
TRACE_CODE = True # for tracing funtionality and developing quickly
TRUNCATED = False # for reducing memory 
LOWERCASE = True
ALLOW_UNKNOWN = True
dim_word = 300
UNK = "$UNK$" # for the word in our own courpus which is unknown in embedding
NUM = "$NUM$" # for the word which is number

base_dir = "../models/data/wordvec"
filename_words_voc = "../models/data/wordvec/words_vocab.txt"
pre_trained_word_embedding_path = "/data/ID_largewv_300_2.txt"
filename_words_vec = "../models/data/wordvec/word2vec.npz".format(dim_word)
log_dir = 'log/' # log path
init_logging(log_dir)

# %%
df = pd.read_csv('../data/processed/mobile_training_v2.csv')

# %%
df.shape
# Out:
# (2107688, 4)

# %%
df.head()
# Out:
#                                           item_name   tokens  label eval_set
# 0   Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White  Samsung      2     test
# 1   Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White   Galaxy      0     test
# 2   Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White       J1      0     test
# 3   Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White      Ace      0     test
# 4   Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White     2016      0     test

# %%
# preprocessing
df['clean_tokens'] = df.tokens.apply(lambda x: clean_name_for_word_embedding(x) if type(x)==str else x)
if LOWERCASE:
    df['clean_tokens'] = df.clean_tokens.apply(lambda x: x.lower() if type(x)==str else x)
df['clean_tokens'] = df.clean_tokens.astype(str)

# %%
import time
# item_id
item_dict = {}
for i, i_n in enumerate(df.item_name.unique().tolist()):
    item_dict[i_n] = i+1
df['item_id'] = [item_dict[i_n] for i_n in df.item_name.tolist()]

#e = time.time()
#logging.info('it spend {} mins on preprocessing'.format( (e-s) / 60.0))

#-------------------
# word embedding 
#-------------------
s = time.time()
# Build Word vocab (vocabulary set) for our customized task
vocab_glove = get_glove_vocab(pre_trained_word_embedding_path) # word set from pre-trained word_embedding
vocab_words = set(df.clean_tokens.tolist()) # word set from our own whole corpurs including train, dev, and test
vocab_set = vocab_words & vocab_glove # 這裡面的字, 肯定都有相對應的vector, 不是zero vector(The reason we did是可以節省我們使用的embbedding大小, 不用沒用到的pre-trained字也佔memory)
vocab_set.add(UNK)
vocab_set.add(NUM)

# Save vocab
write_vocab(vocab_set, base_dir, filename_words_voc)
# create dictionary mapping word to index
word_to_id_dict = load_vocab_and_return_word_to_id_dict(filename_words_voc)
# save word embedding matrix 
export_glove_vectors(word_to_id_dict, glove_filename = pre_trained_word_embedding_path,
                     output_filename = filename_words_vec, dim = dim_word)
# encode a word (string) into id
df['word_id'] = df.clean_tokens.apply( lambda x: encode_word_to_idx(x, word_to_id_dict, vocab_set, LOWERCASE, ALLOW_UNKNOWN))

#e = time.time()
#logging.info('it spend {} mins on word embedding '.format( (e-s) / 60.0))
# Out:
# Building vocab...
# - done. 6629250 tokens
# Writing vocab...
# - done. 27621 tokens

# %%
df.eval_set.unique()
# Out:
# array(['test', 'train', 'val'], dtype=object)

# %%
df[df.eval_set == 'train'].item_name.nunique()
# Out:
# 200428

# %%
val_item_name = set(pd.Series(df[df.eval_set == 'train'].item_name.unique()).sample(frac = 0.1).unique())
val_item_name
# Out:
# {'hp1701-xiaomi redmi 4x pro prime 4gb ram 64gb rom 4 x mobile phone snapdragon 435 octa core',
#  'nokia 105 dual sim 2017 resmi',
#  'huawei p10 ram 4gb rom 64gb black gold blue',
#  'sony xperia z4z3',
#  'housing tab apple ipad 2 32gb original',
#  'evercoss extream 1 plus',
#  'flanagan 022 mm 9 h kaca melunakkan for xiaomi redmi 4 4x 4a layar pelindung film 5a not',
#  'xiaomi mi max 3 ram 4gb rom 64gb garansi distributor',
#  'promo xiaomi redmi 6a 216 garansi distributor abu tua',
#  'promo conveter jack audio handsfree headset earphone apple iphone 7 limited',
#  'nokia 216 new dualsim dual camera mp3 radio garansi resmi biru muda',
#  'cuci gudang kingkong xiaomi redmi note 4x full layar black tempered glass original',
#  'cuci gudang hdc s7 edge ultra ram 2gb 55 replika supercopy kingcopy',
#  'xiaomi redmi note 5 pro 4gb 64gb black garansi distributor 1 tahun gold',
#  'vivo v9 ram 4gb64gb smartphone black',
#  'kaca lcd samsung n910 galany note 4 original king',
#  'xiaomie redmi 5a gray',
#  'blackberry z30 16gb ram 2gb 8mp original 100 garansi 1tahun',
#  'samsung j1 ace 2016 j111 garansi resmi free bonus',
#  'big sale xiaomi mi 6x a2 128gb ram 6gb original new bnib',
#  'sale fashion luxury view window case for asus zenfone c zc451cg capa para soft back cover pu leathe',
#  'vivo y53c',
#  'vivo v9 new grs resmi terlaris',
#  'xiaomi redmi note 3 ram 216 gb 4g lte original garansi distributor 1 tahun',
#  'promo oppo f9 twilight blue ram 4gb internal 64gb',
#  'handphonehp vivo v5s ram 464',
#  'ulefone power 3s 6 64gb android sensor fingerprint smartphone',
#  'xiao mi mi5 ram 3gb 32gb dual sim 4g lte kamera 16mp sensor sony imx298 cpu qualcomm snapdragon',
#  'zenfone 3 deluxe zs570kl 64gb ram 6gb garansi tam new bnib',
#  'asus zenfone 4 sefie pro zd552kl 464gb garansi resmi tam',
#  'hp samsung a6',
#  'stok baru xiaomi redmi note 5 pro 4gb64gb black garansi distributor 1 tahun emas',
#  'samsung galaxy s8 black 64gb 4gb garansi resmi',
#  'huawei honor 10 128gb ram 4gb ai camera new bnib ori',
#  'vivo v9 pro ram 6gb rom 64gb 664gb',
#  'sony xperia z5 3 32gb original fullset murah',
#  'xiaomi mi 4i 2gb ram 16gb josgandos',
#  'murah advan vandroid s40 ram 1gb u002f 8gb garansi resmi',
#  'samsung j7 2016 garansi resmi indonesia',
#  'terlaris minggu ini universal armband sport case size l max 5 inch example samsung j5 dll',
#  'sony xperia xa1 plus 32gb dual new segel original z1127',
#  'xiaomi mi 4c ss mi4c lcd fullset touchscreen original 11',
#  'hot xiaomi redmi note 5 pro ram 4 u002f64 gb garansi distributor emas diskon',
#  'terbaik samsung galaxy tab s3 97 2017',
#  'big sale buy2 get1 cpo greenpeel iphone x 64gb garansi apple 1 tahun hp murah',
#  'cuci gudang advan i5c duo garansi resmi biru',
#  'cuci gudang oppo a57 ram 332gb grs resmi',
#  'power bank perisai captain america 2 port 6800mah red',
#  'hp mito 105 dual sim terlaris',
#  'asus zenfone 4 selfie pro zd552 55 464gb grs resmi',
#  'xiaomi redmi note 4 pro ram internal 64 garansi tam',
#  'cuci gudang vivo v9 resmi original full display layar perfect view emas',
#  'restock huawei honor 9 6gb ram 64gb rom',
#  'dijual new xiaomi redmi 6a ram 2gb 16gb 2 16 garansi distributor 1 tahun emas murah',
#  'tempred glass pro plus for oppo f5',
#  'samsung galaxy j7 duo baru garansi resmi sein',
#  'harga promo handphone nokia c1 01 hp jadul',
#  '01 lcd touchcreen oppo f1s a59 ori',
#  'xiaomi 5 plus ram 464gb 100 original',
#  'baru polytron zap 6 4g500',
#  'termurah hf akg fast charging originan copotan samsung s8 8 note8',
#  'silikon case asus zenfone 2 laser 5 ze500kl murah grosir',
#  'promo xiaomi redmi 1s 3g rom 8gb termurah',
#  'wa083110979993 produk terbaru xiaomi redmi 5 plus ram 4 64 gb rom garansi resmi hp red mi note',
#  'nokia rekondisi 11101112 layar hitam',
#  'xiaomi mi 5x gold ram 4gb internal 64gb garansi distributor 1 tahun',
#  'promo xiaomi mi a1 tam ram 464gb mia1 android one garansi resmi 1446',
#  'hp samsung j2 pro 2018 4g lte galaxy 18 grs resmi',
#  'asus zenfone go zb500kg 5inch 3g 1gb8gb',
#  'blackview bv9000 pro 6 128gb original ip68 waterproof',
#  'cuci gudang asus zenfone 4 max pro edition zc554kl garansi resmi free bonus hitam',
#  'blaupunkt soundphone s2 4g ram 2 gb internal 16 batre 4000mah',
#  'backdoor lenovo a7000 back cover tutup belakang hk995 bl45',
#  'cuci gudang xiaomi redmi note 5a 464 grey abu tua',
#  'hp spigen tough armor tech samsung galaxy a3 2017 metal series rugged',
#  'lcd nokia n73',
#  'new apple iphone 6 gold 16gb gsm garansi distributor 1 tahun emas',
#  'best product xiaomi redmi note 5a garansi resmi tam 2gb u002f16gb gold n black grey bnib emas',
#  'oppo a3s 4g smartphone 3gb 32gb garansi resmi',
#  'murah samsung galaxy j3 2016',
#  'ic power xiaomi mi5 pmi8994 chip mi 5',
#  'hot product sale xiomi redmi note 2 xiaomi motomo tutup belakang hp',
#  'big sale samsung galaxy j2 pro garansi resmi sein hp murah orginal',
#  'hot ada bonus samsung galaxy j7 pro 2017 garansi resmi sein 1769',
#  'new samsung galaxy j7 core j 701 model',
#  'terbaru autofocus shining chrome samsung j7 pro',
#  'casing hp oppo r11s 3 in 1 protection case black hitam',
#  'simtray sony xperia t3',
#  'produk baru samsung arik levy strap gear s3 original hot',
#  'vivo y71 rom 216',
#  'slim fit zenfone live 5 0 inchi asus zb501kl softshell carbon',
#  'diskon samsung galaxy j6 2018 ram 3 u002f32gb garansi resmi sein hitam hot',
#  'gold xiaomi mi max 2 memory 64gb ram 4gb mimax',
#  'baterai cross a330 nexian m7200 mito a5s wg 003 a700 a150 galaxy s2 e99',
#  'advan s4z ram 1gb internal 8gb garansi resmi 1tahun',
#  'diskon huawei mate 10 pro 128gb ram 6gb new bnib 100 ori promo',
#  'luna g8 64gb black resmi',
#  'hot promo samsung galaxy j7 prime g610 white gold bnib grs resmi sein',
#  'polytron c203',
#  'stok terbatas charger samsung galaxy note 4 s6 original fast charging',
#  'promo evercoss u60 4g lte ram 1gb fingerprint 57 inch a3253',
#  'flexible fleksibel board main mesin oppo a39 a57 neo 11',
#  'ready stock original xiaomi mi a2 6128gb garansi 1 tahun distibutor hpmurah',
#  'asus zenfone max m1 zb555kl ram 3gb rom 32gb garansi resmi 1 tahun',
#  'promo bazaar jual vivo v7 plus internal 64 gb garansi resmi black berkualitas hpmurah bergeransi',
#  'casing nokia fullset 6510',
#  'stok baru hp ter murah handphone meriah 4g android bahan stainless',
#  'produk terbaru samsung galaxy a5 2017 black garansi resmi 1 tahun gratis ongkir',
#  'frame dudukan lcd tulang tengah xiaomi redmi 5a original',
#  'terlaris minggu ini tempered glass smartfren andromax a2 u002fanti gores kaca u002fscreen protector',
#  'kesing nokia 215',
#  'samsung microsdhc evo class 10 uhs-1 95mbs 32gb with sd adapter mb-mp32gb',
#  'polytron c 201',
#  'asus zenfone 5q 464 zc600kl garansi resmi',
#  'big sale murah oppo a83 2 u002f16 spesial red garansi indo merah hpmurah',
#  'shopee day sony xperia z1 docomo mulus bergaransi original 1000',
#  'blackberry aurora android ram 4gb rom 32gb',
#  'nokia jadul murah 216 hp mobile phone dua sim baru hpnokia handphone cheap kamera',
#  'samsung j1 mini 2016',
#  'promo asus zenfone 2 ze551ml ram 4 internal 64g garansi distributor perak murah',
#  'soft case sony xperia c5 glossy',
#  'ready stock oppo f5 smartphone 20mp ai beauty 4gb32gb cicil tanpa kartu kredit garansi resmi',
#  'hp advan i5c lite 4g dual camera with fingerprint ram 1gbrom 8gb',
#  'luxury dompet gaya balik kasus cover untuk samsung prime j2 j1 j5 j7 ace 2017 berdiri',
#  'lcd advan advance tab tablet t1g plus',
#  'semi hardcase xiaomi mi a1 redmi note 5 pro',
#  'oppo f5 second fullset mulus',
#  'new hp handphone lipat warna warni unik mirip samsung citrus 3520 murah',
#  'big sale september samsung galaxy note 8 single 64gb ram 6gb second mulus original',
#  'xiomi redmi note 3 pro 2 u002f16gb gold',
#  'samsung galaxy j2 pro 2018 garansi resmi sein',
#  'spigen iron transformer samsung j510 j5 2016',
#  'big promo cucigudang ori yes vivo v11 beli 2 gratis 1',
#  'promo new xiaomi redmi note 5a prime ram 3gb internal 32gb grs dist 1 thn merah muda 5713',
#  'asus zenfone max m1 ram 3gb int 32gb grs resmi',
#  'cuci gudang smartfren andromax prime 4g selfie camera lte segel garansi resmi 1thn sale',
#  'a295 vivo y69',
#  'blackberry classic q20 garansi resmi bnob',
#  'limited lcd touschreen sony xperia c4 e5333 ori',
#  'hot garansi sony sg xperia xz premium 64gb 4gb dual sim perak promo',
#  'diskon xiaomi redmi 4x 3 u002f32 garansi distri snapdragon',
#  'sony xperia xz single 32gb fullset',
#  'ayo shoping promo handphone samsung galaxy j5 pro 2017 4g lte ram 2gb tom 16gb garansi resmi',
#  'sony xperia z1 compact docomo mulus berkualitas',
#  'new vivo v5 ram432 camera 20mp cuci gudang',
#  'promo hot deals buy2 get1 samsung galaxy s6 edge plus 32gb fullset second like new free ongkir',
#  'baterai asus zenfone ss 2 laser 5 ze550kl doubel power vizz',
#  'samsung j1 ace bekas',
#  'lem perekat untuk sony xperia z1 l39h c6902 c6903',
#  'dijual hp mito android murah layar 5 inch blue',
#  'crazy 6in1 alat pembersih kamera vsgo untuk canon nikon sony slr lensa layar lcd',
#  'macam aksesories hard 360 xiaomi redmi 5a full cover thin shoft slim hp',
#  'ringstand model maskot oppo 0311mmoppo 310818',
#  'promo cuci gudang vivo v5s ram 4gb rom 64gb original smartphones garansi resmi inronesia',
#  'polytron prime 7 ram 3gb rom 32gb',
#  'promo bazaar diskon 80 hp samsung galaxy c9 pro sm-c900f 664gb garansi resmi sein 1tahun murah',
#  'perfect flexible flexibel flexsibel lcd huawei t1 701u original menggugah',
#  'xiaomi redmi 5a-tam',
#  'nokia 6 32gb',
#  'blackberry aurora ram 4gb 32gb garansi resmi 1 tahun banyak bonus',
#  'hot deal tempered glass samsung galaxy tab 3 8 inch t310 t311 good quality',
#  'joyo amplifier gitar sound effect super lead ja-03 black',
#  'evercoss n2 garansi resmi',
#  'xiaomi mi 8 128gb 6gb ram original bnib',
#  'mygica pad android tv tuner dvb-t2 terlaris',
#  'advan s7a lcd',
#  'sharp aquos serie mini shv31 4g ram 2gb internal 16gb original',
#  'blackberry q10 garansi 1thn original 100',
#  'new xiaomi mi a1 4 u002f64 android one garansi resmi tam',
#  'free ongkir tombol switch power on off volume nokia lumia 515 520 525 930',
#  'bekas xiaomi 4a prime 232',
#  'terlaris vivo terbaru promo y53 black',
#  'oppo a37 ram 2gb rom 16gb 5 inch',
#  'ready samsung galaxy a6 plus garansi resmi indonesia sein',
#  'diskon ipad mini 2 16gb wifii celluler garansi resmi 1 tahun',
#  'siemens me75 otdor hitam serta cargher',
#  'promo bazaar ready stock bnib iphone 128gb 7 plus garansi apple 1 tahun all colour hpmurah',
#  'xiaomi mi mix 2 ram 8gb rom 128gb white',
#  'redmi 5a warna gold garansi tam',
#  'tablet vandroid active 4g lte 7',
#  'samsung galaxy mega 2 rp 1 5 juta bisa nego',
#  'samsung galaxy note 8 note8 ringke invisible defender full terbaru dan berkualitas',
#  'promo sale hp one plus oneplus 3 a3000 ram 6gb 64gb original 100 termurah',
#  'new promo handphone hp samsung galaxy j2 pro murah',
#  'promo asus zenfone max plus zb570tl m1 464 garansi resmi',
#  'big sale hot promo murah xiaomi mi max rom 3gb 32gb garansi distributor 1 tahun',
#  'oppo f9 ram 464gb garansi resmi indonesia',
#  'asus zenfone 4 max pro zc554kl 3gb 32gb lte 4g garansi tam',
#  'hp advan i6 harga okay',
#  'huawei nova 2 lite blue free bluetooth earphone gift box',
#  'fleksible on off xiaomi mi 4 original',
#  'xiaomi band 2 smartband original mi 40',
#  'asus zenfone 4 max zc520kl',
#  'lg g2 au isai 4g 232gb waterproof edisi mulus',
#  'samsung s6 edge jakarta gojek mulus fullset global 332gb',
#  'huawei y3 2017 grey garansi resmi 1 tahun',
#  'asus zenfone 3 laser zc551kl garansi resmi 1 tahun',
#  'lenovo a 6000 plus',
#  'samsung metal flashdisk usb 30 16gb oem',
#  '99 diskon vivo v5s ram 4gb rom 64gb garansi resmi new original gold dan rosegold promo baru murah',
#  'vivo y28 no minus batangan bukan oppo samsung sony asus xiaomi acer lenovo',
#  'ic power samsung e5 j5 pm8916',
#  'unix back door samsung a510 a5 2016 tutup belakang cover backdoor',
#  'best seller nillkin tempered glass super h pro huawei p20 premium',
#  'color:black ulefone metal android 60 50 inch 4g smartphone',
#  'berkualitas xiaomi redmi 5 3 u002f32gb garansi resmi tam new',
#  'camera xiaomi redmi note 5a small depan premium',
#  'lcd samsung i9500 s4 f5201292vb slot reflika cina',
#  'new best seller xiaomi redmi 5 plus ram 4gb internal 64gb garansi distri 1 tahun emas',
#  'promo xiaomi redmi 6a 216gb garansi distributor 1 tahun original',
#  'hp tablet advan s7c',
#  'new original premium garskin samsung s7 edge batman edition 2018',
#  'new pny duo-link ou1 dual usb flash drive 32gb',
#  'promo agustus xiaomi mi a1 464gb android one garansi resmi tam',
#  'spc l51 blitz 4g fingerprint 5',
#  'ipad mini wifi 64gb',
#  'sale handphone brancode b9900 orange arsy',
#  'samsung s7 edge garansi resmi sein',
#  'hp390-original xiaomi redmi note 4x 4gb ram 64gb rom mobile phone snapdragon 625 octa core',
#  'hp1084-oukitel k6 18:9 smart phone 60 fhd screen 6gb ram 64gb rom mtk6763 octa co',
#  'advan vandroid i4c 4g lte',
#  'advan tab ilite',
#  'jual nokia 6 smartphone black ram 3 grs resmi berkualitas',
#  'vivo y71 ram3',
#  'hot deal car charger vivan 2 usb port 3 1a cc02s mobil samsung xiaomi asus',
#  'dijual housing samsung j7 prime original edisi terakhir',
#  'termurah hp pc 828 versi brandcode b88 hape nokia pisang jadul',
#  'asus zenfone maxpro m1 664',
#  'evercoss m50 star extream 1 pro 50 4glte ram 1gb rom 8gb you tube go unlimited',
#  'psamsung a6 plus garansi resmi sein',
#  'xiaomi s2 tam',
#  'hp vivo y71 ram 332gb resmi 1 tahun black edition',
#  'smartphone polytron t6 r2509 nougot 5inch 4g ram 2gb rom 16gb',
#  'xiaomi redmi note 5 pro ram 3gb rom 32gb',
#  'xiaomi redmi note 5redmi 5 pro ram 464 gb grs distributor',
#  'promo nokia n100 hp jadul murah garansi',
#  'hot samsung s7 flat seken produk baru',
#  'fleksibel xiaomi redmi note 1 4g on off volume',
#  'antenna cable kabel antena samsung s4 i9500',
#  'terlaris oppo a83 2gb u002f16gb gold garansi resmi cicilan 0 produk baru',
#  'oppo a83 ram 2gb rom 16gb 4g lte gold and red garansi resmi new',
#  'oppo a83 ram 2-16',
#  'big promo vivo v9 pro ram 6gb hp murah',
#  'on sale xiaomi redmi 2 prime 2-16 garansi distri 1 tahun berkualitas',
#  'harga khusus hp advan tablet i-tab i7 plus ram 2gb garansi resmi',
#  'xiaomi redmi 4x ram 3 internal 32gb garansi disributor',
#  'samsung s8 plus secone bekas',
#  'gogae brandcode b5 outdoor 3 sim tipis mirip pc9000 b81 28de',
#  'xiaomi redmi note 4 464 black garansi resmi',
#  'best seller oppo f5 u002f garansi resmi indonesia 1th emas',
#  'berkualitas iphone 7 32gb apple 32 gb seken',
#  'vivo condom fruity affair 18 adult',
#  'vivo v7 resmi',
#  'terlaris hp samsung galaxy j2 prime bnib sein 4g lte android baru',
#  'promo samsung galaxy a6 new 3 32 gb infinity display 56 stock terbatas',
#  'advan hammer r3f emas',
#  'advan s4z vandroid termurah',
#  'asus zenfone zoom zx551ml ram 4gb rom 64gb',
#  'crt doraemon oppo a37 a37f neo 9 3d hot',
#  'connector sim konektor slot tray xiaomi mi3 mi 3',
#  'promo samsung galaxy j7 2016 sm j710 4g lte ram 2gb 16gb garansi resmi murah',
#  'promo super men day hp samsung galaxy s8 64gb ram 4gb 100 original new bnib murah',
#  'produk baru xiaomi redmi note 5 note5 tam resmi xiomi xomi 32gb terlaris',
#  'bbig promo oppo f7 ram 4 internal 64gb garansi resmi 1 tahun original',
#  'diskon tempered glass hp samsung a310 a3 2016 anti gores kaca pelindung temp glas temper',
#  'jual lcd ts evercoss a26c full set diskon',
#  '99 super shopping day promo xiaomi redmi 5 plus gold ram 4 internal 64 gb garansi distri 1 th',
#  'cvt cdt hosing housing blackberry q10 list gold fullset original pobubble',
#  'xiaomi mi 3 ram 2gb internal 16gb',
#  'grosir ready stock bnib iphone 256gb x space gray garansi apple 1 tahun handphone terbaru',
#  'hp icherry c225 gold edition ukr mancis gar resmi',
#  'baru xiaomi redmi 2 prime lte ram 216gb garansi distributor 1 th',
#  'samsung galaxy note 9 garansi resmi sein new segel',
#  'sony z5 premium ram 332 batangan mulus',
#  'samsung jadul gt e1195',
#  'vivo y53 garansi resmi limited',
#  'sony experia m5 second',
#  'keren bgt softcase emerald oppo a3s 2018 case back cover',
#  '360 huawei mate 10 pro full mb098 ut09 slim',
#  'terbaru new vivo y53 garansi resmi 1th',
#  'populer samsung j2 prime 3d pig piglet cartoon soft silicone back cover',
#  'hot promo kingkong full super tempered glass samsung galaxy a5 2017',
#  'produk terbaru lenovo vibe k5 plus ram 3 gb garansi resmi gratis ongkir',
#  'samsung galaxy a6 plus smartphone 32gb ram 4gb',
#  'big sale promo akhir bulan bm new asus zenfone max pro m1 zb602kl 332gb garansi resmi tam 1 thn',
#  'samsung galaxy s8 plus 64gb garansi 1 tahun internasional bnib',
#  'vivo v9 pro 664gb garansi resmi indonesia',
#  'xiaomi mi a2 lite ram 464 garansi distributor 1 tahun',
#  'promo xiaomi redmi 5 plus ram 3gb internal 32gb grs resmi tam murah',
#  'vivo v9 free bonus ram 4 gb rom 64 internal garansi resmi 1 tahun hp fifo pipo vi vo fi',
#  'cognos bobo vr box z4 virtual reality 3d glasses free remote ii hitam',
#  'mito 366 flip torch',
#  'promo hp murah sony xperia xa1 g3121 32gb ram 3gb second mulus original big sale 75',
#  'sold apple 3 wi fi 4g 64gb white ipad',
#  'sony xperia l1 16gb ram 2gb new bnib 100 ori',
#  'oppo a3s ram 3gbrom 32gb garansi resmi 1 tahun warna purple dan red',
#  'xiaomi mi 5c mi5c rose gold ram 3 internal 64 gb grs distri 1 th',
#  'nokia lumia 530 dual sim 4gb oranye',
#  'promo murah advan vandroid s6 ram 1-8gb garansi resmi 1 tahun',
#  'diskon casing kesing fullset nokia 2700 classic original china warna hitam',
#  'samsung fullset galaxy s4 i9500 kode seri 1904 dmf4 228',
#  'terbaik samsung galaxy j4 j6 2018 bening list chrome soft case casing slim',
#  'promo hp murah samsung galaxy s8 plus 64gb ram 4gb 100 original new bnib big sale 75',
#  'jual samsung j5 2016 bekas siap pakai',
#  'terbaru apple iphone 6 plus 16gb gold garansi distributor 1 tahun handphone murah',
#  'best seller sony xperia z c6602 c6603 l36h leather flip cover wallet case',
#  'case ipaky hp xiaomi mi note 5a casing protect 360 cover',
#  'dapakan asus zenfone max pro m1 zb602kl 3gb 32gb garansi resmi',
#  'anti gores spy hitam privacy xiaomi mi 3 screen guard protector proscreen 906546',
#  'promo spesial cuci gudangstock asus zenfone max pro m1 3gb 32gb deepsea black garansi resmi',
#  'big sale awal bulan huawei nova 2 lite',
#  'bionase pengobatan sinusitis therapy massage device white',
#  'advan s5e full view 5 android nougat face unlock 4g lte',
#  'baru vivo y83 432 black and red garansi resmi hitam',
#  'apple iphone 6s plus 16gb garansi distributor 1 tahun',
#  'handphone hp htc desire 526g gsm-gsm ram 1gb internal 8gb',
#  'lcd samsung i9500s4 fullset touchscren frame original 100',
#  'xiaomi mi 5x 432gb black',
#  'sony xperia xa global',
#  'sale xiaomi redmi note 5a ram 2 u002f16 gb garansi resmi tam produk baru',
#  'lenovo s5 k520 3g ram 32g rom wajah id lte 57 quot fhd 18:9 ponsel dual 13mp belakang depan',
#  'promo xiaomi mi a2 4gb 64gb cuci gudang 2018',
#  'mofi flip leather ss case for asus zenfone 2 55 originall',
#  'samsung galaxy j5 2016 hitam afs store',
#  'oppo f1s new selfie expert ram 4gb rom 64gb garansi resmi',
#  'lg smartphone g7 thinq 6128gb garansi resmi',
#  'stok terbaru nokia 105 dual sim 2017 garansi resmi 1 tahun putih',
#  'xiaomi redmi 5 rom 32gb black ram 3 gb resmi tam',
#  'new product griffin survivor armored ipad air 2 black free ongkir',
#  'xiaomi redmi note 2 usb charge flexible papan pcb konektor cas plugin',
#  'samsung galaxy j2 prime gold black original segel garansi sein',
#  'samsung galaxy j7 pro pink 4g lte dual sim ram 3gb internal memory 32gb garansi resmi',
#  'samsung b109e sein candybar radio fm garansi resmi',
#  'gratis ongkir lenovo moto e xt1706 bisa dropship promo',
#  'diskon oppo f3 plus black edition',
#  'hp murah oppo a3s resmi 216gb promo bazaar big sale',
#  'terlaris minggu ini case robot oppo f3 a77 hard u002ftransformer u002fhybird u002firon',
#  'nokia tipe rm 1035 terbaik',
#  'xiaomi mi8 6gb 128gb original snapdragon 845 ai mi 8 black',
#  'xiaomi redmi 3x case custom hp',
#  'asus zenfone live l1 za550kl ram 2 internal 16gb garansi resmi',
#  'hot promo lcd nokia 105 asha original ori',
#  'lcd nokia c3 e5 c3-00 e5-00 asha 200 n200 302 n302',
#  'turun harga hp murah say handphone meriah flip lipat unik warna kuning dan emas',
#  'promo sony xperia z3 compact mulus ram 2gb rom 16gb docomojapan bergaransi 8846',
#  'promo xiaomi redmi s2 64gb ram 4gb new bnib 100 ori',
#  'promo cuci gudang xiaomi redmi 5 plus gold ram 4gb internal 64gb black',
#  'gratis ongkir frame list lcd apple ipad 2 3 4 promo murah',
#  'promo oppo f7 ram 4gb garansi resmi',
#  'promo spesial dus box oppo f5 kualitas original fullset big sale bulan ini',
#  'beauty sales tablet android 44 quad-core a33 layar 7 support wifikamerasimplug eu',
#  'xiaomi mi a1 dual back cameras fingerprint identification 55 inch android 71 qualcomm',
#  'lunatik love mei extreme samsung note 3 rectangular black',
#  'vivo y71 ram 2gb 16 gb android oreo 4g lte garansi resmi',
#  'tablet prince pc-11 pc11 layar 7 inch ram 512mb internal 8gb',
#  'advan 4g s50',
#  'promo apple iphone 6s 16gb original bergaransi 1 tahun gold 2133',
#  'promo nokia 105 singel sim murah',
#  'promo honor 9 lite 3gb ram 32gb rom terlaris',
#  'baru xiaomi redmi note 5 ram 4gb internal 64gb garansi resmi tam emas',
#  'hot samsung galaxy j7 pro dijamin garansi resmi sein baru bersegel hitam sale',
#  'hp back door tutup belakang lenovo a6000 tcnn',
#  'samsung galaxy j6 sm-j600 332gb gold',
#  'samsung galaxy j2 prime ori garansi sein',
#  'honor 9 lite ram 3gb garansi resmi surabaya',
#  'promo samsung galaxy j2 prime new absolute black garansi resmi sein hitam a2432',
#  'big sale vivo y83 432gb garansi resmi hpmurah',
#  'promo thr sale sony xperia xa2 ultra 64 gb new original bnib hp murah',
#  'termurah hp nokia c3-00 gsm c3',
#  'sony xperia compact z4 mini docomo',
#  'samsung galaxy tab a 80 sm-p355',
#  'apple iphone 7 rose gold 256gb garansi distributor 1 th',
#  'charger carger hp asus zenfone go 45 inci new 45in 50 inch 55 handphone zenpon ori',
#  'murah blackberry aurora ram 4gb 32gb garansi resmi 1 tahun',
#  'soft flowerring vivo v7 cover diamond bunga plus bling',
#  'big sale bulan september ready stock iphone x 64gb bnib garansi resmi apple 1thn',
#  'edisi cuci gudang hp android xiaomi 6a ram 2gb rom 16gb garansi tam',
#  'oppo a71ram 2gb internal 16gb garansi resmi 1 tahun bisa cicilan tanpa kartu kredit',
#  'nokia n 7070',
#  'jam tangan standard strap mi band 2 miband xiaomi band2 bracklet gelang rubber',
#  'xiaomi redmi note 5 ram 4 rom 64gb garansi resmi ready warna gold',
#  'baru xiaomi mi note 2 ram 4gb internal 64gb garansi distributor 1 tahun hp murah',
#  'advan a8 ram 4gb internal 32gb garansi resmi 1 tahun',
#  'samsung galaxy tab a 7 2016 garansi resmi sein',
#  'apple iphone 6 plus gold 128gb cash or credit free temper glass',
#  'oppo f9 terbaru ready stok ram 4gb rom 64gb twilight blue',
#  'promo besar besaran vivo v9 ram4 black dan red',
#  'promo murah meria vivo v7 4gb32gb garansi resmi hp mrah',
#  'promo thr sale terbaru apple iphone 6 plus 16gb space gray used hp murah',
#  'handphone hp polytron c204 candybar gsm-gsm',
#  'samsung galaxy tab a note 8 2016 p355 216 4g lte grs resmi sein',
#  'lcd touchscren asus zenfone 2 ze500cl 50 inch',
#  'diskon kaca lcd touchscreen xiaomi mi note 2 ori',
#  'evercoss a75b max ram 18gb face unlock garansi resmi',
#  'promo new xiaomi redmi note 4x ram 3gb internal 32gb garansi dist 1 tahun emas by larva',
#  'new brandcode model b1 legenda brand code b 1 miriphone nokia jadul',
#  'kamera mirrorles sony alpha a6000 body only',
#  'pestta promo oppo a3s ram 3gb garansi resmi 1 tahun',
#  '99 super shopping day new xiaomi 5 a prime',
#  'promo apple iphone 6 64gb space gray garansi distributor 1 tahun new',
#  'asus zen 4 selfie zd553kl',
#  'new baterai batre battery samsung galaxy note4 note 4 original 100 sein hitam',
#  'promo best seller samsung galaxy s8 64gb garansi 1 thn bnib original',
#  'oneplus 6 8256gb mirror black',
#  'xiaomi redmi 5a 332gb',
#  'ready iphone 64 gb 8 plus 64gb space gray grey black bnib garansi resmi apple int l 1 thn',
#  'xiaomi mi6x mia2 mi 6x a2 case 360 gkk original hardcase back matte',
#  'laris samsung galaxy s8 64gb dual garansi 1 tahun bantu claim midnight black',
#  'asus zenfone 3s max zc521tl ram 3gb internal 64 gb rose gold berkualitas',
#  'oppo f7 case custom hp',
#  'strap samsung gear s3 classicfrontier terbaru',
#  'evercoss winner tab v at8b ram 1gb rom 8gb garansi resmi',
#  'samsung galaxy a8 2018 resmi sein promo terlaris diskon original',
#  'disc lenovo k6 power 3gb32gb 4g lte gold',
#  'hemat hp handphone mini korek icherry c80 iron murah',
#  'promo bazar buy2 get1 xiaomi mi a1 hp murah',
#  'xiaomi redmi note 4 grey 3gb64gb room global stable official garansi distributor',
#  'sony z3 big',
#  'promo oppo f5 dashing blue smartphone 20mp ai beauty 4gb32gb gold garansi resmi',
#  'nokia 3 android original garansi resmi hitam',
#  'new produk apple iphone 64gb 6s plus space gray garansi distributor 1 tahun barang terjamin',
#  'xioami pocophone f1 664 garansi resmi hitam',
#  'flexibel flexible volume lenovo vibe x s960 original',
#  'asus fonepad note 6 black 32gb ram 2gb new bnib',
#  'promo free ongkir flexible xiaomi redmi note 5 pro board original',
#  'oppo f3 dual selfie camera satu untuk group',
#  'promo shopee loud speaker lagu buzzer xiaomi mi max qr0131',
#  'advan t5c garansi resmi',
#  'lcd samsung g7102 grand 2',
#  'paling laku fleksibel flexible flexibel volume on off asus zenfone go mini 45 zc451tg z005d aw700',
#  'paling murah case cover hardcase standing sling grip for samsung galaxy j6 2018',
#  'oppo a57 fullset',
#  'iphone 7 plus 32gb original apple store garansi internasional free 1 tahun bnib segel dijamin',
#  'hot promo usb battery cover tutup baterai for xiaomi yi international black termurah',
#  'obral cafele amazing fashion case xiaomi mi a1 5x mia1 mi5x original aksesoris hp lucu',
#  'promo barang baru terjangkau asus zenfone max pro m1 zb602kl 4gb 64gb garansi resmi 1 tahun',
#  'earbuds samsung gear iconx barang resmi sein indonesia icon x original',
#  'xiaomi mi 8 128gb6gb',
#  'cuci gudang xiaomi redmi note 5 464 garansi tam',
#  'iphone mobile phone back stickers plus personality p custom creative body inch apple all-i',
#  'dijual prince pc11 tablet android dual sim limited',
#  '99 diskon oppo a3s',
#  'smartfren c',
#  'dijamin keren xiaomi redmi note 5a softcase auto focus casing cover',
#  'simtray simcard slot tempat dudukkan kartu xiaomi redmi note 4',
#  'huawei mediapad t2 70 tablet gold 16gb2gb',
#  'big sale oppo a71 smartphone new resmi hpmurah',
#  'samsung tab s t700 t705 84 bookcover oem super slim light',
#  'vivo y71 3gb32gb garansi resmi',
#  'terlariss huawei nova 3i kirin 710',
#  'xiaomi redmi note 4 note4 not4 not xiomi full 360 hard jo4434 yo78',
#  'evercoss m50 max face unlock 4g lte ram 1gb internal 8gb garansi resmi',
#  'flexible samsung s5330 s5333 spp02',
#  'icherry c207 pisces candybar dual sim card i-cherry',
#  'nokia 3310 hijau fresh',
#  'dijual xiaomi redmi 5a gold new 2gb 16gb global official garansi resmi tam diskon',
#  'berkualitas sony xperia x performance anti air nfc on garansi 1 bulan perak sale',
#  'xiaomi redmi note 5 ram 3gb 32gb 332 gb gold',
#  'new buzzer buzer musik loudspeaker asus zenfone 2 laser 5 incih ze500kl order now',
#  'huawei nova 2i baru murah resmi',
#  'lenovo zuk z2 originalsegel bnib',
#  'limited huawei honor 7x 464gb garansi resmi baru',
#  'original asli xiaomi redmi 5 plus 464 resmi tam',
#  'lcd 1set samsung galaxy j5 2015 j500 j500f j500g original white ie-019',
#  'stokterbaru casing hp nokia e63 kesing',
#  'sony xperia m4 aqua single sim second batangan',
#  'stiker perekat bingkai layar lcd untuk sony xperia m4 aqua e2303 e2353 e2306 levt',
#  'nokia n5 garansi resmi',
#  'mesin xiaomi redmi note 3 pro 216 red blink',
#  'promo xiaomi redmi 6a ram 2gb internal 16gb grs distributor emas qr0786',
#  'meizu m6 216gb 52',
#  'xiaomi mi a2 lite ram 4gb 64gb bnib new ori android one',
#  'nokia 8110 reborn real 4g snapdragon',
#  'promo spesial brand festival hp oppo a39 ram 32gb 4g lte grs resmi 1tahun',
#  'last stok flexible pleksibel on of volume advan s4a s4c s3lite s35f',
#  'super shoping dapatkn diskon sony xperia z5 premium dual garansi resmi indonesia',
#  'berkualitas samsung galaxy note 5 32gb second seken global exinter terlaris',
#  'samsung s6 edge 364gb sein original',
#  'razer phone 64gb ram 8gb smartphone for gamers new bnib ori no cod rekber karena bm',
#  'ipaky 360 full protection samsung a5 2016 of the pakrembo',
#  'samsung j2 prime 15gb 8gb garansi resmi sein silver',
#  'power case 5800mah for samsung s6 edge plus',
#  'xiaomi mia2 lite 64gb ram 4gb baru ori segel',
#  'ready samsung galaxy j7 pro garansi resmi sein hpmurah',
#  'xiaomi mi band 2 colorful replacement strap multi color ch2099 berkualitas',
#  'promo xiaomi redmi 1s 1 8 3g black n white gransi platinum tahun limited',
#  'hardcase imak crystal case 2 generation asus zenfone 4c c',
#  'promo cuci gudang hp oppo f9 ram 4 gb 64 garansi resmi indonesia',
#  'jual hanphone maxtron c19 mirip hp nokia 105',
#  'xiaomi mi mix 2s 664 black ori garansi distri',
#  'promo spesial cuci gudang hp oppo a71 ram 332gb garansi resmi gold&black hitam',
#  'n x200 nokia baru',
#  'samsung j3 pro j320 216gb garansi resmi indonesia 1 tahun',
#  'mito a39 fantasy ram 1 gb',
#  'promo cuci udang samsung galaxy note 9 6gb-128gb garansi resmi 1 tahun',
#  'apple iphone 7 32gb seken original',
#  'lenovo vibe c a2020 second preloved bekas',
#  'huawei p8 lite css cct dragon soft sc01 all the best storeender',
#  'handphone tablet samsung galaxy j7 prime garansi resmi indonesia sein',
#  'promo huawei p10 64gb4gb dual sim garansi hitam 1068',
#  'nokia e90 komunikator symbian',
#  'hp samsung star duos garansi resmi new',
#  'new product wingtips dan earbud untuk samsung gear icon x tahun 2017 reseries putih free ongkir',
#  'baru promo sony xperia e4 dual resmi tam erajaya ex display',
#  'casing soft case belakang motif tulisan untuk vivo y83 v9 y85 y79 y71 y67 y55 y53 y51',
#  'berkualitas apple iphone 5-gold 64 gb gsm-ori garansi platinum 1 tahun new',
#  'promo dus xiaomi redmi 3 pro note original aksesoris handphone model baru murah',
#  'xiaomi redmi 5a prime ram 3gb 32gb 332 gb grey emas',
#  'samsung piton b310 garansi resmi sein biru putih',
#  'asus zenfone max zc550kl new grs resmi',
#  'flexible mito e993sck baru',
#  'xiaomi mi 5 originalsegel bnib',
#  'admin wa 083123410771 infinix hot s3 x573 3gb32gb 4g lte',
#  'aldo s11 4g lte ram 2gb rom 16gb garansi resmi 1 tahun',
#  'hp spc l52 steel 4g lte garansi resmi 1 tahun',
#  'lcd touchscreen oppo f1s original putih',
#  'terlaris minggu ini hard case baby skin lg k10 soft touch matte dove hardcase gea berkualitas',
#  'xiaomi redmi 5 plus ram 4gb rom 64gb blue garansi 1 tahun tam',
#  'xiaomi redmi 5a ram 216gb garansi resmi',
#  'honor 7s 16gb lte',
#  'dijamin bagus xiaomi redmi note 5 pro ram 4 u002f64gb garansi resmi emas',
#  'new release kaca lcd samsung galaxy note 3 n900 n9000 n9002 n9005 original',
#  'xiaomi redmi note 4x 332 gold snapdragon grs 1 tahun',
#  'terlaris baterai asus zenfone 2 laser 55 ze550kl selfie zd551kl ze601kl ori',
#  'produk baru termurah samsung galaxy s9 garansi resmi sein ungu terlaris',
#  'promo sale samsung galaxy a9 pto 2016 4g lte ram 3gb rom 32gb garansi resmi 1tahun murah',
#  'samsung galaxy s9 plus 256gb ram 6gb original new bnib',
#  'apple iphone x 256gb 64gb space grey second original mulus garansi appleinc gojek',
#  'diskon vivo y53 garansi resmi',
#  'promo sale motorola moto g5s plus ram 4gb rom 32gb garansi resmi termurah',
#  'mito 880 garansi resmi indonesia 1 tahun bisa tukar tambah',
#  'ic emmc bga 153 klmbg4geac b001 32gb xiaomi redmi note 2 2nd garansi test box',
#  'super electronoc day oppo a39',
#  'big sale2018 oppo f5 smartphone 20mp ai beauty 4gb32gb cicil tanpa kartu kredit garansi resmi',
#  'fghgf untuk huawei pasangan 10 59 pintar kasus window view cover mate pro 60',
#  'big promo2018 xiaomi redmi 5a 216 garansi resmi tam hargamurah',
#  'back cover nokia 625 lumia 625h 47 inch backdoor tutup batre hp',
#  'discount home button protektor samsung galaxy s5 s65 s7 edge scratch resist promo terbatas',
#  'tempered glass full anti gores kaca asus zenfone 4 max 5 2 inc',
#  'back door sony experia z3 tutup belakang cover xperia',
#  'nokia n70 ori garansi 1bulan',
#  'xiaomi redmi 1s garansi platinum',
#  'promo khusus awal bulan nokia 6 ram 3gb rom 32gb bergaransi resmi',
#  'm-horse c9pro sidik jari ukuran 55 inci 1280 720 hd 1 8gb untuk android',
#  'best seller iphone se 64gb rose gold garansi apple 1 tahun bnib fu',
#  'fujitsu arrows nx-f06e ram 2gb internal 64gb second unit only',
#  'tempred kingkong super glass screen protector slim xiaomi redmi note 4',
#  'harga diskon bundle case asus zenfone 5 5z 2018 ultraslim black matte tg bening',
#  'oppo a37 rose goldblackgold',
#  'lcd samsung s8',
#  'lagi exstra diskon promo nokia 1112 hp jadul murah garansi',
#  'baru smartfren andromax a2 perdana gsm',
#  'big promo samsung galaxy note 9 stock terbatas',
#  'free ongkir promo baru advan s5e 4g murah',
#  'jual samsung galaxy j7 core j701f gold garansi resmi sein 1 tahun terakhir',
#  'hp handphone jadul motorola v3 flip normal bukan v60 v70 v3x v8 v9',
#  'xiaomi redmi note 5 3-32gb blue',
#  'casing nokia 3310 hitam combinasi crome',
#  'laris xiaomi redmi note 5 4 u002f64gb garansi resmi tam emas',
#  'termurah apple ipad pro 105 smart keyboard us english',
#  'advan s40 ram 1gb putih',
#  'vivo y71 smartphone ram 2gb rom 16gb black',
#  'lensa kamera hd 06x wide angle 10x macro untuk iphone samsung',
#  'nokia 6303i classic single sim handphone candybar new refurbished',
#  'diskon gede gedean xiomi note 5a prime hp xiaomi mi 5 a ram 332 gb snapdragon gold',
#  'new samsung galaxy note 9 garansi resmi 1 tahun',
#  'produk baru bnib iphone 7 128gb black garansi apple 1 tahun promo',
#  'dock charger baterai bm42 xiaomi redmi note 1 original desktop only',
#  'cvt sft thin sony experia z5 mini compact pobubble',
#  'xiaomi mi4c ram 2gb internal 16 gb garansi distributor',
#  'produk terbaru samsung galaxy j7 prime whitegold black resmi 1 tahun hitam gratis ongkir',
#  'infinix note 3 pro 3gb 16 gb garansi resmi 1 tahun',
#  'hot sale infinix s pro ram 3gb rom 16gb garansi resmi',
#  'future armor samsung j7 prime on7 2016 soft cover css hp all the best storeender',
#  'big promo oppo find x 8-128gb merah biru wa o82i-9784-2o33',
#  'samsung k zoom s5',
#  'promo bazaar vivo v9 pro 6gb64gb garansi resmi hpmurah',
#  'best produkkk xiaomi redmi note 5a 2 u002f16gb gray garansi resmi tam 1 thn',
#  'restock best priceiphone 7 plus 256gb black bnib garansi 1 tahun apple fu',
#  'xiaomi redmi 5 ram 3 gb internal 32 garansi tam 1 tahun',
#  'advan vandroid g2 3gb-32gb garansi resmi',
#  'tablet advan i7d',
#  'apple iphone 6s 64gb rose gold garansi distributor 1 tahun',
#  'xiaomi redmi 3s ram 2gb internal 16gb garansi distributor 1 tahun',
#  'nokia 5310 gsm fullblack langka jadul express music murah',
#  'promo stiker logo apple iphone 6 s 7 home button sticker keren berkualitas',
#  'diskon gede gedean hp xiaomi redmi note 5a xiomi mi ram 216-gold-rose-grey',
#  'eksklusif smart cover asus fonepad 7 fe171cg promo',
#  'apple iphone 7plus 55 inch 4g lte 12mp camera 4k video recording smartphone',
#  'baru touchsreen touhcren oppo a37 original limited',
#  'polytron c201 dual sim 24 inch candybar camera',
#  'xiaomi mi 6x 464gb rose gold garansi distributor',
#  'murah asus zenfone b go zb452kg 18 cam 5mp new resmi hp termurah',
#  'samsung galaxi note 4 ram 332 4g lte',
#  'tersedia polytron c287 toko kita',
#  'macam aksesories element recon carbon fiber cf samsung galaxy s5 black',
#  'terlaris jam tangan xiaomi huami amazfit pace 2 stratos smart watch inter ver',
#  'promo redmi 3s 4g lte 2 u002f16 gold garansi 1 tahun terlaris',
#  'saleee samsung karamel g-e1272 non kamera ori hitam',
#  'vivo y81 new product',
#  'tempred glass full cover 5d huawei nova 2i',
#  'murah apple imac mk482 5k 2015 27 33ghz 8gb ram bnib garansi 1 tahun promosi',
#  'kabel hippo teleport 120cm micro usb for blackberry asus xiaomi oppo',
#  'camera kamera blackberry dakota 9900 amstrong 9320 davis 9220 original diskon',
#  'samsung a8 baru sein jual cepat',
#  'kartu perdana xl go 4g kuota 90 gb90 hari',
#  'promo samsung j1 ace j111 1gb8gb garansi resmi sein 975',
#  'kabel data samsung tab 2 p1000 usb cable galaxy',
#  'xiaomi redmi note 2 grey ram 2gb16gb garansi distributor 1 tahun',
#  'smartphone huawei nova 2 pic tl00 4g 50 android 70 kirin 659 octa core 236ghz',
#  'bekas sony xperia z1 compact',
#  'promo sale huawei honor 7x 464gb garansi resmi free bonus',
#  'termurah case anti crack asus zenfone 4 maxproanticrack shock break bentur',
#  'ready stock samsung galaxy s8 garansi resmi sein',
#  'cuci gudang sony xperia z3 green 216gb red docomo second 2nd garansi 1 bulan',
#  'xiaomi redmi note 4 364gb garansi distri 1 tahun',
#  'sony xperia xa1 plus 32gb dual sim new segel original',
#  'baru xiaomi redmi note 3 ram 2gb rom 16gb pengiriman cepat',
#  'big hot deals buy2 get1 sharp aquos crystal sh305 4g lte android second mulus 305 sh hp murah',
#  'asus zenfone 2 laser ze500kl 5 inch tombol on off board flex flexi fleksi flexibel 903611',
#  'asus max pro m1 3gb',
#  'evercoss m40 winner t 4 inch4g lteram 1gblolipop',
#  'casing power bank 10400mah kabel usb untuk xiaomi',
#  'sport strap volt samsung galaxy s2 classic gear s3 nike 20mm',
#  'lcd oppo find muse r821 joy r1001 r1011 piano r8113 original',
#  'fleksibel tombol power on off dan volume lenovo a6000',
#  'evercoss c5l',
#  'samsung galaxy s7 edge 2 sim new sein',
#  'xiaomi redmi 5 ram 2gb 16gb new garansi resmi tam',
#  'hp samsung galaxy j1 mini brang masih bagus gan belum pernah di servis',
#  'advan vandroid s40 ram 1gb 8gb hitam garansi resmi',
#  'halo nokia hp murah handphone x series x2-00 nokiax200 refurbished bisa bahasa indonesia',
#  'lem adhesive perekat backdoor sony xperia z5 compact mini',
#  'big sale hp samsung galaxy j2 prime g532 baru segel garansi resmi sein hpmurah',
#  'edisi terbaru tempat headset case earphone biru kekinian',
#  'xiaomi redmi 6 pro 4gb 32gb dual camera ai bnib black',
#  'asus zenfone 3 laser zc551kl nillkin sparkle flipcase cover terlaris',
#  'meizu m5c special edition in red colour ram 2gb internal 16gb 4g garansi resmi bukan distri',
#  'promo samsung galaxy tab a 2016 7 inci t285 8gb garansi resmi murah',
#  'nokia 6 silver android smartphone 332gb garansi resmi 1 tahun',
#  'sony xperia xz1 compact 32gb ram 4gb new 100 ori',
#  'sale samsung galaxy s8 garansi resmi sein 1 tahun produk baru',
#  'xiaomi redmi 5a ram 2gb internal 16gb garansi resmi tam 100 persen original',
#  'asus zenfone 5 lite a502cg on off volume flex',
#  'new ori samsung j6',
#  'dijualan sticker skin glitter samsung j3 2016 terbatas',
#  'samsung galaxy a6 plus 2018 resmi sein',
#  'soft case nillkin sony xperia z5 tpu nature series',
#  'xiaomi mi 6x mia2 mi6x 128gb ram 6gb new bnib',
#  'promo kindle paperwhite e reader black 6 high resolution display 300 ppi murah',
#  'cuci gudang hp polytron c285 non camera',
#  'vivo v5 ram 4gb smartphone kamera 20mp gold',
#  'promo hut toko yng ke 7thn beli 2 gratis 1 oppo f3 plus jual gold second seken mulus',
#  'promo bazaar oppo a3s ram 3 rom 32 garansi resmi hpmurah',
#  'nokia c3-00 qwerty',
#  'big sale new termurah samsung galaxy s7 flat 32gb seken second original berkualitas 100',
#  'samsung galaxy s7 edge dual sim original 32gb seken second',
#  'buzzer xiaomi redmi note 2',
#  'polytron rocket r3 r2407 garansi indonesia putih',
#  'kamera depan small camera oppo neo 5 a31 a31t r1201 original',
#  'blackberry z10 4g lte 2gb16gb garansi distributor 2 tahun',
#  'lcd set oppo f1s limited',
#  'best seller hp murah handphone meriah android 3g layar besar 55inchi mirip samsung galaxy j5',
#  'hp murah oppo f7 4gb-64gb 4g lte red and silver garansi resmi new harga promo',
#  'promo cuci gudang xiaomi redmi s2 332 garansi resmi tam handphone hp murah',
#  'xiaomi mi 6x blue 664gb rom global',
#  'cuci gudang samsung s5 docomo second 32gb mulus',
#  'promo apple iphone 16gb 6s gold garansi distributor 1 tahun',
#  'baterai smartfren andromax m3y m3z original 99 u002fbatre max modem ori',
#  'samsung j3 2016 18gb second like new',
#  'nokia 5 resmi ram 3gb free original crystal case',
#  'evercoss winner y smart u50',
#  'xiaomi redmi note 4x ram 4 gb internal 64 room global stable official mui garansi distributor',
#  'xiaomi mi a2 lite redmi 6 pro android one ram 464 gb',
#  'promo hp baru murah mito 168 mirip nokia 105',
#  'caseology zenfone go b 45 inchi new asus zb452kg hardcase slim carbon',
#  'vivo v9 resmi ram 4 internal 64gb',
#  'big promo oppo f7 smartphone 4gb64gb red garansi resmi free ongkir hpmurah',
#  'termurah samsung z2 black terbatas',
#  'promo xiaomi redmi 5 plus garansi resmi tam 4g lte ram 3gb rom 32gb full hitam a3225',
#  'xiaomi redmi note 5 pro 464gb global garansi bless',
#  'promo xiaomi mi5 64gb ram 3gb mi 5 snapdragon 4g lte putih a3289',
#  'produk terlaris xiaomi redmi 5 plus black ram 3gb internal 32gb garansi resmi tam hitam barang',
#  'advan vandroid i5c lite red free softcase tempered glass 2',
#  'sale stylus pen samsung s n8000 galaxy note 101 original',
#  'free ongkir brandcode b329 rival princemaxtronmito harga murahh',
#  'apple iphone x 64 gb ios new',
#  'baterai xiaomi mi 4s mi4s bm38 bm-38 3210mah original cina',
#  'hp xiaomi redmi 5 ram 2gb rom 16gb garansi tam gold black',
#  'back door asus zenfone 2 laser 5 inch ze550kl cover',
#  'big promo samsung s9 64gb garansi resmi 1 tahun free tumi case original',
#  'diskon oppo f1s plus ram 4 u002f 64gb garansi resmi indonesia sale',
#  'diskon sony xperia z1 compact second batangan produk baru',
#  'murah hp xiaomi redmi note 5 pro ram 4gb dan internal 64gb warna emas biru hitam rose',
#  'oppo f5 pro ram 6',
#  'samsung galaxy note 8 6 u002f256gb ram 6gb 256gb midnight black dual sim',
#  'terbaru back cover oppo r1x r8207 r1c r8201 50 inch backdoor hp tutup ready sktoc',
#  'sony xperia z1 big ram 2gb 32gb second mulus',
#  'wa083110979993 produk terbaru xiaomi mi5 364gb garansi distributor 1 tahun gratis ongkir',
#  'laris xiaomi mi8 mi 8 se ram 6gb internal 64gb ai camera garansi dist 1 th',
#  'sharp m1 ram 3 gb internal 64gb garansi resmi indonesia',
#  'termurah ivvi m1 ram 3gb internal 32gb garansi distributor promo bulan ini',
#  'preloved lg nexus 5 lg-d821 16 gb white',
#  'kredit samsung galaxy note fe 464gb tanpa kartu',
#  'terlaris termurah new ready stock bnib samsung galaxy s8 64gb midnight black garansi 1 tahun terbaik',
#  'samsung galaxy a9 pro sein',
#  'hp oppo a37 ram 216gb internal a37f black limited edition hitam',
#  'xiaomi redmi note 4x gold ram 4gb internal 64gb garansi distributor 1 th',
#  'advan vandroid t2j ram 1gb',
#  'lcd cross evercoss a7r',
#  'oppo a57 second nego',
#  'sony z3 compact d5833 43 inci 4g ram 2gb',
#  'oppo a3s resmi 216gb',
#  'promo super men day diskon 80 iphone 6 32gb garansi resmi apple indonesia tam 1 tahun',
#  'huawei y3 2017 garansi resmi indonesia oppo a37 a71',
#  'hot hp murah handphone meriah maxtron mirip hape nokia kamera 2 kartu',
#  'promo murah 2018 nokia 6 android 32gb ram 3gb',
#  'super promo hp xiaomi note 5a ram 216 gb gold grey rose baru',
#  'grosir samsung galaxy j2 prime garansi resmi sein perak case handphone',
#  'battery baterai batrai baterei hp xiaomi mi4 bm38 bm 38',
#  'xiaomi redmi s2 ram 332gb garansi resmi tam',
#  'baru paling murah hp nokia c5-00 terbatas',
#  'a60415 new asus zenfone max pro m1 zb602kl ram 4gb 64gb garansi resmi',
#  'restock lcd advan advance t1x plus barcelona tab 7inch',
#  'oppo f9 ready',
#  'promo smarphone bm vivo v9 garansi resmi indonesia',
#  'nokia 3310 new 2017 garansi tam indonesia',
#  'x-cam sight 2 portable smartphone gimbal axis bluetooth white',
#  'nokia n86 resmi stok lama',
#  'huawei mate rs porsche design 256gb ram 6gb new bnib ori termurah',
#  'oneplus 6 256gb ram 8gb original bnib',
#  'himax x play ram 4gb rom 64gb front fingerprint',
#  'gadget huawei mate 8 smartphone cnc dual sim 4g core',
#  'dsi sim tray vivo v5 simtray murah',
#  'oppo find mirror r819 white second',
#  'lcd brandcode b11 original',
#  'promo hp murah oppo f5 youth garansi resmi indonesia big sale',
#  'cuci gudang xiaomi redmi note 5 pro ram 4gb rom 64gb new original',
#  'ini t lcd 1set xiaomi redmi note 5 pro 2018 origin black',
#  'samsung galaxy note 3 4g n900s white mulus sekali fullset limited',
#  'handphone hp brandcode b5 mini 3-gsm powerbank 5000 mah',
#  'asus zenfone max plus m1 zb570tl ram 464gb',
#  'big sale samsung galaxy j4 232gb purple garansi resmi sein 1 tahun hp murah orginal',
#  'tb softcase black matte soft case mate tpu samsung a320 a3 2017 murah',
#  'asus zenfone 3 deluxe zs570kl 664gb garansi resmi terlaris',
#  'lcd blackberry bb 8520 007',
#  'restock xiaomi powebank',
#  'chasing termurah robot vivo y55 stand transformer hard cover rubber rugge seri mpv4151',
#  'hp murah xiaomi mi max 3 ram 4gb internal 64gb bnib segel harga promo 100 original',
#  'casing nokia 1110 warna merah',
#  'promo xiaomi redmi 3 pro 332 gb produk baru',
#  'kredit vivo',
#  'xiaomi mi8 se 4gb 64gb',
#  'hp myuser xiaomi 6 mi6 mi 515 inchi softshell colourful new generation clk',
#  'oppo f9 ram 464 garansi resmi 1tahun',
#  'huawei nova 3i 4gb 128gb ai kirin 710 black',
#  'motorola moto m resmi termurah',
#  'samsung galaxy j4 232 gb garansi resmi sein',
#  'promo samsung galaxy s9 internal 64 gb garansi sein resmi original',
#  'meizu m6 216 garansi resmi',
#  'ny hair tpu cover samsung galaxy c5 c7 c9 c9pro pro note3 note4 note5 note 3 4 5',
#  'asus zenfone max pro m1 332gb garansi resmi hitam',
#  'promo samsung galaxy tab a 2016 7 inch 4g lte full hd 1507',
#  'sony xperia zr ram 2 32 gb second batangan murah',
#  'advan vandroid i6',
#  'frame plat middle mid bezel untuk reparasi sony xperia z l36h agda',
#  'selamat berbelanja samsung i9500 menu fleksibel button back tombol s4 original',
#  'advan i7d 4g lte tablet 7 ram 1gb 8gb garansi resmi',
#  'promo murah 2018 samsung galaxy a6 plus 432gb garansi resmi hpmurah',
#  'hoj1033 xiaomi redmi 5 plus ram 464 garansi resmi tam hitam',
#  'promo lenovo hw02 smart band ios android alt hw01 mi 3 iwown i6 hr pro 5088',
#  'best seller xiaomi mi5 anti crackshock case crystal armor not ringke fusion aksesoris tablet dan',
#  'grosir hape flip lipat unik versi samsung citrus gt 3520 hp pc 168 handphone murah',
#  'edisi cuci gudang xiaomi mi mix 2s ram 6gb internal 128gb garansi distributor 1 tahun',
#  'terlaris now kabel out tv samsung p1000p3100 tablet',
#  'hp murah oppo f7 464 selfie expert promo bazaar big sale',
#  '99 promo diskon 80 hp meizu m5 note 332gb garansi resmi 1 tahun murah',
#  'produk terbaru hp asus zenfone max plus zb570tl 464 garansi resmi 1 tahun emas gratis ongkir',
#  'promo cuci gudang hp xiaomi pocophone f1 newww',
#  'diskon samsung galaxy tab s2 80 ex display pameran',
#  'hp oppo a83 ram 2gb rom 16gb full screen 57inci',
#  'big promo2018 oppo a71 2018 edition garansi resmi hpmurah',
#  'nillkin sparkle xiaomi redmi note 4',
#  'promo sony xperia xa2 ultra h4233 64gb ram 4gb new bnib 100 ri 3143',
#  'samsung j8 cicilan tanpa kartu kredit',
#  'casing nokia fullset x2-02 hitam',
#  'sale hp oppo a3s',
#  'samsung galaxy j7 pro garansi resmi 1 tahun',
#  'new infinix zero 5 x603 6 u002f64gb garansi resmi 1 tahun hitam',
#  'backdoor original xiaomi redmi note 3 note3 pro',
#  'promo xiaomi mi 4c 16 gb garansi distributor 1 tahun putih big sale',
#  'advan 14d',
#  'jual xiaomi mi max 2 ram 4 gb rom 64 gold diskon',
#  'termurah hot price ip 6s plus 32gb rosegold garansi apple internasional 1 thn',
#  'tablet imo z8 rock new putih',
#  'grosir xiaomi redmi 3s gold ram 2 u002f16gb garansi 1th',
#  'asus kondisi new dg garansi resmi mulai dari zenfone max selfie 3',
#  'samsung j7 prime resmi sein bnib ram 3gb 32gb whitegold fingerscaner',
#  'blackberry bold 9900 dakota garansi the one 1 tahun',
#  'chasing hp hrp booming neo hybrid ipaky for samsung galaxy a7 original 10 seri mpv1303 4411',
#  'samsung galaxy a6 plus garansi resmi indonesia sein terbaru',
#  'cafele huawei p20 pro plating tpu soft original',
#  'lg q6 plus 464 garansi resmi indonesia ice platinum',
#  'ready vivo y71 332',
#  'hp nokia 3310 new garansi khusus buat telponan pribadi',
#  'big sale xiaomi redmi note 5a prime 332gb new tam hpmurah',
#  'oukitel c5 pro smartphonemtk6737quadcore 5 5mp8mp 2000mah 2gbram16gbrom phone',
#  'minat wa081344790883 hp oppo a3s ram 2gb rom 16 gb garansi resmi indonesia red',
#  'samsung s6 edge plus 32gb single sim mulus lengkapp segel aman msh utuh no minuss',
#  'stok baru oppo f1s ram 332gb garansi resmi indonesia hp murah',
#  'promo handphone nokia xl ram 768mb rom 4gb single sim new original garansi resmi tam 1tahun murah',
#  'murah cht081943675777 hp oppo a83',
#  'xiaomi mi note 3 6128 garansi distributor 1 tahun',
#  'vivo y71 ram 3 32 gb',
#  'chuwi hi10 ultrabook tablet dual os win10 android 4gb 64gb 101 inch',
#  'oppo f1s 64gb',
#  'hp hammer advance r1d',
#  'hp smartfren andromax prime 4g lte ajaib harga ajib',
#  'asus zenfone ze 551ml',
#  'lcd samsung galaxi v g313h ori terbaru',
#  'flexible sony xperia m4 e2303 konektor cas',
#  'xiaomi redmi 6 3gb 32gb rose ready 4g',
#  'big promo samsung galaxy s8 smartphone maple gold 64gbram hp murah',
#  'samsung galaxy a6 2018 blue sein fullset mulus like new',
#  'iphone x 64gb garansi apple 1 tahun',
#  'dijual evercoss m50 4g lte android smartphone handphone hp murah silver berkualitas',
#  'diskon samsung strap gear s3 frontier original size l space grey',
#  'samsung b310 e piston guru musik dual sim',
#  'termurah hp samsung galaxy j2 prime g532 baru segel garansi resmi sein',
#  'diskon hp smartfren andromax prime murah 4g lte bisa whatsapp stok ready hot',
#  'vivo skin mobile legend eudora redeem terlaris',
#  'maxtron c15 new 12 000 mah mirip brandcode b81',
#  'laris xiaomi redmi 5 plus 464gb gold garansi distributor b-cell 1 tahun emas',
#  'soft jacket rubber samsung galaxy j5 2016',
#  'ready stok bnib iphone 256gb 7 plus 7plus gold ori apple 1 tahun gojek',
#  'housing casing samsung lakota c3322',
#  '360 samsung galaxy a5 2016 degree full protection',
#  'samsung galaxy tab a8 2017 garansi resmi free jbl earphone',
#  'samsung galaxy s6 edge 64gb second seken fullset mulus',
#  'xiaomi mi note bambu 3-16',
#  'asus zenfone live l1 ram 2gb internal 16gb garansi resmi',
#  'promo new nokia 105 dual sim garansi resmi tam 1 tahun putih 7083',
#  'baru nokia c3 new c3-00 jadul murah toserba',
#  'terlariss manis samsung galaxy j6 smartphone 32gb u002f 3gb hitam',
#  'smarthpone oppo f3',
#  'promo termurah sony z3 lte new bnib garansi resmi',
#  'asus zenfone max m1 zb555kl smartphone 32 gb',
#  'htc m10 original',
#  'promo lcd advan s50c limited',
#  'sony xperia xa second original mulus bergaransi',
#  'flexible kamera belakang samsung i9082 grand duos termurah',
#  'promo barang bm asus zenfone max pro m1 zb602kl 464 garansi resmi',
#  'produk terbaru ready stock bnib iphone 32gb 7 plus black garansi apple 1 tahun gratis ongkir',
#  'xiaomi mi a2 black 128gb 6gb ram distributor setahun',
#  'chasback new xiaomi redmi note 5 ram 6gb internal 64gb garansi distri 1 thn merah muda terlaris',
#  'xiaomi redmi 2 prime ram internal 16 gb refurbish garansi distri',
#  'xiaomi pocophone f1 ram 6gbroms 128gbgaransi resmi tam',
#  'promo housing casing chasing fullset nokia asha 300',
#  'hp advan i5c lite ram 18gb grs resmi 1 tahun',
#  'cuci gudang xiaomi redmi note 4 pro snapdragon 4gb ram 64gb rom global official hp murah',
#  'hp handphone nokia 720 collector item mulus jadul super rare kolektor masuk museum',
#  'cuci gudang honor 9 lite full view ram 332gb gratis case original biru',
#  'xiaomi note 5 ai ram 3gb rom 32gb tam',
#  'huawei mate 10 64gb ram 4gb new bnib 100 ori',
#  'aksesoris gadget termurah sony xperia xa1 dual sim bnib internasional',
#  'xiaomi redmi 4 a216 garansi tam',
#  'samsung galaxy note 8 64 gb orchid grey',
#  'flexible flexibel power on off sony xperia m2 aqua original',
#  'murah xiaomi mi max 2 4gb u002f 64gb gold emas',
#  'best price ready stock lcd 1set xiaomi redmi 4x ori black white gold',
#  'sunny smart watch bluetooth untuk iphone ios samsung android sim gsm',
#  'big promo oppo f5 youth 332 beli 2 unit gratis 1',
#  'handphone jadul nokia 1112 hp layar putih',
#  'sony xperia xz1 64gb ram 4gb new bnib original',
#  'hp lipat icherry c212handphone harmonyhp flip',
#  'hp xiaomi redmi note5a grey ram 2gb 16gb grs distributor family sahre',
#  'blackberry aurora bbc100-1 32gb silver',
#  'new baterai ori 99 asus zenfone 2 laser 5 batre original battery ny',
#  'jual apple ipad pro 97 ultra slim keyboard',
#  'promo hp android spc l52 steel 4g',
#  'promo smarphone bm blackberry keyone 64gb black',
#  'unik blackview bv6000 ram 3 32gb original ip68 waterproof diskon',
#  'big sale xiaomi redmi 5 plus 4gb64gb bonus tempered glass garansi distributor hp murah orginal',
#  'samsung galaxy k zoom resmi',
#  'garskin custom samsung j5',
#  'ready iphone 256 gb 8 256gb silver white bnib garansi resmi apple international 1 thn',
#  'nokia 3 ram 2gb 16gb 4g lte',
#  'hot hp philips e103 dual sim garansi resmi 1 tahun merah on sale',
#  'polytron c24e candybar dual sim kamera double speaker',
#  'model baru calandiva ring carbon case xiaomi redmi 3 pro prime 3s black tg hitam',
#  'cuci gudang hp nokia 5130 xpressmusic gsm kamera 2megapixel termurah',
#  'lcd blackberry bb 8520 gemini frame ori seri 007',
#  'promo barang baru terjangkau vivo v9 ram 6 black',
#  'iphone 5s 16gb preloved apple jual handphone bekas murah',
#  'big promo samsung galaxy a8 star garansi resmi sein 1tahun hpmurah',
#  'ad708 baterai xiaomi redmi 3 4x 4000mah bm47',
#  'grosir hp xiaomi redmi mi note 4x pro ram 316gb xiomi 4g lte internal 16gb',
#  'jual nokia 3310 new 2017 reborn garansi resmi murah',
#  'hphandphone samsung j1 ace',
#  'big promo xiaomi redmi note 4x 4 pro 332 garansi resmi tam emas',
#  'hp vivo v7',
#  'hp samsung j7 2016 bekas',
#  'samsung j7 2016 second',
#  'xiaomi redmi 6a ram 2gb gold garansi 1tahun',
#  'dijual buzzer lound speaker oppo r7s original diskon',
#  'terlaris kamera belakang back camera samsung g7102',
#  'promo hp xiaomi redmi 5 ram 2gb rom 16gb 7 inchi garansi resmi tam a3965',
#  'samsung galaxy j4 2018 ram 2gb internal 32gb garansi resmi sein',
#  'flexible flexibel on off samsung galaxy a5 a500 a5000',
#  'best seller sharp sh 01f 3g seken',
#  'simtray original xiaomi mi 5 black gold silver',
#  'advan vandroid i5e 4g lte 2gb 16gb gratis airbag bumper case',
#  'cuci gudang oppo a71 black gold garansi resmi indonesia 1thn emas on sale',
#  'lcd evercoss at1a at7e original',
#  'diskon samsung galaxy s8 plus smartphone midnight black 64gb 4gb dual',
#  'lagi ekstra promo nokia 7610 original',
#  'recomended hp xiaomi redmi 5a prime xiomi u002fxomi 5 a ram 3 u002f32 gb 32gb grs 1 thn abu',
#  'murah samsung z2 tizen duos warna hitam terbatas',
#  'promo iphone 6 64gb space grey mulus like new fullset ori apple icloud aman 2593',
#  'cuci gudang samsung galaxy j1 ace garansi resmi putih',
#  'tab lenovo a7 30',
#  'new xiaomi redmi s2 ram 3gb internal 32gb garansi distributor grey dus orange',
#  'promo xiaomi redmi 2 4g lte 1 8gb garansi distributor platinum tahun putih murah',
#  'cuci gudang ready iphone 8 plus 256gb space grey gray garansi apple 1 th ori terlaris',
#  'murah banget samsung galaxy j7 plus garansi resmi sein 01 02 03 04 05 06 07 08 09 10 11 12 13',
#  'grosir xiaomi redmi 4a prime 232 gb hp murah',
#  'hp murah oppo r11 64gb ram 4gb 20mp garansi 1thn original 100 big sale bazaar',
#  'model korea kpop new asli mewah elegan s xiaomi redmi 6a 216 redyh bindonesia playstore',
#  'i phone 7 rose gold 256 gb',
#  'xiaomi redmi note5a note 5a 2-16 gb tempered glass color full layar hp termurah',
#  'ready xiaomi redmi s2 464 gb ram 4gb internal 64gb emas',
#  'kjt ic power sony xperia zr c5502 c5503 docomo',
#  'handphone bandel nokia 1280 hp jadul keren new refurbish',
#  'new samsung galaxy a6 2018 3 u002f32gb garansi resmi black',
#  'cuci gudang xiaomi redmi 3s gold ram 2 u002f16gb garansi 1th',
#  'promo asus zenfone max m1 zb555kl 3gb32gb garansi distri ori hitam',
#  'apple iphone 5c 16gb white 4g lte garansi platinum 1thn putih',
#  'apple new ipad 97 40 2017 41 air 3 5 32gb wifi gold grey silver q416',
#  'laris xiaomi redmi note 5 pro 3gb u002f32gb black garansi distributor 1 tahun emas',
#  'ready vivo v9 black and gold original dan garansi resmi emas',
#  'buzzer bazer load speaker musik rumah xiaomi redmi note 4 original',
#  'murah cht081943675777 samsung galaxy s8 g950 sm-g950f garanai sein',
#  'hp1508-global version xiaomi redmi note 4 smartphone 3gb 32gb snapdragon 625 octa core 55&q',
#  'terlaris sony xperia xz1 compact 32gb ram 4gb 19mp garansi 1thn hitam',
#  'hot advan hammer r3e handphone lipat garansi resmi',
#  'samsung note 5 33gb',
#  'paling laris tempered glass andromax a smartfren anti gores kaca k-box',
#  'garskin oppo neo 7',
#  'samsung galaxy j2 pro ram 2 gb rom 32 garansi resmi sein',
#  'hp498-hot sales honor 9 smart phone tempered film glass cover for huawei with d',
#  'asus zenfone live l1 216 garansi resmi',
#  'samsung j2 bekas open nego',
#  'diskon 50 original xiaomi pocophone f1 664gb garansi 1 tahun distibutor promo cuci gudang',
#  'big 88 sony xperia x performance second mulus original 100',
#  'ready doogee s50',
#  'xiaomi redmi note 5a ram 216 gb garansi tam',
#  'hp1680-global rom xiaomi redmi note 4x 3gb ram 16gb mobile phone snapdragon 625 octa cor',
#  'ready original xiaomi pocophone f1 664gb garansi 1 tahun distibutor',
#  'big promo xiaomi redmi note 5a 216 garansi resmi tam abu tua',
#  'hot refurbished apple iphone 5s-32 gb gray garansi distributor 1 thn abu-abu muda 2677',
#  'promo evercoss a53c android murah 3g',
#  'promo hari jadi toko kami stock terbatas asus zenfone max plus m1 zb570tl 4gb ram 64gb rom',
#  'termurah hp xiaomi redmi note 5a xiomi not 5 a ram 2 16gb 16 rose pink',
#  'promo nokia 130 dual sim tam erajaya ex display',
#  'wa 085314372635 xiaomi mi 6x ram 6gb hdd 128gb',
#  'promo xiaomi redmi 5 plus garansi resmi tam 4g lte ram 3gb rom 32gb full hitam',
#  'asus zenfone max pro m1 zb602kl smartphone black 64gb 6gb',
#  'big sale xiaomi mi a2 lite 464gb bnib new ori android one',
#  'ready backdoor vivo y28 back cover tutup belakang terjamin berkualitas',
#  'spigen crystal wallet series samsung galaxy s8 original blue coral',
#  'new ipad 6 97 2018 wifi cell 32gb garansi apple 1 tahun',
#  'promo infinix hot s3 64gb garansi resmi 1 tahun',
#  'frame dudukan tulang tempat lcd xiaomi redmi note 3 pro original',
#  'apple ipad 97 inch 2018 cellularwifi 128 gb space gray silver gold new 6',
#  'backdrop housing xiaomi mi4c',
#  'diskon special promo akhir xiaomi mi a2 lite ram 3 gb rom 32 black garansi distributor',
#  'tempered glass nokia 6 full glue 25d cover',
#  'vivo v9 true red garansi resmi indonesia',
#  'lenovo a588t flip phone',
#  'xiaomi pocophone f1 664 garansi resmi hitam',
#  'nokia 5 garansi resmi 1 tahun',
#  'advan vandroid e1c nxt ram 1gb8gb garansi resmi',
#  'flexible lenovo k4 note-a7010 onoff volumetombol power termurah',
#  'baru sony xperia z4 au bukan docomo anti air jkt gojek mulus fullset diskon termurah',
#  'big promo samsung galaxy a6 plus 2018 432gb garansi resmi original',
#  'baru silicon tpu bening shining chrome lenovo a7000 a 7000 good quality',
#  'distributor asus zenfone 5 4 64gb garansi resmi navy',
#  'edisi cuci gudang xiaomi pocophone f1 steel blue ram 6gb internal 128gb',
#  'hot ringke air apple iphone 7 plus ink black',
#  'handphone second samsung galaxy chat baca deskripsi',
#  'vivo y83 432 gb 622 garansi resmi',
#  'xiaomi redmi note 5a prime ram 3gb rom 32gb tam',
#  'samsung j3 emerge mulus seken original garansi',
#  'garskin skin guarskin huawei nova 3i motif woods free custom gambar',
#  'samsung note 8 ultimate special edition 1:1 like ori',
#  'promo speaker portable jbl go bluetooth original garansi resmi ims 1 tahun termurah',
#  'lcd samsung s6500 galaxy mini 2',
#  'samsung galaxy note 4 global 4g',
#  'xiaomi redmi mi a1 tam ram 4 internal 64gb garansi resmi merah muda',
#  '99 promo diskon 80 hp xiaomi mi a1 432gb free in-ear headphones basic black murah',
#  ...}

# %%
for ix, row in df[df.eval_set == 'train'].iterrows():
    if row['item_name'] in val_item_name:
        #print (df.iloc[ix].eval_set)
        print (row['item_name'])
        df['eval_set'].iloc[ix] = 'val'
# Out:
# hp xiaomi c redmi note 3 pro 16gb ram 2gb garansi 1 tahun gs
# baru samsung j6 case 3d motif karakter 2018
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df[df.item_name == 'hp xiaomi c redmi note 3 pro 16gb ram 2gb garansi 1 tahun gs']
# Out:
#                                                 item_name   tokens  label  \
# 813077  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...       hp      0
# 813078  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...   xiaomi      2
# 813079  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...        c      0
# 813080  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...    redmi      0
# 813081  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...     note      0
# 813082  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...        3      0
# 813083  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...      pro      0
# 813084  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...     16gb      0
# 813085  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...      ram      0
# 813086  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...      2gb      0
# 813087  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...  garansi      0
# 813088  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...        1      0
# 813089  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...    tahun      0
# 813090  hp xiaomi c redmi note 3 pro 16gb ram 2gb gara...       gs      0
#
#        eval_set clean_tokens  item_id  word_id
# 813077    train           hp    80022     4715
# 813078    train       xiaomi    80022    14132
# 813079    train            c    80022     1509
# 813080    train        redmi    80022     7033
# 813081      val         note    80022     3504
# 813082    train            3    80022     3249
# 813083    train          pro    80022    15082
# 813084    train         16gb    80022     3044
# 813085    train          ram    80022     7908
# 813086    train          2gb    80022     5340
# 813087    train      garansi    80022    22458
# 813088    train            1    80022     3249
# 813089    train        tahun    80022     4622
# 813090    train           gs    80022     8389

# %%
num_sentences = df['item_name'].nunique()
seq_len_distribution = df.groupby('item_name').tokens.apply( lambda x : len(x.tolist())).to_frame('seq_len').reset_index()

# %%
seq_len_distribution.seq_len.max()
# Out:
# 36

# %%
#seq_len_distribution[seq_len_distribution.seq_len == 36]

# %%
#df[df.item_name.str.contains('Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra')]
# Out:
#                                                item_name      tokens  label  \
# 34065  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...        Asus      2
# 34066  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...     Zenfone      0
# 34067  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...          5Z      0
# 34068  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...     ZS620KL      0
# 34069  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...         Ram      0
# 34070  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...    6GB128GB      0
# 34071  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...           -      0
# 34072  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...  Snapdragon      0
# 34073  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...         845      0
# 34074  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...           -      0
# 34075  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...          62      0
# 34076  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...        Inch      0
# 34077  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...         FHD      0
# 34078  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...       Super      0
# 34079  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...         IPS      0
# 34080  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...           -      0
# 34081  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...        Sony      0
# 34082  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...    Flagship      0
# 34083  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...      IMX363      0
# 34084  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...        12MP      0
# 34085  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...        Dual      0
# 34086  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...      Camera      0
# 34087  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...           -      0
# 34088  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...        3300      0
# 34089  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...         mAh      0
# 34090  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...           -      0
# 34091  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...        Dual      0
# 34092  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...     Simcard      0
# 34093  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...          4G      0
# 34094  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...         LTE      0
# 34095  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...     Garansi      0
# 34096  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...       Resmi      0
# 34097  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...        Asus      2
# 34098  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...   Indonesia      0
# 34099  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...           1      0
# 34100  Asus Zenfone 5Z ZS620KL Ram 6GB128GB - Snapdra...       Tahun      0
#
#       eval_set clean_tokens  item_id  word_id
# 34065     test         asus     2900      922
# 34066     test      zenfone     2900    22763
# 34067     test           5z     2900    11970
# 34068     test      zs620kl     2900    24394
# 34069     test          ram     2900     7908
# 34070     test     6gb128gb     2900     8611
# 34071     test                  2900    24394
# 34072     test   snapdragon     2900     6118
# 34073     test          845     2900     3249
# 34074     test                  2900    24394
# 34075     test           62     2900     3249
# 34076     test         inch     2900    22772
# 34077     test          fhd     2900     2838
# 34078     test        super     2900     6216
# 34079     test          ips     2900    26490
# 34080     test                  2900    24394
# 34081     test         sony     2900    23438
# 34082     test     flagship     2900     7563
# 34083     test       imx363     2900    24394
# 34084     test         12mp     2900    27532
# 34085     test         dual     2900    17460
# 34086     test       camera     2900    18073
# 34087     test                  2900    24394
# 34088     test         3300     2900     3249
# 34089     test          mah     2900    10545
# 34090     test                  2900    24394
# 34091     test         dual     2900    17460
# 34092     test      simcard     2900    18911
# 34093     test           4g     2900    12415
# 34094     test          lte     2900    12659
# 34095     test      garansi     2900    22458
# 34096     test        resmi     2900    10305
# 34097     test         asus     2900      922
# 34098     test    indonesia     2900     7752
# 34099     test            1     2900     3249
# 34100     test        tahun     2900     4622

# %%
from sklearn.model_selection import GroupShuffleSplit

# %%
gsplit = GroupShuffleSplit(n_splits = 1, random_state = 3, train_size = 0.9, test_size = 0.1)

# %%
help(gsplit)
# Out:
# Help on GroupShuffleSplit in module sklearn.model_selection._split object:
#
# class GroupShuffleSplit(ShuffleSplit)
#  |  Shuffle-Group(s)-Out cross-validation iterator
#  |
#  |  Provides randomized train/test indices to split data according to a
#  |  third-party provided group. This group information can be used to encode
#  |  arbitrary domain specific stratifications of the samples as integers.
#  |
#  |  For instance the groups could be the year of collection of the samples
#  |  and thus allow for cross-validation against time-based splits.
#  |
#  |  The difference between LeavePGroupsOut and GroupShuffleSplit is that
#  |  the former generates splits using all subsets of size ``p`` unique groups,
#  |  whereas GroupShuffleSplit generates a user-determined number of random
#  |  test splits, each with a user-determined fraction of unique groups.
#  |
#  |  For example, a less computationally intensive alternative to
#  |  ``LeavePGroupsOut(p=10)`` would be
#  |  ``GroupShuffleSplit(test_size=10, n_splits=100)``.
#  |
#  |  Note: The parameters ``test_size`` and ``train_size`` refer to groups, and
#  |  not to samples, as in ShuffleSplit.
#  |
#  |
#  |  Parameters
#  |  ----------
#  |  n_splits : int (default 5)
#  |      Number of re-shuffling & splitting iterations.
#  |
#  |  test_size : float, int, None, optional
#  |      If float, should be between 0.0 and 1.0 and represent the proportion
#  |      of the dataset to include in the test split. If int, represents the
#  |      absolute number of test samples. If None, the value is set to the
#  |      complement of the train size. By default, the value is set to 0.2.
#  |      The default will change in version 0.21. It will remain 0.2 only
#  |      if ``train_size`` is unspecified, otherwise it will complement
#  |      the specified ``train_size``.
#  |
#  |  train_size : float, int, or None, default is None
#  |      If float, should be between 0.0 and 1.0 and represent the
#  |      proportion of the groups to include in the train split. If
#  |      int, represents the absolute number of train groups. If None,
#  |      the value is automatically set to the complement of the test size.
#  |
#  |  random_state : int, RandomState instance or None, optional (default=None)
#  |      If int, random_state is the seed used by the random number generator;
#  |      If RandomState instance, random_state is the random number generator;
#  |      If None, the random number generator is the RandomState instance used
#  |      by `np.random`.
#  |
#  |  Method resolution order:
#  |      GroupShuffleSplit
#  |      ShuffleSplit
#  |      BaseShuffleSplit
#  |      abc.NewBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, n_splits=5, test_size='default', train_size=None, random_state=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseShuffleSplit:
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  get_n_splits(self, X=None, y=None, groups=None)
#  |      Returns the number of splitting iterations in the cross-validator
#  |
#  |      Parameters
#  |      ----------
#  |      X : object
#  |          Always ignored, exists for compatibility.
#  |
#  |      y : object
#  |          Always ignored, exists for compatibility.
#  |
#  |      groups : object
#  |          Always ignored, exists for compatibility.
#  |
#  |      Returns
#  |      -------
#  |      n_splits : int
#  |          Returns the number of splitting iterations in the cross-validator.
#  |
#  |  split(self, X, y=None, groups=None)
#  |      Generate indices to split data into training and test set.
#  |
#  |      Parameters
#  |      ----------
#  |      X : array-like, shape (n_samples, n_features)
#  |          Training data, where n_samples is the number of samples
#  |          and n_features is the number of features.
#  |
#  |      y : array-like, shape (n_samples,)
#  |          The target variable for supervised learning problems.
#  |
#  |      groups : array-like, with shape (n_samples,), optional
#  |          Group labels for the samples used while splitting the dataset into
#  |          train/test set.
#  |
#  |      Returns
#  |      -------
#  |      train : ndarray
#  |          The training set indices for that split.
#  |
#  |      test : ndarray
#  |          The testing set indices for that split.
#  |
#  |      Notes
#  |      -----
#  |      Randomized CV splitters may return different results for each call of
#  |      split. You can make the results identical by setting ``random_state``
#  |      to an integer.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from abc.NewBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
x = [1,1,2,3,4,2]
g = [1,2]

# %%
for train_idx, test_idx in gsplit.split(x,g):
    print ('train_idx',train_idx)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-b1cc5f5cb7c0> in <module>()
# ----> 1 for train_idx, test_idx in gsplit.split(x,g):
#       2     print ('train_idx',train_idx)
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    1201         to an integer.
#    1202         """
# -> 1203         X, y, groups = indexable(X, y, groups)
#    1204         for train, test in self._iter_indices(X, y, groups):
#    1205             yield train, test
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     227         else:
#     228             result.append(np.array(X))
# --> 229     check_consistent_length(*result)
#     230     return result
#     231
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [6, 2]

# %%
u = pd.read_csv('../data/processed/mobile_training_v2.csv')
pd.options.display.max_columns = 100
pd.options.display.max_rows = 5000
pd.options.display.max_colwidth = 1000

# %%
u.eval_set.value_counts()
# Out:
# test     357
# train    350
# val       29
# Name: eval_set, dtype: int64

# %%
u
# Out:
#                                                                                         item_name  \
# 0                                  SAMSUNG CARAMEL GT-E1272 FLIP DUAL SIM CAMERA FLIP REFURBHISED
# 334             Guru      0     test
# 335            Music      0     test
# 336         SM-B310E      0     test
# 337                -      0     test
# 338             Biru      0     test
# 339          Samsung      2     test
# 340           Phyton      0     test
# 341            B310E      0     test
# 342                -      0     test
# 343             Dual      0     test
# 344              SIM      0     test
# 345          Samsung      2     test
# 346            Piton      0     test
# 347                -      0     test
# 348            B310E      0     test
# 349                -      0     test
# 350             Biru      0     test
# 351    SamsungGalaxy      0     test
# 352               J7      0     test
# 353             Core      0     test
# 354                -      0     test
# 355          SM-J701      0     test
# 356            -Gold      0     test
# 357          baterai      0    train
# 358            nokia      2    train
# 359            blc-2      0    train
# 360             3310      0    train
# 361             3315      0    train
# 362             3330      0    train
# 363             3350      0    train
# 364             3410      0    train
# 365             3510      0    train
# 366             3530      0    train
# 367             3585      0    train
# 368             3586      0    train
# 369             3570      0    train
# 370             5510      0    train
# 371             6800      0    train
# 372             best      0    train
# 373           seller      0    train
# 374           xiaomi      2    train
# 375               mi      0    train
# 376             band      0    train
# 377                2      0    train
# 378       blackberry      2      val
# 379            curve      0      val
# 380             9380      0      val
# 381          orlando      0      val
# 382          garansi      0      val
# 383            resmi      0      val
# 384                1      0      val
# 385            tahun      0      val
# 386             boya      0    train
# 387               by      0    train
# 388              wm8      0    train
# 389              uhf      0    train
# 390             dual      0    train
# 391          channel      0    train
# 392         wireless      0    train
# 393       microphone      0    train
# 394            canon      0    train
# 395             sony      2    train
# 396            nikon      0    train
# 397             dslr      0    train
# 398              p20      0    train
# 399           camera      0    train
# 400           kamera      0    train
# 401             sony      2    train
# 402           xperia      0    train
# 403               z5      0    train
# 404          premium      0    train
# 405            e6853      0    train
# 406            small      0    train
# 407            depan      0    train
# 408         original      0    train
# 409           casing      0    train
# 410           kesing      0    train
# 411            nokia      2    train
# 412                z      0    train
# 413           qwerty      0    train
# 414              e72      0    train
# 415          fullset      0    train
# 416           diskon      0    train
# 417           xiaomi      2    train
# 418           miband      0    train
# 419                2      0    train
# 420             oled      0    train
# 421             ip67      0    train
# 422        wateproof      0    train
# 423               20      0    train
# 424               hr      0    train
# 425            stand      0    train
# 426               by      0    train
# 427               mi      0    train
# 428             band      0    train
# 429           uniqqq      0    train
# 430         terlaris      0    train
# 431        flashdisk      0    train
# 432             sony      2    train
# 433           suzaku      0    train
# 434              ori      0    train
# 435               99      0    train
# 436             32gb      0    train
# 437          packing      0    train
# 438             pres      0    train
# 439          garskin      0    train
# 440             asus      2    train
# 441          zenfone      0    train
# 442                c      0    train
# 443             z007      0    train
# 444            murah      0    train
# 445             foto      0    train
# 446            bebas      0    train
# 447           grosir      0    train
# 448           xiaomi      2    train
# 449            redmi      0    train
# 450               4x      0    train
# 451              2gb      0    train
# 452              ram      0    train
# 453             16gb      0    train
# 454              rom      0    train
# 455           global      0    train
# 456         official      0    train
# 457           stable      0    train
# 458               hp      0    train
# 459             baru      0    train
# 460               hp      0    train
# 461        handphone      0    train
# 462            advan      2    train
# 463              s5e      0    train
# 464               4g      0    train
# 465              lte      0    train
# 466            seken      0    train
# 467           second      0    train
# 468            bekas      0    train
# 469            mulus      0    train
# 470           lancar      0    train
# 471               hp      0    train
# 472            nokia      2    train
# 473             1650      0    train
# 474            seken      0    train
# 475            murah      0    train
# 476  hp1769-original      0    train
# 477           xiaomi      2    train
# 478            redmi      0    train
# 479                5      0    train
# 480              3gb      0    train
# 481              ram      0    train
# 482             32gb      0    train
# 483              rom      0    train
# 484           mobile      0    train
# 485            phone      0    train
# 486           google      0    train
# 487             play      0    train
# 488       snapdragon      0    train
# 489              450      0    train
# 490             octa      0    train
# 491             jual      0    train
# 492         flexible      0    train
# 493          samsung      2    train
# 494               s4      0    train
# 495            i9500      0    train
# 496          speaker      0    train
# 497           sensor      0    train
# 498              ori      0    train
# 499      berkualitas      0    train
# 500             jual      0    train
# 501         flexible      0    train
# 502             sony      2    train
# 503            d6633      0    train
# 504           xperia      0    train
# 505               z3      0    train
# 506             dual      0    train
# 507               on      0    train
# 508              off      0    train
# 509           volume      0    train
# 510              ori      0    train
# 511      berkualitas      0    train
# 512              lcd      0      val
# 513             1set      0      val
# 514      touchscreen      0      val
# 515               ss      0      val
# 516           xiaomi      2      val
# 517             mi4i      0      val
# 518              m4i      0      val
# 519         original      0      val
# 520              lcd      0    train
# 521            nokia      2    train
# 522        e71e72e63      0    train
# 523         original      0    train
# 524              lcd      0    train
# 525             sony      2    train
# 526           xperia      0    train
# 527                e      0    train
# 528            d2004      0    train
# 529            d2005      0    train
# 530            d2105      0    train
# 531              lcd      0    train
# 532      touchscreen      0    train
# 533             asus      2    train
# 534          zenfone      0    train
# 535                3      0    train
# 536              max      0    train
# 537          zc520tl      0    train
# 538           x008da      0    train
# 539         original      0    train
# 540           lenovo      2      val
# 541              s90      0      val
# 542             livo      0      val
# 543               lg      2    train
# 544               q6      0    train
# 545              432      0    train
# 546               mu      0    train
# 547          gravity      0    train
# 548             mini      0    train
# 549          folding      0    train
# 550           tripod      0    train
# 551            lipat      0    train
# 552              for      0    train
# 553            gopro      0    train
# 554             dslr      0    train
# 555           xiaomi      2    train
# 556               yi      0    train
# 557       smartphone      0    train
# 558              new      0    train
# 559           hikaru      0    train
# 560             anti      0    train
# 561           finger      0    train
# 562            print      0    train
# 563             asus      2    train
# 564          zenfone      0    train
# 565                3      0    train
# 566              max      0    train
# 567          zc520tl      0    train
# 568                5      0    train
# 569                2      0    train
# 570             oppo      2    train
# 571           a57a39      0    train
# 572          supreme      0    train
# 573             fuze      0    train
# 574             case      0    train
# 575            motif      0    train
# 576            keren      0    train
# 577              dan      0    train
# 578           cantik      0    train
# 579         original      0    train
# 580          samsung      2    train
# 581           galaxy      0    train
# 582             note      0    train
# 583                8      0    train
# 584            clear      0    train
# 585             view      0    train
# 586         standing      0    train
# 587            cover      0    train
# 588            black      0    train
# 589          penutup      0    train
# 590            lensa      0    train
# 591           kamera      0    train
# 592            logam      0    train
# 593          standar      0    train
# 594        universal      0    train
# 595             52mm      0    train
# 596            warna      0    train
# 597            hitam      0    train
# 598            untuk      0    train
# 599   canonnikonsony      0    train
# 600            promo      0    train
# 601           xiaomi      2    train
# 602            redmi      0    train
# 603                2      0    train
# 604          limited      0    train
# 605            radio      0    train
# 606               ht      0    train
# 607         motorola      2    train
# 608           cp1660      0    train
# 609              grs      0    train
# 610                1      0    train
# 611            tahun      0    train
# 612          samsung      2    train
# 613               a5      0    train
# 614             2017      0    train
# 615            balck      0    train
# 616             baru      0    train
# 617          garansi      0    train
# 618            resmi      0    train
# 619             sein      0    train
# 620          samsung      2    train
# 621          caramel      0    train
# 622               gt      0    train
# 623            e1272      0    train
# 624          samsung      2    train
# 625           galaxy      0    train
# 626               j2      0    train
# 627            prime      0    train
# 628              new      0    train
# 629         original      0    train
# 630          garansi      0    train
# 631            resmi      0    train
# 632          samsung      2    train
# 633            piton      0    train
# 634               sm      0    train
# 635            b310e      0    train
# 636         termurah      0    train
# 637          garansi      0    train
# 638            resmi      0    train
# 639          samsung      2    train
# 640               s6      0    train
# 641             edge      0    train
# 642             plus      0    train
# 643             64gb      0    train
# 644               ex      0    train
# 645            inter      0    train
# 646           single      0    train
# 647          mulusss      0    train
# 648       kinclonggg      0    train
# 649          samsung      2    train
# 650              tab      0    train
# 651                a      0    train
# 652             with      0    train
# 653                s      0    train
# 654              pen      0    train
# 655             sony      2    train
# 656         ericsson      0    train
# 657             t200      0    train
# 658           mantap      0    train
# 659             sony      2      val
# 660           xperia      0      val
# 661               xa      0      val
# 662            ultra      0      val
# 663            f3216      0      val
# 664            white      0      val
# 665              316      0      val
# 666             cash      0      val
# 667               or      0      val
# 668           credit      0      val
# 669        terlaaris      0    train
# 670         terlaris      0    train
# 671         original      0    train
# 672             sony      2    train
# 673              mdr      0    train
# 674               zx      0    train
# 675              310      0    train
# 676               ap      0    train
# 677           stereo      0    train
# 678        headphone      0    train
# 679       bergaransi      0    train
# 680        fantastic      0    train
# 681             n357      0    train
# 682      touchscreen      0    train
# 683             mito      2    train
# 684              a73      0    train
# 685         original      0    train
# 686            tutup      0    train
# 687         belakang      0    train
# 688             back      0    train
# 689            cover      0    train
# 690          samsung      2    train
# 691             g355      0    train
# 692           galaxy      0    train
# 693             core      0    train
# 694                2      0    train
# 695             high      0    train
# 696          quality      0    train
# 697            tutup      0    train
# 698             port      0    train
# 699              usb      0    train
# 700           memori      0    train
# 701             sony      2    train
# 702           xperia      0    train
# 703               m2      0    train
# 704             aqua      0    train
# 705         original      0    train
# 706           xiaomi      2    train
# 707               mi      0    train
# 708                a      0    train
# 709               sz      0    train
# 710                1      0    train
# 711               a1      0    train
# 712             mia1      0    train
# 713              gkk      0    train
# 714              360      0    train
# 715             full      0    train
# 716       protection      0    train
# 717         original      0    train
# 718        hardcasee      0    train
# 719           xiaomi      2    train
# 720               mi      0    train
# 721               a1      0    train
# 722             32gb      0    train
# 723             rose      0    train
# 724             gold      0    train
# 725          garansi      0    train
# 726            resmi      0    train
# 727              tam      0    train
# 728                1      0    train
# 729            tahun      0    train
# 730           xiaomi      2    train
# 731               mi      0    train
# 732               a1      0    train
# 733              464      0    train
# 734          garansi      0    train
# 735            resmi      0    train

# %%
for i in range(3):
    print (i)
# Out:
# 0
# 1
# 2
