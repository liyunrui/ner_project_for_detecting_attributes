# %%
import pandas as pd
import ast # load json-like string as dict
import gc
pd.options.display.max_columns = 100
pd.options.display.max_rows = 5000
pd.options.display.max_colwidth = 1000

# %% [markdown]
# # 1.pull ㄩ

# %%
df1 = pd.read_csv('../data/processed/mobile_training.csv')

# %%
df1.head() # is_brand --> tag

# %%
shoope_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_tagging.csv')

# %%
shoope_mobile.shape

# %%
shoope_mobile.head()

# %%
c = 0
for ix, row in shoope_mobile.iterrows():
    title = row['title'] # str
    tagging_dict = ast.literal_eval(row['mobile']) # dict
    attr_tag = tagging_dict[' Brand'][0][0] # str
    if attr_tag.lower() in title.lower():
        pass
    else:
        print ('title', title)
        print ('attr_tag', attr_tag)
        if 'iphone' in title.lower():
            c+=1
print (c)

# %%
def filter_data_for_ner_task(df, out_col, attr = ' Brand'):
    """
    Return reliable data that we generally make sure attribute you assigned exist in the title.
    """
    num_filter = 0
    keep = []
    attr_tags = []
    for ix, row in df.iterrows():
        title = row['title'] # str
        tagging_dict = ast.literal_eval(row['mobile']) # dict
        attr_tag = tagging_dict[attr][0][0] # str
        if attr_tag.lower() in title.lower():
            keep.append(1)
            attr_tags.append(attr_tag)
        else:
            num_filter += 1
            keep.append(0)
            attr_tags.append(0)
    #-----------------
    # output
    #-----------------
    df['keep'] = keep
    df['attr_tags'] = attr_tags
    df.rename(columns = {'title': out_col[0], 'attr_tags':out_col[1]}, inplace = True)
    df[df.keep == 1]
    df = df[out_col]
    gc.collect()
    return df, num_filter

# %%
# df, num_filter = filter_data_for_ner_task(shoope_mobile.head(100), attr = ' Brand')
output_column = ['item_name', 'brand']
df, num_filter = filter_data_for_ner_task(shoope_mobile.head(100), out_col = output_column, attr =  ' Brand')

# %%
df

# %%
df.shape

# %%
39873 / shoope_mobile.shape[0]

# %%
df.head()

# %%
#--------------------------
# loading data
#--------------------------
lazada_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_brand.csv')
shoope_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_tagging.csv')

#--------------------------
# preprocessing data
#--------------------------
shoope_mobile.drop_duplicates(subset = ['itemid'], inplace = True)
lazada_mobile.brand = lazada_mobile.brand.apply(lambda x : x.lower())
lazada_mobile.rename(columns = {'title':'item_name'}, inplace = True)

brand_list_lazada = set(lazada_mobile.brand.unique())
# brand_list_shopee = set(shoope_mobile.brand.unique())
# print ('difference betwee target and source dataset', brand_list_lazada.difference(brand_list_shopee))

# %%
lazada_mobile.head()

# %%
#--------------------------
# setting
#--------------------------
output_column = ['item_name', 'brand']
#--------------------------
# loading data
#--------------------------
lazada_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_brand.csv')
shoope_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_tagging.csv')

#--------------------------
# preprocessing data
#--------------------------
shoope_mobile.drop_duplicates(subset = ['itemid'], inplace = True)
lazada_mobile.brand = lazada_mobile.brand.apply(lambda x : x.lower())
lazada_mobile.rename(columns = {'title':'item_name'}, inplace = True)


#--------------------------
# data configuration: take Lazada data as testing and shoppe as training data.
#-------------------------- 

lazada_mobile['eval_set'] = ['test' for i in range(len(lazada_mobile))]
shoope_mobile['eval_set'] = ['train' for i in range(len(shoope_mobile))]

# 
df = pd.concat([lazada_mobile[output_column], shoope_mobile[output_column]], axis = 0)

# %%
shoope_mobile.head()

# %%
lazada_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_brand.csv')

# %%
lazada_mobile

# %%
#! /usr/bin/env python3
"""
Created on Oct 24 2018

It provides text preprocessing and 
@author: Ray

"""

import sys
import ast # real json-like string
import pandas as pd
import gc
import sys
import os
sys.path.append('../../brand_recognition_bio_FE/preprocessing')
sys.path.append('../../brand_recognition_bio_FE/py_model')
from preprocessing import sequence_labeling_w_bio_encoding
import logging

def filter_data_for_ner_task(df, out_col, attr = ' Brand'):
    """
    Return reliable data that we generally make sure attribute you assigned exist in the title.
    """
    num_filter = 0
    keep = []
    attr_tags = []
    for ix, row in df.iterrows():
        title = row['title'] # str
        tagging_dict = ast.literal_eval(row['mobile']) # dict
        attr_tag = tagging_dict[attr][0][0] # str
        if attr_tag.lower() in title.lower():
            keep.append(1)
            attr_tags.append(attr_tag)
        else:
            num_filter += 1
            keep.append(0)
            attr_tags.append(0)
    #-----------------
    # output
    #-----------------
    df['keep'] = keep
    df['attr_tags'] = attr_tags
    df.rename(columns = {'title': out_col[0], 'attr_tags':out_col[1]}, inplace = True)
    df = df[df.keep == 1]
    df = df[out_col]
    gc.collect()
    return df, num_filter

if __name__ == '__main__':
    #--------------------------
    # setting
    #--------------------------
    output_column = ['item_name', 'brand', 'eval_set']

    #--------------------------
    # loading data
    #--------------------------
    lazada_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_brand.csv')
    shoope_mobile = pd.read_csv('/data/ner_task/mobile/mobile_ID_attribute_tagging.csv')

    #--------------------------
    # preprocessing data
    #--------------------------
    shoope_mobile.drop_duplicates(subset = ['itemid'], inplace = True)
    lazada_mobile.brand = lazada_mobile.brand.apply(lambda x : x.lower())
    lazada_mobile.rename(columns = {'title':'item_name'}, inplace = True)


    #--------------------------
    # data configuration: take Lazada data as testing and shoppe as training data.
    #-------------------------- 

    lazada_mobile['eval_set'] = ['test' for i in range(len(lazada_mobile))]
    shoope_mobile['eval_set'] = ['train' for i in range(len(shoope_mobile))]
    #--------------------------
    # filter: In order to get high-quality data, we remove the sku that his attribute name do not exist in title from our shopee data.
    #--------------------------
    attr = ' Brand'
    shoope_mobile, num_filter = filter_data_for_ner_task(shoope_mobile, out_col = output_column, attr =  attr)
    print ('num_sku_removed: {}'.format(num_filter))

    df = pd.concat([lazada_mobile[output_column], shoope_mobile[output_column]], axis = 0)
    del lazada_mobile, shoope_mobile
    gc.collect()

    #--------------------------
    # BIO tagging
    #--------------------------
    df.rename(columns = {'brand':'what_brand_name'}, inplace = True)
# Out:
# num_sku_removed: 39873

# %%
df
# Out:
#                                                 item_name what_brand_name
# 0       Samsung Galaxy J2 Prime REFRESH SM-G532 - Abso...         samsung
# 1        Samsung Galaxy J1 Ace 2016 SM-J111 - 8GB - Hitam         samsung
# 2       Samsung Galaxy J2 Prime REFRESH SM-G532 - Meta...         samsung
# 3       Samsung Galaxy J1 Ace 2016 SM-J111 - 8GB - Putih          samsung
# 4                Samsung Galaxy J2 Prime SM-G532 - Silver         samsung
# 5                   Samsung Galaxy J2 Pro - SMJ250 - Gold         samsung
# 6         Samsung Galaxy J1 Ace 2016 SM-J111 - 8GB - Biru         samsung
# 7                   SamsungGalaxy J7 Core - SM-J701 -Gold         samsung
# 8                      Samsung Guru Music SM-B310E - Biru         samsung
# 9                         Samsung Phyton B310E - Dual SIM         samsung
# 10      SAMSUNG CARAMEL GT-E1272 FLIP DUAL SIM CAMERA ...         samsung
# 11               Samsung Galaxy J7 Core - SM-J701 -Black          samsung
# 12                                 Galaxy J2 Core SM-J260         samsung
# 13               Samsung Galaxy J7 Prime SM-G610 - Hitam          samsung
# 14          Samsung Galaxy J3 Pro - SM-J330G -Blue Silver         samsung
# 15              Samsung Galaxy S9 -Midnight Black 4/64 GB         samsung
# 16             Samsung Galaxy J4 SM-J400F - Black 2/16 GB         samsung
# 17                           Samsung Galaxy J5 Pro - Emas         samsung
# 18      SAMSUNG GALAXY C9 PRO Dual SIM 64GB RAM 6GB FR...         samsung
# 19          Samsung Galaxy J7 Prime SM-G610 - White Gold          samsung
# 20               Samsung Galaxy J1 Ace 2016 - 8GB - Putih         samsung
# 21                  Samsung Galaxy J7 2016 SM-J710 - Emas         samsung
# 22                 Samsung Galaxy J3 Pro - SM-J330G -Gold         samsung
# 23               Samsung Galaxy J1 Ace 2016 - 8GB - Hitam         samsung
# 24                           Samsung Galaxy Note9 6/128GB         samsung
# 25                            Samsung Galaxy J8 3GB 32 GB         samsung
# 26           Samsung Galaxy J1 2016 SM-J120 - 8GB - Putih         samsung
# 27                           Samsung Piton - B310E - Biru         samsung
# 28                       Samsung Galaxy J2 Prime - Silver         samsung
# 29              Samsung Galaxy J4 SM-J400F - Gold 2/32 GB         samsung
# ...                                                   ...             ...
# 309757               asli original samsung galaxy j8 2018         Samsung
# 309758      promo oppo find x ram 8gb 256gb garansi resmi            OPPO
# 309759  cuci gudang xiaomi redmi note 5 pro ram 4/64 b...          Xiaomi
# 309760  cuci gudang oppo f5 youth 3/32gb garansi resmi...            OPPO
# 309761  harga mantap original 100 charger oppo a3s fas...            OPPO
# 309762  xiaomi pocophone f1 6/128gb garansi resmi tam ...          Xiaomi
# 309763  big promo oppo f7 pro 6gb-128gb 4g lte red and...            OPPO
# 309765  special khusus hari ini hp lenovo a7700 garans...          Lenovo
# 309766              oppo f9 ram 4/64 garansi resmi 1tahun            OPPO
# 309767                  nokia 3 android garansi resmi 100           Nokia
# 309768  promo cucigudang hp oppo f5 youth new edition ...            OPPO
# 309769  big promo termurah oppo a71 garansi resmi 1 tahun            OPPO
# 309770                            xiaomi redmi 6 pro 32gb          Xiaomi
# 309771  samsung note 5 sein 32gb mulus bangets fullset...         Samsung
# 309772  big promo samsung j7 prime 3gb 32gb dual sim 4...         Samsung
# 309774  spesial9.9 apple iphone 5s 32gb space gray gar...           Apple
# 309775  murah samsung galaxy s7 edge 32gb single sim m...         Samsung
# 309776  big promo apple iphone 7 plus 128gb red bnib n...           Apple
# 309777  cuci gudang xiaomi redmi 5a 2gb/16gb garansi r...          Xiaomi
# 309778  cuci gudang xiaomi redmi note 3 pro gold ram 2...          Xiaomi
# 309779  cuci gudang xiaomi redmi 2 4g lte garansi plat...          Xiaomi
# 309780  promo xiaomi redmi note 4 ram 4gb internal 64g...          Xiaomi
# 309781  big sale cuci gudang samsung s5 docomo bekas s...         Samsung
# 309782  big promo samsung galaxy a8 2018 sm-a530 garan...         Samsung
# 309783  super sale promo shopee 9.9 oppo f9 4gb ram 64...            OPPO
# 309784  huawei honor 6x pro ini yang 4gb/64gb bukan yg...          Huawei
# 309785  oppo f7 youth 4gb/64gb ai beauty technology 20...            OPPO
# 309786        xiaomi redmi 6a gold 2/16 garansi resmi tam          Xiaomi
# 309787  promo diskon 80 hp xiaomi redmi note 4x ram 3/...          Xiaomi
# 309788            oppo f7 plus ram 6/128 gb garansi resmi            OPPO
#
# [300324 rows x 2 columns]
