# %%
import time
import sys
import numpy as np
import pandas as pd
from tqdm import tqdm
from billiard import Pool
import gc
sys.path.append('/home/ld-sgdev/yunrui_li/ner_project/brand_recognition_bio_FE/preprocessing')
sys.path.append('/home/ld-sgdev/yunrui_li/ner_project/brand_recognition_bio_FE/py_model')
from clean_helpers import clean_name_for_word_embedding
from utils import init_logging
import gc

def pad_1d(array, max_len):
    array = array[:max_len]
    length = len(array)
    padded = array + [0]*(max_len - len(array))
    return padded, length

def encode_word_to_idx(x, word_to_id, vocabulary_set):
    if x in vocabulary_set:
        return word_to_id[x]
    else:
        return word_to_id['None']

def parallelize_dataframe(df, func):
    '''
    speeding up DataFrame.apply() via parallelizing.

    '''
    #---------------
    # setting
    #---------------
    num_partitions = 10
    num_cores = 10

    # core
    df1,df2,df3,df4,df5,df6,df7,df8,df9,df10 = np.array_split(df, num_partitions)
    pool = Pool(num_cores)
    df = pd.concat(pool.map(func, [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]))
    pool.close()
    pool.join()
    return df

def speed_up_func_for_feature_engineering(df):
    df['clean_tokens'] = df.tokens.apply(lambda x: clean_name_for_word_embedding(x) if type(x)==str else x)
    df['clean_tokens'] = df.clean_tokens.apply(lambda x: x.lower() if type(x)==str else x)
    df['word_id'] = df.clean_tokens.apply( lambda x: encode_word_to_idx(x, word_to_id, vocabulary_set))
    return df

# %%
#-------------------
# loading data
#-------------------
df = pd.read_csv('../data/processed/mobile_training.csv')

#-------------------
# setting
#-------------------
TRUNCATED = False
num_sentences = df['item_name'].nunique()
seq_len_distribution = df.groupby('item_name').tokens.apply( lambda x : len(x.tolist())).to_frame('seq_len').reset_index()

if TRUNCATED == False:
    max_seq_length = seq_len_distribution.seq_len.max()
else:
    max_seq_length = 100


#-------------------
# word embedding preparation
#-------------------
word_embedding_path = '/data/ID_large_wordvec_300_2.h5'
word2vec = pd.read_hdf(word_embedding_path)
# get word_to_id
word_to_id = {word: int(i+1) for i, word in enumerate(word2vec.word.tolist())}
# for those word that do not exist in our vocabulary
word_to_id.update({'None': int(len(word_to_id)+1)})
# vocabulary_set
vocabulary_set = set(word_to_id.keys())

# %%
s = time.time()
df['clean_tokens'] = df.tokens.apply(lambda x: clean_name_for_word_embedding(x) if type(x)==str else x)
df['clean_tokens'] = df.clean_tokens.apply(lambda x: x.lower() if type(x)==str else x)
df['word_id'] = df.clean_tokens.apply( lambda x: encode_word_to_idx(x, word_to_id, vocabulary_set))
e = time.time()
print (e-s)
# Out:
# 4.660710096359253

# %%
len(df) * 0.13265609741210938 / 5000
# Out:
# 6.727070293426514

# %%
len(df)
# Out:
# 253553

# %%
df = pd.read_csv('../data/processed/mobile_training.csv')

# %%
df.
# Out:
#                                                 item_name      tokens  \
# 0         Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White     Samsung
# 1         Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White      Galaxy
# 2         Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White          J1
# 3         Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White         Ace
# 4         Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White        2016
# 5         Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White    SM-J111F
# 6         Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White         8GB
# 7         Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White           -
# 8         Samsung Galaxy J1 Ace 2016 SM-J111F 8GB - White       White
# 9            Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...   Blackview
# 10           Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...      BV8000
# 11           Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...         Pro
# 12           Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...         RAM
# 13           Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...         6GB
# 14           Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...        64GB
# 15           Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...        IP68
# 16           Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...  Waterproff
# 17           Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...      Rugged
# 18           Blackview BV8000 Pro RAM 6GB 64GB IP68 Wa...  Smartphone
# 19                                    iCherry C118 -putih     iCherry
# 20                                    iCherry C118 -putih        C118
# 21                                    iCherry C118 -putih      -putih
# 22                    Advan Hammer R3F - Dual Sim - Hitam       Advan
# 23                    Advan Hammer R3F - Dual Sim - Hitam      Hammer
# 24                    Advan Hammer R3F - Dual Sim - Hitam         R3F
# 25                    Advan Hammer R3F - Dual Sim - Hitam           -
# 26                    Advan Hammer R3F - Dual Sim - Hitam        Dual
# 27                    Advan Hammer R3F - Dual Sim - Hitam         Sim
# 28                    Advan Hammer R3F - Dual Sim - Hitam           -
# 29                    Advan Hammer R3F - Dual Sim - Hitam       Hitam
# ...                                                   ...         ...
# 253523  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...          3G
# 253524  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...           -
# 253525  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...       Putih
# 253526  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...     Samsung
# 253527  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...      Galaxy
# 253528  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...           V
# 253529  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...   SM-G313HZ
# 253530  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...           -
# 253531  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...      Kitkat
# 253532  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...           -
# 253533  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...        Dual
# 253534  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...         SIM
# 253535  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...          3G
# 253536  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...           -
# 253537  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...         4GB
# 253538  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...           -
# 253539  Samsung Galaxy V SM-G313HZ - Kitkat - Dual SIM...       Hitam
# 253540  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...     Samsung
# 253541  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...      Galaxy
# 253542  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...           V
# 253543  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...   SM-G313HZ
# 253544  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...           -
# 253545  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...     Android
# 253546  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...      Kitkat
# 253547  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...           -
# 253548  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...        Dual
# 253549  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...         SIM
# 253550  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...          3G
# 253551  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...           -
# 253552  Samsung Galaxy V SM-G313HZ - Android Kitkat - ...       Hitam
#
#         is_brand is_valid
# 0              2    train
# 1              0    train
# 2              0    train
# 3              0    train
# 4              0    train
# 5              0    train
# 6              0    train
# 7              0    train
# 8              0    train
# 9              2    train
# 10             0    train
# 11             0    train
# 12             0    train
# 13             0    train
# 14             0    train
# 15             0    train
# 16             0    train
# 17             0    train
# 18             0    train
# 19             2    train
# 20             0    train
# 21             0    train
# 22             0    train
# 23             0    train
# 24             0    train
# 25             0    train
# 26             0    train
# 27             0    train
# 28             0    train
# 29             0    train
# ...          ...      ...
# 253523         0    train
# 253524         0    train
# 253525         0    train
# 253526         2    train
# 253527         0    train
# 253528         0    train
# 253529         0    train
# 253530         0    train
# 253531         0    train
# 253532         0    train
# 253533         0    train
# 253534         0    train
# 253535         0    train
# 253536         0    train
# 253537         0    train
# 253538         0    train
# 253539         0    train
# 253540         2    train
# 253541         0    train
# 253542         0    train
# 253543         0    train
# 253544         0    train
# 253545         0    train
# 253546         0    train
# 253547         0    train
# 253548         0    train
# 253549         0    train
# 253550         0    train
# 253551         0    train
# 253552         0    train
#
# [253553 rows x 4 columns]

# %%
UNK = "$UNK$"
NUM = "$NUM$"
NONE = "O"

# %%
'$UNK$' in vocabulary_set
# Out:
# False

# %%
len(vocabulary_set)
# Out:
# 6629250

# %%
d = dict({'A':1,'B':2}) 
d
# Out:
# {'A': 1, 'B': 2}

# %%
d[UNK]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-02629e8fead9> in <module>()
# ----> 1 d[UNK]
#
# KeyError: '$UNK$'
