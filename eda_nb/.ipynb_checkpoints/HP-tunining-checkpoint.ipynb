# %%
import numpy as np
import pandas as pd
from datetime import datetime
import time
import sys
sys.path.append('../models/blend/')
from utils import customized_eval, HyperParameterTuning, KFoldValidation

# %%
#---------------------
# setting
#---------------------
BINARY_SCENARIO = None
#---------------------
# load features
#---------------------
feature_dir = '../features/lazada_and_amazon/all_features.h5'
df = pd.read_hdf(feature_dir)
#---------------------
# label post-processing
#---------------------
if df.label.nunique() == 2: 
    BINARY_SCENARIO = True
    # binary class
    df['label'] = df.label.apply(lambda x: 1 if x == 2 else 0) # for customized f1 score inference of lgb
else:
    # multi-class(B, I or O)
    pass

# %%
features = df.columns.tolist()[7:]
target = 'label'

# %%
#-----------------------
# parameter tuning for session-level
#-----------------------
target = 'label'
n_splits = 5
pbounds = {
'num_leaves': (25, 50),
'lambda_l2': (0.0, 0.05),
'lambda_l1': (0.0, 0.05),
'min_child_samples': (20, 120),
'bagging_fraction': (0.5, 1.0),
'feature_fraction': (0.5, 1.0),
} # 6 parameters to tune

# Create objec HyperParameterTuning for helping us tuning
HP_tuning = HyperParameterTuning(train = df, features= features, target = target,
                                 n_splits = n_splits, params_bound = pbounds)

date_str = datetime.now().strftime('%Y-%m-%d_%H-%M')
s = time.time()
result = HP_tuning.param_tuning(init_points = 5, num_iter = 30)
e = time.time()
logging.info('It took {} mins'.format((e-s)/60.0))

result.points_to_csv('logs/param_tuning_for_lgb_{}.csv'.format(date_str), index = False)

logging.info(pp.pprint(result.res['max']['max_params']))
# Out:
# Initialization
# ----------------------------------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |   bagging_fraction |   feature_fraction |   lambda_l1 |   lambda_l2 |   min_child_samples |   num_leaves |
# params {'objective': 'binary', 'metric': 'None', 'num_leaves': 48, 'lambda_l2': 0.01273586787787735, 'lambda_l1': 0.030414811872730513, 'min_child_samples': 62, 'bagging_fraction': 0.7653204710389181, 'feature_fraction': 0.5455923488142518, 'subsample_freq': 1, 'bagging_seed': 1540193136, 'max_depth': -1, 'learning_rate': 0.1, 'verbosity': -1, 'num_threads': 32, 'early_stopping_rounds': 50}
# Fold  0 :
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/lightgbm/engine.py:107: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's f1-score-on-sentence-level: 0
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.177708
# [6]	valid_0's f1-score-on-sentence-level: 0.595411
# [7]	valid_0's f1-score-on-sentence-level: 0.772087
# [8]	valid_0's f1-score-on-sentence-level: 0.834663
# [9]	valid_0's f1-score-on-sentence-level: 0.873399
# [10]	valid_0's f1-score-on-sentence-level: 0.891298
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's f1-score-on-sentence-level: 0.891298
# res_score_ls [0, 0, 0, 0, 0.17770849571317227, 0.5954108648754658, 0.7720868556273827, 0.8346625766871166, 0.8733993015133876, 0.8912982258518728]
# Fold  1 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.127809
# [6]	valid_0's f1-score-on-sentence-level: 0.602967
# [7]	valid_0's f1-score-on-sentence-level: 0.773293
# [8]	valid_0's f1-score-on-sentence-level: 0.855191
# [9]	valid_0's f1-score-on-sentence-level: 0.890072
# [10]	valid_0's f1-score-on-sentence-level: 0.899944
# res_score_ls [0, 0, 0, 0, 0.12780936907663148, 0.6029673590504452, 0.7732929700639084, 0.8551912568306012, 0.8900719424460432, 0.8999436302142052]
# Fold  2 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.146726
# [6]	valid_0's f1-score-on-sentence-level: 0.588374
# [7]	valid_0's f1-score-on-sentence-level: 0.778906
# [8]	valid_0's f1-score-on-sentence-level: 0.84472
# [9]	valid_0's f1-score-on-sentence-level: 0.879365
# [10]	valid_0's f1-score-on-sentence-level: 0.893551
# res_score_ls [0, 0, 0, 0, 0.14672626873520908, 0.5883739198743126, 0.7789059941041598, 0.84472049689441, 0.8793650793650793, 0.8935511123627148]
# Fold  3 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.00113507
# [6]	valid_0's f1-score-on-sentence-level: 0.609967
# [7]	valid_0's f1-score-on-sentence-level: 0.762664
# [8]	valid_0's f1-score-on-sentence-level: 0.84795
# [9]	valid_0's f1-score-on-sentence-level: 0.883562
# [10]	valid_0's f1-score-on-sentence-level: 0.895813
# res_score_ls [0, 0, 0, 0, 0.001135073779795687, 0.6099672888204734, 0.7626640093007806, 0.8479497156539958, 0.8835616438356164, 0.895813047711782]
# Fold  4 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.141345
# [6]	valid_0's f1-score-on-sentence-level: 0.584039
# [7]	valid_0's f1-score-on-sentence-level: 0.770275
# [8]	valid_0's f1-score-on-sentence-level: 0.833079
# [9]	valid_0's f1-score-on-sentence-level: 0.87763
# [10]	valid_0's f1-score-on-sentence-level: 0.892389
# res_score_ls [0, 0, 0, 0, 0.1413446267866596, 0.584039408866995, 0.7702747434624296, 0.8330790357033873, 0.8776298840704164, 0.8923891831614162]
# cv_result [0.8912982258518728, 0.8999436302142052, 0.8935511123627148, 0.895813047711782, 0.8923891831614162]
#     1 | 02m01s |    0.89460 |             0.7653 |             0.5456 |      0.0304 |      0.0127 |             62.3325 |      48.5909 |
# params {'objective': 'binary', 'metric': 'None', 'num_leaves': 27, 'lambda_l2': 0.03665686404353218, 'lambda_l1': 0.02419863108764486, 'min_child_samples': 81, 'bagging_fraction': 0.7185114067092719, 'feature_fraction': 0.9760194200525144, 'subsample_freq': 1, 'bagging_seed': 1540193257, 'max_depth': -1, 'learning_rate': 0.1, 'verbosity': -1, 'num_threads': 32, 'early_stopping_rounds': 50}
# Fold  0 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0.000571429
# [4]	valid_0's f1-score-on-sentence-level: 0.000571265
# [5]	valid_0's f1-score-on-sentence-level: 0.000571265
# [6]	valid_0's f1-score-on-sentence-level: 0.553665
# [7]	valid_0's f1-score-on-sentence-level: 0.747959
# [8]	valid_0's f1-score-on-sentence-level: 0.869119
# [9]	valid_0's f1-score-on-sentence-level: 0.894263
# [10]	valid_0's f1-score-on-sentence-level: 0.898907
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's f1-score-on-sentence-level: 0.898907
# res_score_ls [0, 0, 0.0005714285714285715, 0.0005712653527563553, 0.0005712653527563553, 0.553665451599838, 0.7479591836734695, 0.8691191557965704, 0.8942632170978627, 0.8989074816761167]
# Fold  1 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.027984
# [6]	valid_0's f1-score-on-sentence-level: 0.538
# [7]	valid_0's f1-score-on-sentence-level: 0.734296
# [8]	valid_0's f1-score-on-sentence-level: 0.854017
# [9]	valid_0's f1-score-on-sentence-level: 0.89229
# [10]	valid_0's f1-score-on-sentence-level: 0.89583
# res_score_ls [0, 0, 0, 0, 0.027984009137635633, 0.5379995858355767, 0.7342961545153993, 0.8540167865707433, 0.8922904086504705, 0.8958304281132338]
# Fold  2 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.0329793
# [6]	valid_0's f1-score-on-sentence-level: 0.630034
# [7]	valid_0's f1-score-on-sentence-level: 0.718869
# [8]	valid_0's f1-score-on-sentence-level: 0.864
# [9]	valid_0's f1-score-on-sentence-level: 0.886459
# [10]	valid_0's f1-score-on-sentence-level: 0.897248
# res_score_ls [0, 0, 0, 0, 0.03297931805477921, 0.6300338727888596, 0.7188685753708175, 0.864, 0.8864592094196803, 0.8972479601714839]
# Fold  3 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.155411
# [6]	valid_0's f1-score-on-sentence-level: 0.532735
# [7]	valid_0's f1-score-on-sentence-level: 0.738687
# [8]	valid_0's f1-score-on-sentence-level: 0.862831
# [9]	valid_0's f1-score-on-sentence-level: 0.892106
# [10]	valid_0's f1-score-on-sentence-level: 0.90037
# res_score_ls [0, 0, 0, 0, 0.15541069100391133, 0.5327350601672445, 0.7386866281047975, 0.8628312106572977, 0.8921063622441876, 0.9003700150746882]
# Fold  4 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0
# [6]	valid_0's f1-score-on-sentence-level: 0.568534
# [7]	valid_0's f1-score-on-sentence-level: 0.730218
# [8]	valid_0's f1-score-on-sentence-level: 0.857393
# [9]	valid_0's f1-score-on-sentence-level: 0.884166
# [10]	valid_0's f1-score-on-sentence-level: 0.895267
# res_score_ls [0, 0, 0, 0, 0, 0.5685339690107271, 0.730218281036835, 0.8573925710123818, 0.8841660802251935, 0.8952670070373948]
# cv_result [0.8989074816761167, 0.8958304281132338, 0.8972479601714839, 0.9003700150746882, 0.8952670070373948]
#     2 | 01m37s |    0.89752 |             0.7185 |             0.9760 |      0.0242 |      0.0367 |             81.8115 |      27.7735 |
# params {'objective': 'binary', 'metric': 'None', 'num_leaves': 27, 'lambda_l2': 0.04444760615638821, 'lambda_l1': 0.007986218160554536, 'min_child_samples': 110, 'bagging_fraction': 0.514864732470284, 'feature_fraction': 0.8631151942404583, 'subsample_freq': 1, 'bagging_seed': 1540193354, 'max_depth': -1, 'learning_rate': 0.1, 'verbosity': -1, 'num_threads': 32, 'early_stopping_rounds': 50}
# Fold  0 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0
# [6]	valid_0's f1-score-on-sentence-level: 0.552354
# [7]	valid_0's f1-score-on-sentence-level: 0.753093
# [8]	valid_0's f1-score-on-sentence-level: 0.846839
# [9]	valid_0's f1-score-on-sentence-level: 0.876634
# [10]	valid_0's f1-score-on-sentence-level: 0.890292
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's f1-score-on-sentence-level: 0.890292
# res_score_ls [0, 0, 0, 0, 0, 0.5523538961038961, 0.7530926961531944, 0.8468386902067301, 0.8766336349274737, 0.8902918069584735]
# Fold  1 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0
# [6]	valid_0's f1-score-on-sentence-level: 0.544665
# [7]	valid_0's f1-score-on-sentence-level: 0.752776
# [8]	valid_0's f1-score-on-sentence-level: 0.846154
# [9]	valid_0's f1-score-on-sentence-level: 0.879178
# [10]	valid_0's f1-score-on-sentence-level: 0.889737
# res_score_ls [0, 0, 0, 0, 0, 0.5446650124069479, 0.7527763540064925, 0.8461538461538463, 0.8791781218347562, 0.8897370653095844]
# Fold  2 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.0235889
# [6]	valid_0's f1-score-on-sentence-level: 0.51463
# [7]	valid_0's f1-score-on-sentence-level: 0.740304
# [8]	valid_0's f1-score-on-sentence-level: 0.835608
# [9]	valid_0's f1-score-on-sentence-level: 0.872193
# [10]	valid_0's f1-score-on-sentence-level: 0.889667
# res_score_ls [0, 0, 0, 0, 0.02358887952822241, 0.5146295912014941, 0.7403035413153457, 0.8356081286017591, 0.8721934369602764, 0.8896667600112014]
# Fold  3 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.0124153
# [6]	valid_0's f1-score-on-sentence-level: 0.561117
# [7]	valid_0's f1-score-on-sentence-level: 0.774772
# [8]	valid_0's f1-score-on-sentence-level: 0.835767
# [9]	valid_0's f1-score-on-sentence-level: 0.869154
# [10]	valid_0's f1-score-on-sentence-level: 0.884196
# res_score_ls [0, 0, 0, 0, 0.012415349887133184, 0.5611166500498505, 0.7747718383311604, 0.835766972753274, 0.8691535150645624, 0.8841958041958042]
# Fold  4 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.164841
# [6]	valid_0's f1-score-on-sentence-level: 0.524933
# [7]	valid_0's f1-score-on-sentence-level: 0.745098
# [8]	valid_0's f1-score-on-sentence-level: 0.840281
# [9]	valid_0's f1-score-on-sentence-level: 0.872286
# [10]	valid_0's f1-score-on-sentence-level: 0.886721
# res_score_ls [0, 0, 0, 0, 0.1648408972352634, 0.5249333059716808, 0.7450980392156863, 0.8402808904825938, 0.8722857142857142, 0.8867214713668663]
# cv_result [0.8902918069584735, 0.8897370653095844, 0.8896667600112014, 0.8841958041958042, 0.8867214713668663]
#     3 | 01m29s |    0.88812 |             0.5149 |             0.8631 |      0.0080 |      0.0444 |            110.5578 |      27.1009 |
# params {'objective': 'binary', 'metric': 'None', 'num_leaves': 36, 'lambda_l2': 0.040563907768700024, 'lambda_l1': 0.043465905994749, 'min_child_samples': 112, 'bagging_fraction': 0.8136892581622326, 'feature_fraction': 0.7805097410932683, 'subsample_freq': 1, 'bagging_seed': 1540193444, 'max_depth': -1, 'learning_rate': 0.1, 'verbosity': -1, 'num_threads': 32, 'early_stopping_rounds': 50}
# Fold  0 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.0253736
# [6]	valid_0's f1-score-on-sentence-level: 0.528317
# [7]	valid_0's f1-score-on-sentence-level: 0.773014
# [8]	valid_0's f1-score-on-sentence-level: 0.841769
# [9]	valid_0's f1-score-on-sentence-level: 0.871654
# [10]	valid_0's f1-score-on-sentence-level: 0.895813
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's f1-score-on-sentence-level: 0.895813
# res_score_ls [0, 0, 0, 0, 0.025373555117000283, 0.5283174865646961, 0.7730142904619476, 0.8417692658458733, 0.8716538851106931, 0.8958130477117819]
# Fold  1 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.0495775
# [6]	valid_0's f1-score-on-sentence-level: 0.548454
# [7]	valid_0's f1-score-on-sentence-level: 0.760089
# [8]	valid_0's f1-score-on-sentence-level: 0.842975
# [9]	valid_0's f1-score-on-sentence-level: 0.882591
# [10]	valid_0's f1-score-on-sentence-level: 0.894953
# res_score_ls [0, 0, 0, 0, 0.04957746478873239, 0.5484536082474227, 0.7600885407798399, 0.8429752066115702, 0.8825910931174089, 0.8949526367877845]
# Fold  2 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.102371
# [6]	valid_0's f1-score-on-sentence-level: 0.54774
# [7]	valid_0's f1-score-on-sentence-level: 0.769384
# [8]	valid_0's f1-score-on-sentence-level: 0.835466
# [9]	valid_0's f1-score-on-sentence-level: 0.884654
# [10]	valid_0's f1-score-on-sentence-level: 0.898474
# res_score_ls [0, 0, 0, 0, 0.10237068965517242, 0.5477397121427122, 0.7693836978131213, 0.8354661791590493, 0.8846536765751671, 0.8984743411927877]
# Fold  3 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.0257775
# [6]	valid_0's f1-score-on-sentence-level: 0.566481
# [7]	valid_0's f1-score-on-sentence-level: 0.772988
# [8]	valid_0's f1-score-on-sentence-level: 0.85145
# [9]	valid_0's f1-score-on-sentence-level: 0.878977
# [10]	valid_0's f1-score-on-sentence-level: 0.890653
# res_score_ls [0, 0, 0, 0, 0.02577752871952928, 0.5664808917197452, 0.7729880347484019, 0.8514498141263941, 0.8789772727272727, 0.8906532943306866]
# Fold  4 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.153402
# [6]	valid_0's f1-score-on-sentence-level: 0.58118
# [7]	valid_0's f1-score-on-sentence-level: 0.757895
# [8]	valid_0's f1-score-on-sentence-level: 0.834819
# [9]	valid_0's f1-score-on-sentence-level: 0.869578
# [10]	valid_0's f1-score-on-sentence-level: 0.889848
# res_score_ls [0, 0, 0, 0, 0.15340162857893355, 0.5811797198658513, 0.7578947368421053, 0.8348194045640018, 0.8695777075553002, 0.8898482105556329]
# cv_result [0.8958130477117819, 0.8949526367877845, 0.8984743411927877, 0.8906532943306866, 0.8898482105556329]
#     4 | 01m29s |    0.89395 |             0.8137 |             0.7805 |      0.0435 |      0.0406 |            112.8608 |      36.3963 |
# params {'objective': 'binary', 'metric': 'None', 'num_leaves': 27, 'lambda_l2': 0.038531711497808, 'lambda_l1': 0.0009075883158428111, 'min_child_samples': 65, 'bagging_fraction': 0.624416559107086, 'feature_fraction': 0.5777540546746236, 'subsample_freq': 1, 'bagging_seed': 1540193534, 'max_depth': -1, 'learning_rate': 0.1, 'verbosity': -1, 'num_threads': 32, 'early_stopping_rounds': 50}
# Fold  0 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.013617
# [6]	valid_0's f1-score-on-sentence-level: 0.543828
# [7]	valid_0's f1-score-on-sentence-level: 0.729538
# [8]	valid_0's f1-score-on-sentence-level: 0.851108
# [9]	valid_0's f1-score-on-sentence-level: 0.887477
# [10]	valid_0's f1-score-on-sentence-level: 0.899236
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's f1-score-on-sentence-level: 0.899236
# res_score_ls [0, 0, 0, 0, 0.013617021276595745, 0.5438275371161277, 0.7295379823498875, 0.8511081362486984, 0.8874770577438938, 0.8992355802640722]
# Fold  1 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0
# [6]	valid_0's f1-score-on-sentence-level: 0.55608
# [7]	valid_0's f1-score-on-sentence-level: 0.729753
# [8]	valid_0's f1-score-on-sentence-level: 0.867399
# [9]	valid_0's f1-score-on-sentence-level: 0.892157
# [10]	valid_0's f1-score-on-sentence-level: 0.89514
# res_score_ls [0, 0, 0, 0, 0, 0.5560795571047776, 0.7297533671506035, 0.8673992673992674, 0.8921568627450981, 0.8951399526528339]
# Fold  2 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0
# [6]	valid_0's f1-score-on-sentence-level: 0.581076
# [7]	valid_0's f1-score-on-sentence-level: 0.722155
# [8]	valid_0's f1-score-on-sentence-level: 0.847881
# [9]	valid_0's f1-score-on-sentence-level: 0.888517
# [10]	valid_0's f1-score-on-sentence-level: 0.899616
# res_score_ls [0, 0, 0, 0, 0, 0.5810757754220652, 0.7221550682092903, 0.8478810408921934, 0.8885172798216276, 0.8996160175534833]
# Fold  3 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0
# [6]	valid_0's f1-score-on-sentence-level: 0.59679
# [7]	valid_0's f1-score-on-sentence-level: 0.725335
# [8]	valid_0's f1-score-on-sentence-level: 0.852599
# [9]	valid_0's f1-score-on-sentence-level: 0.884594
# [10]	valid_0's f1-score-on-sentence-level: 0.897232
# res_score_ls [0, 0, 0, 0, 0, 0.5967897892090505, 0.72533516672396, 0.8525990281254602, 0.884593837535014, 0.8972321183885996]
# Fold  4 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0
# [6]	valid_0's f1-score-on-sentence-level: 0.58858
# [7]	valid_0's f1-score-on-sentence-level: 0.725237
# [8]	valid_0's f1-score-on-sentence-level: 0.860634
# [9]	valid_0's f1-score-on-sentence-level: 0.881826
# [10]	valid_0's f1-score-on-sentence-level: 0.891346
# res_score_ls [0, 0, 0, 0, 0, 0.5885803676183027, 0.7252368647717485, 0.8606342740762293, 0.8818258190982918, 0.8913464196848216]
# cv_result [0.8992355802640722, 0.8951399526528339, 0.8996160175534833, 0.8972321183885996, 0.8913464196848216]
#     5 | 01m29s |    0.89651 |             0.6244 |             0.5778 |      0.0009 |      0.0385 |             65.6159 |      27.6209 |
# params {'objective': 'binary', 'metric': 'None', 'num_leaves': 34, 'lambda_l2': 0.027550465293810434, 'lambda_l1': 0.006812901805310512, 'min_child_samples': 43, 'bagging_fraction': 0.7048692576154553, 'feature_fraction': 0.9976009306662141, 'subsample_freq': 1, 'bagging_seed': 1540193623, 'max_depth': -1, 'learning_rate': 0.1, 'verbosity': -1, 'num_threads': 32, 'early_stopping_rounds': 50}
# Fold  0 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.00114253
# [6]	valid_0's f1-score-on-sentence-level: 0.582823
# [7]	valid_0's f1-score-on-sentence-level: 0.758981
# [8]	valid_0's f1-score-on-sentence-level: 0.857911
# [9]	valid_0's f1-score-on-sentence-level: 0.89043
# [10]	valid_0's f1-score-on-sentence-level: 0.902097
# Did not meet early stopping. Best iteration is:
# [10]	valid_0's f1-score-on-sentence-level: 0.902097
# res_score_ls [0, 0, 0, 0, 0.0011425307055127106, 0.5828232971372161, 0.758981278461798, 0.8579112505602868, 0.8904303510758778, 0.902096930981808]
# Fold  1 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0.000579374
# [5]	valid_0's f1-score-on-sentence-level: 0.0132374
# [6]	valid_0's f1-score-on-sentence-level: 0.53622
# [7]	valid_0's f1-score-on-sentence-level: 0.746248
# [8]	valid_0's f1-score-on-sentence-level: 0.863724
# [9]	valid_0's f1-score-on-sentence-level: 0.888794
# [10]	valid_0's f1-score-on-sentence-level: 0.897611
# res_score_ls [0, 0, 0, 0.0005793742757821554, 0.013237410071942445, 0.5362198168193172, 0.7462480593410384, 0.8637241789270322, 0.8887943262411347, 0.8976113982399777]
# Fold  2 :
# [1]	valid_0's f1-score-on-sentence-level: 0
# [2]	valid_0's f1-score-on-sentence-level: 0
# [3]	valid_0's f1-score-on-sentence-level: 0
# [4]	valid_0's f1-score-on-sentence-level: 0
# [5]	valid_0's f1-score-on-sentence-level: 0.0045403
# [6]	valid_0's f1-score-on-sentence-level: 0.556294
# [7]	valid_0's f1-score-on-sentence-level: 0.731565
# [8]	valid_0's f1-score-on-sentence-level: 0.865624
# [9]	valid_0's f1-score-on-sentence-level: 0.893706
# [10]	valid_0's f1-score-on-sentence-level: 0.902193
# res_score_ls [0, 0, 0, 0, 0.004540295119182746, 0.556294058408862, 0.7315654405474764, 0.8656236291855535, 0.8937062937062937, 0.9021934059870327]
# Fold  3 :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-361cee0f49ef> in <module>()
#      19 date_str = datetime.now().strftime('%Y-%m-%d_%H-%M')
#      20 s = time.time()
# ---> 21 result = HP_tuning.param_tuning(init_points = 20, num_iter = 80)
#      22 e = time.time()
#      23 logging.info('It took {} mins'.format((e-s)/60.0))
#
# ~/ner_project/brand_recognition_bio_DL/models/blend/utils.py in param_tuning(self, init_points, num_iter, **args)
#     151         lgbBO = BayesianOptimization(self.lgb_eval, self.params_bound)
#     152
# --> 153         lgbBO.maximize(init_points=init_points, n_iter= num_iter, **args)
#     154         return lgbBO
#     155
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/bayes_opt/bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, xi, **gp_params)
#     241             if self.verbose:
#     242                 self.plog.print_header()
# --> 243             self.init(init_points)
#     244
#     245         y_max = self.space.Y.max()
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/bayes_opt/bayesian_optimization.py in init(self, init_points)
#      87         # Evaluate target function at all initialization points
#      88         for x in self.init_points:
# ---> 89             y = self._observe_point(x)
#      90
#      91         # Add the points from `self.initialize` to the observations
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/bayes_opt/bayesian_optimization.py in _observe_point(self, x)
#     102
#     103     def _observe_point(self, x):
# --> 104         y = self.space.observe_point(x)
#     105         if self.verbose:
#     106             self.plog.print_step(x, y)
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/bayes_opt/target_space.py in observe_point(self, x)
#     137             # measure the target function
#     138             params = dict(zip(self.keys, x))
# --> 139             y = self.target_func(**params)
#     140             self.add_observation(x, y)
#     141         return y
#
# ~/ner_project/brand_recognition_bio_DL/models/blend/utils.py in lgb_eval(self, num_leaves, lambda_l2, lambda_l1, min_child_samples, bagging_fraction, feature_fraction)
#     134         if self.group_fold == True:
#     135             #print ('params',params)
# --> 136             cv_result = self.cv(fit_params = params) # return the f1-score on sentence-level. The higher, The better.
#     137
#     138         else:
#
# ~/ner_project/brand_recognition_bio_DL/models/blend/utils.py in cv(self, fit_params)
#      95                               valid_sets = dvalid,
#      96                               evals_result = evals_result,
# ---> 97                               feval = customized_eval(data = item_id_for_f1, threshold = 0.5, verbose = False),
#      98                                  )
#      99             res_score_ls = evals_result['valid_0']['f1-score-on-sentence-level']
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     181     # construct booster
#     182     try:
# --> 183         booster = Booster(params=params, train_set=train_set)
#     184         if is_valid_contain_train:
#     185             booster.set_train_data_name(train_data_name)
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, silent)
#    1305             self.handle = ctypes.c_void_p()
#    1306             _safe_call(_LIB.LGBM_BoosterCreate(
# -> 1307                 train_set.construct().handle,
#    1308                 c_str(params_str),
#    1309                 ctypes.byref(self.handle)))
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/lightgbm/basic.py in construct(self)
#     858                                 weight=self.weight, group=self.group, init_score=self.init_score,
#     859                                 predictor=self._predictor, silent=self.silent, feature_name=self.feature_name,
# --> 860                                 categorical_feature=self.categorical_feature, params=self.params)
#     861             if self.free_raw_data:
#     862                 self.data = None
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/lightgbm/basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#     650             self.pandas_categorical = reference.pandas_categorical
#     651             categorical_feature = reference.categorical_feature
# --> 652         data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data, feature_name, categorical_feature, self.pandas_categorical)
#     653         label = _label_from_pandas(label)
#     654         self.data_has_header = False
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/lightgbm/basic.py in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     243             raise ValueError('Input data must be 2 dimensional and non empty.')
#     244         if feature_name == 'auto' or feature_name is None:
# --> 245             data = data.rename(columns=str)
#     246         cat_cols = data.select_dtypes(include=['category']).columns
#     247         if pandas_categorical is None:  # train dataset
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     185         @wraps(func)
#     186         def wrapper(*args, **kwargs):
# --> 187             return func(*args, **kwargs)
#     188
#     189         if not PY2:
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/frame.py in rename(self, *args, **kwargs)
#    3779         kwargs.pop('axis', None)
#    3780         kwargs.pop('mapper', None)
# -> 3781         return super(DataFrame, self).rename(**kwargs)
#    3782
#    3783     @Substitution(**_shared_doc_kwargs)
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/generic.py in rename(self, *args, **kwargs)
#     972                 level = self.axes[axis]._get_level_number(level)
#     973             result._data = result._data.rename_axis(f, axis=baxis, copy=copy,
# --> 974                                                     level=level)
#     975             result._clear_item_cache()
#     976
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in rename_axis(self, mapper, axis, copy, level)
#    3337
#    3338         """
# -> 3339         obj = self.copy(deep=copy)
#    3340         obj.set_axis(axis, _transform_index(self.axes[axis], mapper, level))
#    3341         return obj
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in copy(self, deep, mgr)
#    3918             new_axes = list(self.axes)
#    3919         return self.apply('copy', axes=new_axes, deep=deep,
# -> 3920                           do_integrity_check=False)
#    3921
#    3922     def as_array(self, transpose=False, items=None):
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in copy(self, deep, mgr)
#     776         values = self.values
#     777         if deep:
# --> 778             values = values.copy()
#     779         return self.make_block_same_class(values)
#     780
#
# KeyboardInterrupt:
